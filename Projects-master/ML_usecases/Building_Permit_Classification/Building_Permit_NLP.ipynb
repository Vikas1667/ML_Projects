# %% [markdown]
# # Introduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import nltk
import string
import spacy
en_core = spacy.load('en_core_web_sm')
from nltk.corpus import stopwords
stop = stopwords.words('english')
from nltk.tokenize.regexp import regexp_tokenize

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import FeatureUnion

# %%
train_df=pd.read_csv('./dataset/train_file.csv')
test_df=pd.read_csv('./dataset/test_file.csv')

# %%
train_df['Action Type'].unique()
# Out:
# array(['ADD/ALT', 'DEMOLITION', 'ALTER', 'NEW',
#        'TREE/VEGETATION MAINT/RESTORE', 'NO CONSTRUCTION', nan, 'TEMP',
#        'CURB CUT', 'GRADING', 'SHORELINE EXEMPTION ONLY',
#        'SITE MONITORING ONLY', 'DECONSTRUCTION', 'RELOCATION',
#        'FLOODPLAIN LICENSE ONLY', 'TREE PROTECTION EXEMPTION',
#        'DRAINAGE APPROVAL'], dtype=object)

# %%
train_df.dtypes
# Out:
# Application/Permit Number            int64
# Permit Type                         object
# Address                             object
# Description                         object
# Action Type                         object
# Work Type                           object
# Applicant Name                      object
# Application Date                    object
# Issue Date                          object
# Final Date                          object
# Expiration Date                     object
# Status                              object
# Contractor                          object
# Permit and Complaint Status URL     object
# Master Use Permit                  float64
# Latitude                           float64
# Longitude                          float64
# Location                            object
# Category                            object
# dtype: object

# %%
#### train
train_df['Description'] = train_df['Description'].fillna('')
train_df['clean_description']=[' '.join([w for w in x.lower().split() if w not in stop]) for x in train_df['Description'].tolist()]
##### test
test_df['Description'] = test_df['Description'].fillna('')
test_df['clean_description']=[' '.join([w for w in x.lower().split() if w not in stop]) for x in test_df['Description'].tolist()]

# %%
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def remove_punctuation(text):
    return text.translate(str.maketrans('', '',string.punctuation))

def lemmatize(text):
    tokens=regexp_tokenize(text,pattern='\s+',gaps=True) #https://towardsdatascience.com/benchmarking-python-nlp-tokenizers-3ac4735100c5
    return ' '.join([lemmatizer.lemmatize(w) for w in tokens])
###### Train
train_df['clean_description']=train_df['clean_description'].apply(lemmatize)
train_df['clean_description']=train_df['clean_description'].apply(remove_punctuation)
print(train_df['clean_description'])

#### Test
test_df['clean_description']=test_df['clean_description'].apply(lemmatize)
test_df['clean_description']=test_df['clean_description'].apply(remove_punctuation)
print(train_df['clean_description'])
# Out:
# 0        alteration single family residence portions ma...
# 1        change use permit restaurant residential const...
# 2        construct interior alteration existing office ...
# 3        need remove fire escape part building fire saf...
# 4        channel modification thornton creek stream res...
#                                ...
# 33534       interior repair modification existing building
# 33535    construct south duplex units cd one surface pa...
# 33536    establish use construction single family resid...
# 33537    construction new 1923 sf single story wood fra...
# 33538    construct repair existing garage accessory exi...
# Name: clean_description, Length: 33539, dtype: object
# 0        alteration single family residence portions ma...
# 1        change use permit restaurant residential const...
# 2        construct interior alteration existing office ...
# 3        need remove fire escape part building fire saf...
# 4        channel modification thornton creek stream res...
#                                ...
# 33534       interior repair modification existing building
# 33535    construct south duplex units cd one surface pa...
# 33536    establish use construction single family resid...
# 33537    construction new 1923 sf single story wood fra...
# 33538    construct repair existing garage accessory exi...
# Name: clean_description, Length: 33539, dtype: object

# %% [markdown]
# ### Deep Learning for Training
# <!--  -->

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.layers import Flatten,LSTM,Bidirectional
from keras.layers import Embedding,SpatialDropout1D
from numpy import array
from numpy import asarray
from numpy import zeros
from keras.callbacks import EarlyStopping

# %%
t = Tokenizer()
t.fit_on_texts(train_df['clean_description'])
vocab_size = len(t.word_index) + 1
print(vocab_size)
# integer encode the documents
encoded_docs = t.texts_to_sequences(train_df['clean_description'])
# print(encoded_docs)
# pad documents to a max length of 25 words
max_length = 25
padded_docs = pad_sequences(encoded_docs, maxlen=max_length, padding='post')
print(padded_docs.shape)
# Out:
# 17118
# (33539, 25)

# %%
############test Dta
test_t = Tokenizer()
test_t.fit_on_texts(test_df['clean_description'])
vocab_size_test = len(test_t.word_index) + 1
# integer encode the documents
encoded_test_docs = test_t.texts_to_sequences(test_df['clean_description'])
# print(encoded_docs)
# pad documents to a max length of 25 words
max_length = 25
padded_test_docs = pad_sequences(encoded_test_docs, maxlen=max_length, padding='post')
print(padded_test_docs.shape)
# Out:
# (22360, 25)

# %%
# load the whole embedding into memory
embeddings_index = dict()
f = open('./dataset/glove.6B.100d.txt',encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
# create a weight matrix for words in training docs
embedding_matrix = zeros((vocab_size, 100))
for word, i in t.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
Y = pd.get_dummies(train_df['Category']).values
print('Shape of label tensor:', Y.shape)

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.10, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
Y[0]
# Out:
# Shape of label tensor: (33539, 5)
# (30185, 10) (30185, 5)
# (3354, 10) (3354, 5)
# array([0, 0, 0, 0, 1], dtype=uint8)

# %%
# define model
model = Sequential()
e = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=25, trainable=False)
model.add(e)
# model.add(Flatten())
model.add(Bidirectional(LSTM(128, dropout=0.2, recurrent_dropout=0.2)))
model.add(Dense(5, activation='relu'))
model.add(Activation('softmax'))

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# summarize the model
print(model.summary())
# fit the model
model.fit(padded_docs, Y, epochs=100,validation_split=0.1)
# evaluate the model
loss, accuracy = model.evaluate(padded_docs, Y, verbose=0)
print('Accuracy: %f' % (accuracy*100))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 25, 100)           1711800
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               234496
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_3 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 1,947,581
# Trainable params: 235,781
# Non-trainable params: 1,711,800
# _________________________________________________________________
# None
# Epoch 1/100
# 944/944 [==============================] - 67s 61ms/step - loss: 0.6499 - accuracy: 0.7314 - val_loss: 0.6280 - val_accuracy: 0.7788
# Epoch 2/100
# 944/944 [==============================] - 56s 59ms/step - loss: 0.6216 - accuracy: 0.7805 - val_loss: 0.6175 - val_accuracy: 0.7838
# Epoch 3/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.6140 - accuracy: 0.7875 - val_loss: 0.6170 - val_accuracy: 0.7940
# Epoch 4/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.6127 - accuracy: 0.7936 - val_loss: 0.6146 - val_accuracy: 0.7970
# Epoch 5/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.6112 - accuracy: 0.7913 - val_loss: 0.6172 - val_accuracy: 0.7886
# Epoch 6/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.6073 - accuracy: 0.8213 - val_loss: 0.6111 - val_accuracy: 0.8626
# Epoch 7/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.6032 - accuracy: 0.8711 - val_loss: 0.6122 - val_accuracy: 0.8679
# Epoch 8/100
# 944/944 [==============================] - 60s 63ms/step - loss: 0.6012 - accuracy: 0.8707 - val_loss: 0.6107 - val_accuracy: 0.8706
# Epoch 9/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.5992 - accuracy: 0.8770 - val_loss: 0.6111 - val_accuracy: 0.8637
# Epoch 10/100
# 944/944 [==============================] - 57s 60ms/step - loss: 0.5979 - accuracy: 0.8837 - val_loss: 0.6114 - val_accuracy: 0.8640
# Epoch 11/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5977 - accuracy: 0.8769 - val_loss: 0.6099 - val_accuracy: 0.8688
# Epoch 12/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5954 - accuracy: 0.8842 - val_loss: 0.6118 - val_accuracy: 0.8733
# Epoch 13/100
# 944/944 [==============================] - 59s 63ms/step - loss: 0.5950 - accuracy: 0.8824 - val_loss: 0.6134 - val_accuracy: 0.8697
# Epoch 14/100
# 944/944 [==============================] - 60s 63ms/step - loss: 0.5933 - accuracy: 0.8855 - val_loss: 0.6137 - val_accuracy: 0.8718
# Epoch 15/100
# 944/944 [==============================] - 59s 63ms/step - loss: 0.5924 - accuracy: 0.8870 - val_loss: 0.6139 - val_accuracy: 0.8709
# Epoch 16/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5912 - accuracy: 0.8906 - val_loss: 0.6169 - val_accuracy: 0.8724
# Epoch 17/100
# 944/944 [==============================] - 61s 65ms/step - loss: 0.5906 - accuracy: 0.8886 - val_loss: 0.6168 - val_accuracy: 0.8724
# Epoch 18/100
# 944/944 [==============================] - 64s 68ms/step - loss: 0.5890 - accuracy: 0.8921 - val_loss: 0.6168 - val_accuracy: 0.8697
# Epoch 19/100
# 944/944 [==============================] - 61s 64ms/step - loss: 0.5889 - accuracy: 0.8908 - val_loss: 0.6207 - val_accuracy: 0.8724
# Epoch 20/100
# 944/944 [==============================] - 70s 74ms/step - loss: 0.5876 - accuracy: 0.8939 - val_loss: 0.6164 - val_accuracy: 0.8712
# Epoch 21/100
# 944/944 [==============================] - 77s 82ms/step - loss: 0.5876 - accuracy: 0.8931 - val_loss: 0.6194 - val_accuracy: 0.8745
# Epoch 22/100
# 944/944 [==============================] - 73s 77ms/step - loss: 0.5870 - accuracy: 0.8922 - val_loss: 0.6221 - val_accuracy: 0.8715
# Epoch 23/100
# 944/944 [==============================] - 63s 67ms/step - loss: 0.5867 - accuracy: 0.8945 - val_loss: 0.6213 - val_accuracy: 0.8721
# Epoch 24/100
# 944/944 [==============================] - 62s 66ms/step - loss: 0.5856 - accuracy: 0.8941 - val_loss: 0.6209 - val_accuracy: 0.8727
# Epoch 25/100
# 944/944 [==============================] - 60s 63ms/step - loss: 0.5847 - accuracy: 0.8977 - val_loss: 0.6226 - val_accuracy: 0.8700
# Epoch 26/100
# 944/944 [==============================] - 60s 63ms/step - loss: 0.5850 - accuracy: 0.8942 - val_loss: 0.6214 - val_accuracy: 0.8688
# Epoch 68/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5768 - accuracy: 0.9128 - val_loss: 0.6550 - val_accuracy: 0.8724
# Epoch 69/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5767 - accuracy: 0.9123 - val_loss: 0.6488 - val_accuracy: 0.8763
# Epoch 70/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5762 - accuracy: 0.9141 - val_loss: 0.6495 - val_accuracy: 0.8691
# Epoch 71/100
# 944/944 [==============================] - 60s 64ms/step - loss: 0.5768 - accuracy: 0.9107 - val_loss: 0.6430 - val_accuracy: 0.8736
# Epoch 72/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.5764 - accuracy: 0.9128 - val_loss: 0.6465 - val_accuracy: 0.8730
# Epoch 73/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5763 - accuracy: 0.9135 - val_loss: 0.6516 - val_accuracy: 0.8697
# Epoch 74/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5768 - accuracy: 0.9121 - val_loss: 0.6542 - val_accuracy: 0.8679
# Epoch 75/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5765 - accuracy: 0.9115 - val_loss: 0.6542 - val_accuracy: 0.8670
# Epoch 76/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5770 - accuracy: 0.9131 - val_loss: 0.6514 - val_accuracy: 0.8721
# Epoch 77/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5761 - accuracy: 0.9137 - val_loss: 0.6482 - val_accuracy: 0.8703
# Epoch 78/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5763 - accuracy: 0.9142 - val_loss: 0.6547 - val_accuracy: 0.8724
# Epoch 79/100
# 944/944 [==============================] - 57s 60ms/step - loss: 0.5754 - accuracy: 0.9176 - val_loss: 0.6509 - val_accuracy: 0.8697
# Epoch 80/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5766 - accuracy: 0.9136 - val_loss: 0.6504 - val_accuracy: 0.8754
# Epoch 81/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5758 - accuracy: 0.9142 - val_loss: 0.6500 - val_accuracy: 0.8724
# Epoch 82/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5762 - accuracy: 0.9141 - val_loss: 0.6547 - val_accuracy: 0.8727
# Epoch 83/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5759 - accuracy: 0.9153 - val_loss: 0.6546 - val_accuracy: 0.8754
# Epoch 84/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5767 - accuracy: 0.9137 - val_loss: 0.6498 - val_accuracy: 0.8709
# Epoch 85/100
# 944/944 [==============================] - 60s 64ms/step - loss: 0.5752 - accuracy: 0.9175 - val_loss: 0.6545 - val_accuracy: 0.8724
# Epoch 86/100
# 944/944 [==============================] - 60s 64ms/step - loss: 0.5761 - accuracy: 0.9128 - val_loss: 0.6543 - val_accuracy: 0.8763
# Epoch 87/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5759 - accuracy: 0.9146 - val_loss: 0.6534 - val_accuracy: 0.8748
# Epoch 88/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5759 - accuracy: 0.9153 - val_loss: 0.6529 - val_accuracy: 0.8718
# Epoch 89/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5752 - accuracy: 0.9161 - val_loss: 0.6558 - val_accuracy: 0.8703
# Epoch 90/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5754 - accuracy: 0.9167 - val_loss: 0.6545 - val_accuracy: 0.8757
# Epoch 91/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5755 - accuracy: 0.9136 - val_loss: 0.6570 - val_accuracy: 0.8772
# Epoch 92/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5754 - accuracy: 0.9147 - val_loss: 0.6496 - val_accuracy: 0.8742
# Epoch 93/100
# 944/944 [==============================] - 57s 61ms/step - loss: 0.5756 - accuracy: 0.9152 - val_loss: 0.6491 - val_accuracy: 0.8706
# Epoch 94/100
# 944/944 [==============================] - 58s 61ms/step - loss: 0.5756 - accuracy: 0.9129 - val_loss: 0.6541 - val_accuracy: 0.8733
# Epoch 95/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.5752 - accuracy: 0.9147 - val_loss: 0.6505 - val_accuracy: 0.8724
# Epoch 96/100
# 944/944 [==============================] - 59s 62ms/step - loss: 0.5747 - accuracy: 0.9179 - val_loss: 0.6458 - val_accuracy: 0.8721
# Epoch 97/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.5756 - accuracy: 0.9146 - val_loss: 0.6453 - val_accuracy: 0.8778
# Epoch 98/100
# 944/944 [==============================] - 61s 64ms/step - loss: 0.5752 - accuracy: 0.9152 - val_loss: 0.6530 - val_accuracy: 0.8718
# Epoch 99/100
# 944/944 [==============================] - 60s 64ms/step - loss: 0.5752 - accuracy: 0.9156 - val_loss: 0.6514 - val_accuracy: 0.8730
# Epoch 100/100
# 944/944 [==============================] - 58s 62ms/step - loss: 0.5745 - accuracy: 0.9205 - val_loss: 0.6604 - val_accuracy: 0.8763
# Accuracy: 91.878110

# %%
pred=model.predict_classes(padded_test_docs)

# %%
LE_target=LabelEncoder()
y=train_df['Category']
y=LE_target.fit_transform(y)
labels=pred.flatten()
test_df['Category']=LE_target.inverse_transform(labels)

# %%
test_df
# Out:
#        Application/Permit Number   Permit Type                Address  \
# 0                        6425384  Construction       8348 18TH AVE NW
# 1                        6496502  Construction    3120 S FRONTENAC ST
# 2                        6622347    Demolition       4031 S WILLOW ST
# 3                        6565685  Construction        3940 1ST AVE NE
# 4                        6487370  Construction    5317 BALLARD AVE NW
# ...                          ...           ...                    ...
# 22355                    6284796  Construction         6701 6TH AVE S
# 22356                    6242102  Construction           2001 8TH AVE
# 22357                    6593264  Construction        3200 SW 97TH ST
# 22358                    6440664  Construction  4140 ROOSEVELT WAY NE
# 22359                    6264853  Construction         7400 8TH AVE S
#
#                                              Description Action Type  \
# 0      Construct 6' retaining wall to create walkway,...     ADD/ALT
# 1      Like for like repair of framing at porches of ...     ADD/ALT
# 2      Demolish existing single family dwelling. Subj...  DEMOLITION
# 3      Establish use as rowhouse and construct new du...         NEW
# 4      Tenant improvement to existing women's boutiqu...     ADD/ALT
# ...                                                  ...         ...
# 22355                    TI - add additional locker room     ADD/ALT
# 22356  Non-structural building improvement on floor 3...     ADD/ALT
# 22357  Interior alterations to existing single family...     ADD/ALT
# 22358  Re-roof as overlay to commercial structure, su...     ADD/ALT
# 22359  Temporary use for 258 bus and van  parking spa...        TEMP
#
#             Work Type        Applicant Name     Application Date  \
# 0      No plan review        JOSSART, STEVE  2014-07-02T00:00:00
# 1      No plan review        RUNDLE, DANIEL  2015-11-12T00:00:00
# 2      No plan review         WEBER, JULIAN  2017-10-04T00:00:00
# 3         Plan Review         NOVION, SHAUN  2017-02-14T00:00:00
# 4      No plan review  DYNA CONTRACTING INC  2017-07-19T00:00:00
# ...               ...                   ...                  ...
# 22355     Plan Review           FADDEN, BOB                  NaN
# 22356     Plan Review         TULLY, TRICIA                  NaN
# 22357  No plan review           VEIT, TYLER  2017-04-24T00:00:00
# 22358  No plan review          NELSON, LANE  2014-10-09T00:00:00
# 22359     Plan Review       STEWART, DANIEL                  NaN
#
#                 Issue Date           Final Date      Expiration Date  \
# 0      2014-07-02T00:00:00  2015-06-29T00:00:00  2016-01-02T00:00:00
# 1      2015-11-12T00:00:00  2016-02-10T00:00:00  2017-05-12T00:00:00
# 2                      NaN                  NaN                  NaN
# 3      2017-10-20T00:00:00                  NaN  2019-04-20T00:00:00
# 4      2017-07-19T00:00:00  2018-01-17T00:00:00  2019-01-19T00:00:00
# ...                    ...                  ...                  ...
# 22355                  NaN                  NaN                  NaN
# 22356                  NaN                  NaN                  NaN
# 22357  2017-04-24T00:00:00                  NaN  2018-10-24T00:00:00
# 22358  2014-10-09T00:00:00  2016-04-04T00:00:00  2016-04-09T00:00:00
# 22359                  NaN                  NaN  2012-02-29T00:00:00
#
#                               Status              Contractor  \
# 0                      Permit Closed                     NaN
# 1                      Permit Closed  SCHULTIS SUNDBERG INC.
# 2                  Reviews Completed                     NaN
# 3                      Permit Issued                     NaN
# 4                      Permit Closed    DYNA CONTRACTING INC
# ...                              ...                     ...
# 22355                            NaN        VIOX CORPORATION
# 22356  Initial Information Collected                     NaN
# 22357                  Permit Issued                     NaN
# 22358                  Permit Closed                     NaN
# 22359  Initial Information Collected                     NaN
#
#                          Permit and Complaint Status URL  Master Use Permit  \
# 0      {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# 1      {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# 2      {'url': 'http://web6.seattle.gov/dpd/PermitSta...          3024280.0
# 3      {'url': 'http://web6.seattle.gov/dpd/PermitSta...          3025762.0
# 4      {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# ...                                                  ...                ...
# 22355  {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# 22356  {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# 22357  {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# 22358  {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
# 22359  {'url': 'http://web6.seattle.gov/dpd/PermitSta...                NaN
#
#         Latitude   Longitude  \
# 0      47.690123 -122.379795
# 1      47.540111 -122.290535
# 2      47.540470 -122.281410
# 3      47.654986 -122.327467
# 4      47.666714 -122.383900
# ...          ...         ...
# 22355  47.543799 -122.326393
# 22356  47.615789 -122.337271
# 22357  47.516830 -122.373745
# 22358  47.657730 -122.317570
# 22359  47.537002 -122.321081
#
#                                                 Location  \
# 0      {'latitude': '47.69012273', 'human_address': '...
# 1      {'latitude': '47.54011095', 'human_address': '...
# 2      {'latitude': '47.54046991', 'human_address': '...
# 3      {'latitude': '47.65498619', 'human_address': '...
# 4      {'latitude': '47.66671437', 'human_address': '...
# ...                                                  ...
# 22355  {'latitude': '47.54379887', 'human_address': '...
# 22356  {'latitude': '47.61578904', 'human_address': '...
# 22357  {'latitude': '47.51683006', 'human_address': '...
# 22358  {'latitude': '47.65773041', 'human_address': '...
# 22359  {'latitude': '47.53700203', 'human_address': '...
#
#                                        clean_description  \
# 0      construct 6 retaining wall create walkway per ...
# 1      like like repair framing porch existing 2 fami...
# 2      demolish existing single family dwelling subje...
# 3      establish use rowhouse construct new duplex su...
# 4      tenant improvement existing womens boutique su...
# ...                                                  ...
# 22355                     ti  add additional locker room
# 22356  nonstructural building improvement floor 3r ad...
# 22357  interior alteration existing single family res...
# 22358  reroof overlay commercial structure subject fi...
# 22359  temporary use 258 bus van parking space beginn...
#
#                      Category
# 0                  COMMERCIAL
# 1      SINGLE FAMILY / DUPLEX
# 2      SINGLE FAMILY / DUPLEX
# 3                  COMMERCIAL
# 4                  COMMERCIAL
# ...                       ...
# 22355  SINGLE FAMILY / DUPLEX
# 22356              COMMERCIAL
# 22357  SINGLE FAMILY / DUPLEX
# 22358              COMMERCIAL
# 22359              COMMERCIAL
#
# [22360 rows x 20 columns]

# %%
NLP_model=pd.DataFrame(test_df,columns=['Application/Permit Number','Category'])
NLP_model.to_csv('submission1.csv')

# %%
# define model
model = Sequential()
e = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=25, trainable=False)
model.add(e)
# model.add(Flatten())
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(5, activation='relu'))
model.add(Activation('softmax'))

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# summarize the model
print(model.summary())
# fit the model
model.fit(padded_docs, Y, epochs=5,validation_split=0.1)
# evaluate the model
loss, accuracy = model.evaluate(padded_docs, Y, verbose=0)
print('Accuracy: %f' % (accuracy*100))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 25, 100)           1711800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 645
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 1,829,693
# Trainable params: 117,893
# Non-trainable params: 1,711,800
# _________________________________________________________________
# None
# Epoch 1/5
# 944/944 [==============================] - 32s 32ms/step - loss: 0.6932 - accuracy: 0.2866 - val_loss: 0.6931 - val_accuracy: 0.3083
# Epoch 2/5
# 944/944 [==============================] - 30s 31ms/step - loss: 0.6931 - accuracy: 0.2907 - val_loss: 0.6931 - val_accuracy: 0.3083
# Epoch 3/5
# 944/944 [==============================] - 30s 31ms/step - loss: 0.6931 - accuracy: 0.2926 - val_loss: 0.6931 - val_accuracy: 0.3083
# Epoch 4/5
# 944/944 [==============================] - 29s 31ms/step - loss: 0.6931 - accuracy: 0.2926 - val_loss: 0.6931 - val_accuracy: 0.3083
# Epoch 5/5
# 944/944 [==============================] - 30s 32ms/step - loss: 0.6931 - accuracy: 0.2917 - val_loss: 0.6931 - val_accuracy: 0.3083
# Accuracy: 29.154119
