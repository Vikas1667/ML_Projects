# %% [markdown]
# # Author_Coauthor_Network

# %% [markdown]
# # The code contain three module
#  1. Extraction of PubMed Data from NCBI's PubMed DB
#  2. Calculat the Weight of the network
#  3. Vizulaization of the coauthor Network

# %% [markdown]
# ## Extraction Process

# %%
import requests
from bs4 import BeautifulSoup as bs
import json

API_KEY = "9446fd13127051ca7343c2018204779d8007"
keyword = "covid19"


esearch = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term="
#covid19&usehistory=true&webenv=true&retmax=10&api_key=9446fd13127051ca7343c2018204779d8007"

search_resp = requests.get(esearch+keyword+"&usehistory=true&webenv=true"+"api_key="+API_KEY)
search_soup = bs(search_resp.content,features="lxml")
webenv = search_soup.find("webenv").text
#count = search_soup.find("count").text
count =100
batch_size = 5
batches = []
for batch in range(0,int(count),5):
    efetch = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&query_key=1&webenv="    
    fetch_resp = requests.get(efetch+webenv+"&rettype=xml&api_key="+API_KEY+"&retmode=xml&retmax=2000&retstart="+str(batch))
    fetch_soup = bs(fetch_resp.content,features="lxml")
    articles_list = []
    PubmedArticleSet = fetch_soup.find("pubmedarticleset")
    articles = PubmedArticleSet.find_all("pubmedarticle")
    for article in articles:
        article_dict = {}
        title = article.find("articletitle").text        
        pmid = article.find("pmid").text    
        
        authors =  article.find("authorlist")
        author_list = []
        try:
            author_l = authors.find_all("author")
        except AttributeError:
            break        
            
        for auth in author_l:
            author_dict = {}
            try:
                first_name = auth.find("forename").text            
            except:
                first_name = ""            
            try:
                second_name = auth.find("lastname").text            
            except:
                second_name = ""           
            try:
                initials = auth.find("initials").text           
            except:
                initials = ""            
                
            author_name = initials+" " +first_name +" "+second_name            
            try:
                affiliation = auth.find("affiliation").text            
            except:
                affiliation = ""            
            author_dict["author_name"] = author_name            
            author_dict["affiliation"] = affiliation            
            author_list.append(author_dict)
        article_dict["title"] = title        
        article_dict["pmid"] = pmid        
        article_dict["author"] = author_list    
    batches.append(article_dict)
    print(batches)
    print("<------------------------------------------------------------------------------------------------>")
# Out:
# [{}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# <------------------------------------------------------------------------------------------------>

# %% [markdown]
# ## Weight Calulation

# %%
import pandas as pd
pd.__version__
# !pip install update pandas
import json
from ast import literal_eval
import ast

# %%
# df=pd.read_csv('V:/ML_projects/Github_projects/Projects/Projects-master/ML_usecases/Pubmed_extraction/df1.csv')
df=pd.read_csv('V:/ML_projects/Github_projects/Projects/Projects-master/ML_usecases/Pubmed_extraction/pubmed10.csv')
# df['affiliation'][0]
df
# Out:
#     Unnamed: 0                                              title      pmid  \
# 0            0  Occupational facial dermatoses related to mask...  34450685
# 1            1  Occupational facial dermatoses related to mask...  34450685
# 2            2  Identification of Niemann-Pick C1 protein as a...  34450201
# 3            3  Identification of Niemann-Pick C1 protein as a...  34450201
# 4           10  Sex steroid hormones are associated with morta...  34449505
# 5           11  Sex steroid hormones are associated with morta...  34449505
# 6           12  Sex steroid hormones are associated with morta...  34449505
# 7           13  Sex steroid hormones are associated with morta...  34449505
# 8           14  Sex steroid hormones are associated with morta...  34449505
# 9           15  Sex steroid hormones are associated with morta...  34449505
# 10          16  Sex steroid hormones are associated with morta...  34449505
#
#                    author_name  \
# 0                  E Ece Altun
# 1      F Filiz Topaloglu Demir
# 2      I Isabel Garcia-Dorival
# 3                 Cuesta-Geijo
# 4   IE Ingeborg E van Zeggeren
# 5               A Anita Boelen
# 6       D Diederik van de Beek
# 7      AC Annemieke C Heijboer
# 8      APJ Alexander P J Vlaar
# 9        MC Matthijs C Brouwer
# 10
#
#                                           affiliation
# 0   Department of Dermatology and Venereology, Ist...
# 1   Department of Dermatology and Venereology, Ist...
# 2   Dpt. BiotecnologÃ­a, Instituto Nacional de Inv...
# 3                                                 NaN
# 4   Amsterdam UMC, University of Amsterdam, Depart...
# 5   Amsterdam UMC, University of Amsterdam, Depart...
# 6   Amsterdam UMC, University of Amsterdam, Depart...
# 7   Amsterdam UMC, University of Amsterdam, Depart...
# 8   Amsterdam UMC, University of Amsterdam, Depart...
# 9   Amsterdam UMC, University of Amsterdam, Depart...
# 10                                                NaN

# %%
duplicate = df[~df['pmid'].duplicated()]
first_auth_name=duplicate['author_name'].tolist()
print(first_auth_name)
duplicate = df[df['pmid'].duplicated()]
coauth_name=duplicate['author_name'].tolist()
print(coauth_name)
# Out:
# ['E Ece Altun', 'I Isabel Garcia-Dorival', 'IE Ingeborg E van Zeggeren']
# ['F Filiz Topaloglu Demir', '  Cuesta-Geijo', 'A Anita Boelen', 'D Diederik van de Beek', 'AC Annemieke C Heijboer', 'APJ Alexander P J Vlaar', 'MC Matthijs C Brouwer', '  ']

# %%
for i in df.iteritems():
    print(i)
# Out:
# ('Unnamed: 0', 0      0
# 1      1
# 2      2
# 3      3
# 4     10
# 5     11
# 6     12
# 7     13
# 8     14
# 9     15
# 10    16
# Name: Unnamed: 0, dtype: int64)
# ('title', 0     Occupational facial dermatoses related to mask...
# 1     Occupational facial dermatoses related to mask...
# 2     Identification of Niemann-Pick C1 protein as a...
# 3     Identification of Niemann-Pick C1 protein as a...
# 4     Sex steroid hormones are associated with morta...
# 5     Sex steroid hormones are associated with morta...
# 6     Sex steroid hormones are associated with morta...
# 7     Sex steroid hormones are associated with morta...
# 8     Sex steroid hormones are associated with morta...
# 9     Sex steroid hormones are associated with morta...
# 10    Sex steroid hormones are associated with morta...
# Name: title, dtype: object)
# ('pmid', 0     34450685
# 1     34450685
# 2     34450201
# 3     34450201
# 4     34449505
# 5     34449505
# 6     34449505
# 7     34449505
# 8     34449505
# 9     34449505
# 10    34449505
# Name: pmid, dtype: int64)
# ('author_name', 0                    E Ece Altun
# 1        F Filiz Topaloglu Demir
# 2        I Isabel Garcia-Dorival
# 3                   Cuesta-Geijo
# 4     IE Ingeborg E van Zeggeren
# 5                 A Anita Boelen
# 6         D Diederik van de Beek
# 7        AC Annemieke C Heijboer
# 8        APJ Alexander P J Vlaar
# 9          MC Matthijs C Brouwer
# 10
# Name: author_name, dtype: object)
# ('affiliation', 0     Department of Dermatology and Venereology, Ist...
# 1     Department of Dermatology and Venereology, Ist...
# 2     Dpt. BiotecnologÃ­a, Instituto Nacional de Inv...
# 3                                                   NaN
# 4     Amsterdam UMC, University of Amsterdam, Depart...
# 5     Amsterdam UMC, University of Amsterdam, Depart...
# 6     Amsterdam UMC, University of Amsterdam, Depart...
# 7     Amsterdam UMC, University of Amsterdam, Depart...
# 8     Amsterdam UMC, University of Amsterdam, Depart...
# 9     Amsterdam UMC, University of Amsterdam, Depart...
# 10                                                  NaN
# Name: affiliation, dtype: object)

# %%
first_name--> count(pmid)
coauth_name->count(pmid)
module_function

(first-->each(co_auth))--> bigram-->count(pmid)
coauthor-->first_author-->pmid
coauthr-->coauthor-->

module building 

visualize(first,couther)
analysis->observation
module_function

break(bootstrap)-->statistic-->eda
visualize-->build
module_function

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

data = pd.read_csv("V:/ML_projects/Github_projects/Projects/Projects-master/ML_usecases/Pubmed_extraction/pubmed10.csv")
data = data.query("affiliation == 'Department of Dermatology and Venereology, Istanbul Medipol University, Istanbul, Turkey.'")
# data["Date"] = pd.to_datetime(data["Date"], format="%Y-%m-%d")
# data.sort_values("Date", inplace=True)

# app = dash.Dash(__name__)
