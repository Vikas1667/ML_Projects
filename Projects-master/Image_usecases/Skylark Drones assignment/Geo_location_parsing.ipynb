# %%
import wget
file=wget.download("https://opendata.arcgis.com/datasets/8fdd810d7bbc4c64b1676a5130cbf90d_0.geojson")
# Out:
# -1 / unknown

# %%
# !pip install geojson
import geojson
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'v:\python_environments\nlp_projects\scripts\python.exe -m pip install --upgrade pip' command.

# %%
with open(file) as f:
    gj = geojson.load(f)

# %%
print(gj)
# Out:
# {"crs": {"properties": {"name": "urn:ogc:def:crs:OGC:1.3:CRS84"}, "type": "name"}, "features": [{"geometry": {"coordinates": [75.85, 30.9], "type": "Point"}, "properties": {"cityarea": 159, "cityname": "Ludhiana", "households": 344333, "objectid": 1, "population": 1618879, "round": 1, "statename": "Punjab", "type": "Light House"}, "type": "Feature"}, {"geometry": {"coordinates": [77.2, 28.6], "type": "Point"}, "properties": {"cityarea": 43, "cityname": "NDMC", "households": 59500, "objectid": 2, "population": 257803, "round": 1, "statename": "Delhi", "type": "Light House"}, "type": "Feature"}, {"geometry": {"coordinates": [75.82, 26.92], "type": "Point"}, "properties": {"cityarea": 485, "cityname": "Jaipur", "households": 599507, "objectid": 3, "population": 3046163, "round": 1, "statename": "Rajasthan", "type": "Light House"}, "type": "Feature"}, {"geometry": {"coordinates": [73.69, 24.58], "type": "Point"}, "properties": {"cityarea": 57, "cityname": "Udaipur", "households": 94704, 
# ...
