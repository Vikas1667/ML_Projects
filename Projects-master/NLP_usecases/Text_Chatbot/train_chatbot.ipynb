# %% [markdown]
# ## Import Libraries and Load the Data

# %%
import numpy as np
import json

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

import pickle
import random

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
intents_file = open("intents.json").read()
print(intents_file)
intents = json.loads(intents_file)
# Out:
# {"intents": [
#         {"tag": "greeting",
#          "patterns": ["Hi there", "How are you", "Is anyone there?","Hey","Hola", "Hello", "Good day"],
#          "responses": ["Hello, thanks for asking", "Good to see you again", "Hi there, how can I help?"],
#          "context": [""]
#         },
#         {"tag": "goodbye",
#          "patterns": ["Bye", "See you later", "Goodbye", "Nice chatting to you, bye", "Till next time"],
#          "responses": ["See you!", "Have a nice day", "Bye! Come back again soon."],
#          "context": [""]
#         },
#         {"tag": "thanks",
#          "patterns": ["Thanks", "Thank you", "That's helpful", "Awesome, thanks", "Thanks for helping me"],
#          "responses": ["Happy to help!", "Any time!", "My pleasure"],
#          "context": [""]
#         },
#         {"tag": "noanswer",
#          "patterns": [],
#          "responses": ["Sorry, can't understand you", "Please give me more info", "Not sure I understand"],
#          "context": [""]
#         },
#         {"tag": "options",
#          "patterns": ["How you could help me?", "What you can do?", "What help you provide?", "How you can be helpful?", "What support is offered"],
#          "responses": ["I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies", "Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies"],
#          "context": [""]
#         },
#         {"tag": "adverse_drug",
#          "patterns": ["How to check Adverse drug reaction?", "Open adverse drugs module", "Give me a list of drugs causing adverse behavior", "List all drugs suitable for patient with adverse reaction", "Which drugs dont have adverse reaction?" ],
#          "responses": ["Navigating to Adverse drug reaction module"],
#          "context": [""]
#         },
#         {"tag": "blood_pressure",
#          "patterns": ["Open blood pressure module", "Task related to blood pressure", "Blood pressure data entry", "I want to log blood pressure results", "Blood pressure data management" ],
#          "responses": ["Navigating to Blood Pressure module"],
#          "context": [""]
#         },
#         {"tag": "blood_pressure_search",
#          "patterns": ["I want to search for blood pressure result history", "Blood pressure for patient", "Load patient blood pressure result", "Show blood pressure results for patient", "Find blood pressure results by ID" ],
#          "responses": ["Please provide Patient ID", "Patient ID?"],
#          "context": ["search_blood_pressure_by_patient_id"]
#         },
#         {"tag": "search_blood_pressure_by_patient_id",
#          "patterns": [],
#          "responses": ["Loading Blood pressure result for Patient"],
#          "context": [""]
#         },
#         {"tag": "pharmacy_search",
#          "patterns": ["Find me a pharmacy", "Find pharmacy", "List of pharmacies nearby", "Locate pharmacy", "Search pharmacy" ],
#          "responses": ["Please provide pharmacy name"],
#          "context": ["search_pharmacy_by_name"]
#         },
#         {"tag": "search_pharmacy_by_name",
#          "patterns": [],
#          "responses": ["Loading pharmacy details"],
#          "context": [""]
#         },
#         {"tag": "hospital_search",
#          "patterns": ["Lookup for hospital", "Searching for hospital to transfer patient", "I want to search hospital data", "Hospital lookup for patient", "Looking up hospital details" ],
#          "responses": ["Please provide hospital name or location"],
#          "context": ["search_hospital_by_params"]
#         },
#         {"tag": "search_hospital_by_params",
#          "patterns": [],
#          "responses": ["Please provide hospital type"],
#          "context": ["search_hospital_by_type"]
#         },
#         {"tag": "search_hospital_by_type",
#          "patterns": [],
#          "responses": ["Loading hospital details"],
#          "context": [""]
#         }
#    ]
# }

# %% [markdown]
# ## Preprocessing the Data

# %%
words = []
classes = []
documents = []
ignore_letters = ['!','?',',','.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        # add document in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes")
print(classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words")
print(words)
# Out:
# 47 documents
# 9 classes
# ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words
# ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %% [markdown]
# ## Create Training and Testing Data

# %%
# create the training data
training = []

# create empty array for the output
output_empty = [0] * len(classes)

# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)

# create training and testing lists. X - patterns, Y - intents
X_train = list(training[:,0])
y_train = list(training[:,1])

# %% [markdown]
# ## Training the Model

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(X_train[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]), activation='softmax'))

# %%
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               11264
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 585
# =================================================================
# Total params: 20,105
# Trainable params: 20,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training and saving the model 
hist = model.fit(np.array(X_train), np.array(y_train), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.3002 - accuracy: 0.1277
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1949 - accuracy: 0.1277
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1375 - accuracy: 0.1702
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0558 - accuracy: 0.2340
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9430 - accuracy: 0.3830
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7852 - accuracy: 0.5319
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7436 - accuracy: 0.5319
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5254 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5401 - accuracy: 0.5532
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2753 - accuracy: 0.7234
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2197 - accuracy: 0.6596
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1033 - accuracy: 0.7447
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2137 - accuracy: 0.7021
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8516 - accuracy: 0.7660
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8920 - accuracy: 0.7447
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7243 - accuracy: 0.8298
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7314 - accuracy: 0.8298
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6457 - accuracy: 0.8511
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7079 - accuracy: 0.8723
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8511
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5874 - accuracy: 0.7660
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5090 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4238 - accuracy: 0.8936
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8936
# Epoch 25/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.80 - 0s 2ms/step - loss: 0.3260 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4450 - accuracy: 0.8723
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3521 - accuracy: 0.8936
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9787
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2139 - accuracy: 0.9149
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2692 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.9787
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 0.9574
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1383 - accuracy: 0.9787
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9362
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 1.0000
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.9362
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9149
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1701 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2048 - accuracy: 0.9362
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0789 - accuracy: 1.0000
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9362
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.8936
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9574
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9362
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0717 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9362
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.8936
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9574
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1114 - accuracy: 0.9574
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9787
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9787
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1004 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9787
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9574
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9787
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0759 - accuracy: 0.9574
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.9574
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9787
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1605 - accuracy: 0.9574
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0828 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 0.9787
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9574
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9362
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9787
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9787
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# model is created
