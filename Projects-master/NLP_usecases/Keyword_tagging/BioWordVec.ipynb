# %% [markdown]
# # Keyword and Phrase tagging
#    <font size="4">With this task we will extract keywords and Phrase with contextual and semantic relations</font>
#
# ## Data
# [1.Data Extraction](#1.Data_Extraction)
#
# <font size="4">
#     Here 2k Patent Records from Patbase has been used
# </font>
#
# ## Trained and Pre-trained Embedding Model overview and Usage
#
# ### Embedding
#
# <font size="3">
#       1. BioWordVec Trained
#       2. BioWordVec Pre-trained
#       3. Glove
# </font>
#
#
# ### Model
#
# <font size="4">
#       1. Sentence Transformers
#       2. BlueBERT
# </font>
#
#
# ## Preprocessing
#
# 1. Remove tags
# 2. Lemmatizer
#
#
#
# ## Keywords Tagging
#
#
# ### Keywords Extraction
#
# <font size="4">
# 1) Count Vectorizer \
# 2) TFIDF
# </font>
#
#
# ### Remove Redudant Keywords
# <font size="4">
#        Maximal Margin Relevancy
# </font>
#
#
# ## Library
# 1) gensim
# 2) spacy
# 3) nltk

# %%
import string
import re
import numpy as np
import pandas as pd
import codecs
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from gensim.models import Word2Vec
from gensim.models.fasttext import FastText
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
from scipy import spatial


import nltk
from nltk.corpus import wordnet,stopwords
from nltk.stem import WordNetLemmatizer 
from nltk import WordNetLemmatizer, pos_tag, word_tokenize



from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

from scipy import stats

import spacy
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])


import tqdm

# doc=nlp(text)
stop_words=stopwords.words('english')
from gensim.summarization import keywords
lemmatizer = WordNetLemmatizer()
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %% [markdown]
# ## 1.Data_Extraction

# %%
pat_data=pd.read_csv('patbase_bib_csv200020210716_.csv')
abs_text=pat_data['Abstract']
print(type(abs_text))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Preprocessing

# %%
def text_cleaning(text):
    cleaned_txt = re.sub('<[^<]+>', '', str(text))
    cleaned_txt = re.sub( r'\[.*?\]', '',cleaned_txt)  #remove brackets
    cleaned_txt = re.sub('\d+', '', cleaned_txt)
    cleaned_txt = re.sub('\(\w+\)', '', cleaned_txt)
    cleaned_txt=cleaned_txt.translate(str.maketrans('', '',string.punctuation)) 
    return cleaned_txt
   
def stopword_removal(text):
    cleaned_txt = ' '.join([token for token in word_tokenize(text) if token not in stop_words])
    return cleaned_txt
def lemmatize_text(text):
    cleaned_txt=' '.join([lemmatizer.lemmatize(token) for token in word_tokenize(text)])
    return cleaned_txt

def preprocessed_text(df):
    
    col=['nltk_tokens','nouns','lemmatize_text']
    preprocess_txt=pd.DataFrame(columns=col)
    abs_clean_text=df.apply(text_cleaning)
    
    stopword_removed_text=abs_clean_text.apply(stopword_removal)         
    preprocess_txt['lemmatize_text']=stopword_removed_text.apply(lemmatize_text)
  
    for ind,text in preprocess_txt['lemmatize_text'].iteritems():       
        tokens=word_tokenize(text)
        pos_tokens=nltk.pos_tag(tokens)
        preprocess_txt.at[ind,'nouns']=[pos_token for pos_token,pos in pos_tokens if pos.startswith('N')]
        preprocess_txt.at[ind,'nltk_tokens']=tokens     
    return preprocess_txt

# %%
preprocessed_df=preprocessed_text(abs_text)
preprocessed_df
# Out:
#                                             nltk_tokens  \
# 0     [The, purpose, present, invention, provide, re...
# 1     [A, battery, pack, including, least, one, batt...
# 2     [A, quaternary, ammonium, compound, reaction, ...
# 3     [A, washing, machine, comprises, outer, tub, i...
# 4     [The, present, invention, relates, ceiling, ty...
# ...                                                 ...
# 1995  [A, control, method, includes, establishing, c...
# 1996  [A, numerical, controller, capable, determinin...
# 1997  [A, magnetic, resonance, apparatus, provided, ...
# 1998  [A, fluidconveying, device, conveying, fluid, ...
# 1999  [The, present, disclosure, provides, method, t...
#
#                                                   nouns  \
# 0     [invention, resin, balance, variety, property,...
# 1     [battery, pack, battery, cell, pack, case, bat...
# 2     [ammonium, compound, reaction, product, amine,...
# 3     [machine, comprises, inner, tub, mean, rotor, ...
# 4     [invention, ceiling, type, air, conditioner, h...
# ...                                                 ...
# 1995  [control, method, connection, device, device, ...
# 1996  [controller, input, value, operator, range, li...
# 1997  [resonance, apparatus, resonance, apparatus, p...
# 1998  [device, tank, pump, swirl, pot, pump, drive, ...
# 1999  [disclosure, wound, method, compound, inhibits...
#
#                                          lemmatize_text
# 0     The purpose present invention provide resin ex...
# 1     A battery pack including least one battery cel...
# 2     A quaternary ammonium compound reaction produc...
# 3     A washing machine comprises outer tub inner tu...
# 4     The present invention relates ceiling type air...
# ...                                                 ...
# 1995  A control method includes establishing connect...
# 1996  A numerical controller capable determining whe...
# 1997  A magnetic resonance apparatus provided The ma...
# 1998  A fluidconveying device conveying fluid tank i...
# 1999  The present disclosure provides method treatin...
#
# [2000 rows x 3 columns]

# %%
## Testing

###########nltk########################


#######################################Steps to convert : Document->Sentences->Tokens->POS->Lemmas

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet


class text_tokenizer(object):
    """
    split the document into sentences and tokenize each sentence
    """
    def __init__(self):
        self.splitter  =  nltk.WordPunctTokenizer()
        self.tokenizer = nltk.tokenize.TreebankWordTokenizer()

    def split(self,text):
        # split into single sentence
        sentences = self.splitter.tokenize(text)
        # tokenization in each sentences
        tokens = [self.tokenizer.tokenize(sent) for sent in sentences]
        return tokens

class text_cleaner(object):
    def __init__(self):
        self.lemmatizer = WordNetLemmatizer()
        
    def stopword_removal(self,text):
        cleaned_txt = ' '.join([token for token in word_tokenize(token) if token not in stop_words])
    def lemmatize_tokens(self,text):
        cleaned_txt=' '.join([self.lemmatizer.lemmatize(token) for token in word_tokenize(text)])



class LemmatizationWithPOSTagger(object):
    def __init__(self):
        pass
    def get_wordnet_pos(self,treebank_tag):
        """
        return WORDNET POS compliance to WORDENT lemmatization (a,n,r,v) 
        """
        if treebank_tag.startswith('J'):
            return wordnet.ADJ
        elif treebank_tag.startswith('V'):
            return wordnet.VERB
        elif treebank_tag.startswith('N'):
            return wordnet.NOUN
        elif treebank_tag.startswith('R'):
            return wordnet.ADV
        else:
            # As default pos in lemmatization is Noun
            return wordnet.NOUN

    def pos_tag(self,tokens):
        # find the pos tagginf for each tokens [('What', 'WP'), ('can', 'MD'), ('I', 'PRP') ....
        pos_tokens = [nltk.pos_tag(token) for token in tokens]

        # lemmatization using pos tagg   
        # convert into feature set of [('What', 'What', ['WP']), ('can', 'can', ['MD']), ... ie [original WORD, Lemmatized word, POS tag]
        pos_tokens = [[(word, lemmatizer.lemmatize(word,self.get_wordnet_pos(pos_tag)), [pos_tag]) for (word,pos_tag) in pos] for pos in pos_tokens]
        return pos_tokens

    
lemmatizer = WordNetLemmatizer()
text_tokenizer = text_tokenizer()
lemmatization_using_pos_tagger = LemmatizationWithPOSTagger()

#step 1 split document into sentence followed by tokenization
tokens = text_tokenizer.split(text)

#step 2 lemmatization using pos tagger 
lemma_pos_token = lemmatization_using_pos_tagger.pos_tag(tokens)
print(lemma_pos_token)



# #####Text blob############    
# from textblob import TextBlob

# sent = TextBlob(sentence)
# " ". join([w.lemmatize() for w in sent.words])

# ##########################

# def lemmatize_with_postag(sentence):
#     sent = TextBlob(sentence)
#     tag_dict = {"J": 'a', 
#                 "N": 'n', 
#                 "V": 'v', 
#                 "R": 'r'}
#     words_and_tags = [(w, tag_dict.get(pos[0], 'n')) for w, pos in sent.tags]    
#     lemmatized_list = [wd.lemmatize(tag) for wd, tag in words_and_tags]
#     return " ".join(lemmatized_list)

# %% [markdown]
# ## Keyword Extractor Library Based Approach

# %%
def gensim_keyword_extractor(text):
    """Here text as input keywords is module from gensim.summarization """
    print(keywords(text,words = 8))

doc0=abs_clean_text[0]
gensim_keyword_extractor(doc0)

# %%
def spacy_keyword_extractor(text):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    print(doc)
    nouns = set()
#     noun_phrases = set(chunk.text.strip().lower() for chunk in doc.noun_chunks)
    for token in doc:
        if token.pos_ == "NOUN":
            nouns.add(token.text)
#     all_nouns = nouns.union(noun_phrases)
#     print(nouns)
    return list(nouns)
#     print(all_nouns)

#     candidates = list(filter(lambda candidate: candidate in all_nouns, all_candidates))
#     return candidates[:20]
spacy_keyword_extractor(doc0)

# %% [markdown]
# ## Pretrained Embeddings and Model
# ### 1) BiowordVec Trained and Pretrained
# ### 2) Glove
# ### 3) Sentence Transformer
# ### 4) BlueBERT Model

# %% [markdown]
# ## BiowordVec Trained

# %%
vec_path='pubmed_mesh_test.wv.vectors_ngrams.npy'
bin_path='pubmed_mesh_test.bin'
test_path='pubmed_mesh_test'
word_model=KeyedVectors.load_word2vec_format(bin_path,binary=True)
# test_model=KeyedVectors.load_word2vec_format(test_path)

# %%
disambiguation_words=['patients','patient']
most_similar_patients=word_model.most_similar('patients',topn=10)
most_similar_patient=word_model.most_similar('patient',topn=10)
print('patients:',most_similar_patients,'\n','patient:',most_similar_patient)

# stats.zscore(most_similar_patients)
# Out:
# patients: [('nonpatients', 0.8853691220283508), ('inpatients', 0.8622636198997498), ('patient', 0.8075956106185913), ('whom', 0.7961167693138123), ('subjects', 0.7958483695983887), ('outpatients', 0.7919209599494934), ('children', 0.7650102376937866), ('cases', 0.7648932337760925), ('individuals', 0.733061671257019), ('who', 0.7279455661773682)]
#  patient: [('inpatient', 0.8259785771369934), ('patients', 0.8075956106185913), ('whom', 0.7504878044128418), ('outpatient', 0.7308553457260132), ('nonpatients', 0.7290786504745483), ('boy', 0.7279731035232544), ('case', 0.7218676805496216), ('inpatients', 0.7181251645088196), ('who', 0.7089853286743164), ('withheld', 0.7009677290916443)]

# %%
most_similar_patients=word_model.most_similar_cosmul(['blood','pressure'],topn=10)
print('Blood Pressure:\n',most_similar_patients)
print('glycogen:\n',word_model.most_similar('glycogen',topn=10))
# print(word_model.most_similar('glycosidic'))

# word_model.most_similar('n-acetylneuraminic')
# list=word_model.most_similar_cosmul(['eye','diabetes'])
# word_model.most_similar_cosmul(['cancer','lung'])
# word_model.most_similar_cosmul(['organ','ligament'])
# Out:
# Blood Pressure:
#  [('rcbf', 0.782541036605835), ('pressures', 0.7733681201934814), ('rbf', 0.7583125829696655), ('cbf', 0.7578179240226746), ('bloodflow', 0.7540532350540161), ('flow', 0.7476402521133423), ('mbf', 0.7328212261199951), ('pressurized', 0.731748104095459), ('arterial', 0.7188305854797363), ('low-pressure', 0.715316116809845)]
# glycogen:
#  [('glycogenic', 0.8793429136276245), ('glycogenolysis', 0.8574715852737427), ('glycogenolytic', 0.8442074060440063), ('glycogenosis', 0.8203446865081787), ('glycogenesis', 0.7889986634254456), ('glycogen-depletion', 0.774672269821167), ('glycogen-phosphorylase', 0.758968710899353), ('glucan', 0.7334698438644409), ('hexose', 0.7278242111206055), ('glucose', 0.723128080368042)]

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.vocab.keys()), sample)
        else:
            words = [ word for word in model.vocab ]
        
    word_vectors = np.array([model[w] for w in words])

    twodim = PCA().fit_transform(word_vectors)[:,:2]
    
    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)
# display_pca_scatterplot(word_model,['glycosidic','n-acetylneuraminic','patients','glycogen'])

# %% [markdown]
# ## BiowordVec Pretrained
# ### Intrinsic task

# %%
# # !pip install sent2vec
# import sent2vec
import math
path='/ML_projects/NLP_pipeline/pretrain_model/bio_embedding_intrinsic.bin'
Bioword_intrinsic_model=KeyedVectors.load_word2vec_format(path,binary=True)
Bioword_intrinsic_model.word_vec('deltaproteobacterial')

# %%
def get_dist(word1, word2):
    print(word1, word2)
    v1 = Bioword_intrinsic_model.get_vector(word1)
    v2 = Bioword_intrinsic_model.get_vector(word2)
    err = ((v1 - v2) ** 2).sum()
    return math.sqrt(err)


print(get_dist('biomedical', 'medical'))
print(get_dist('biomedical', 'biological'))
print(get_dist('biomedical', 'biomechanical'))
# Out:
# biomedical medical
# 3.2407716164303895
# biomedical biological
# 2.9746289318341024
# biomedical biomechanical
# 4.23327487294439

# %% [markdown]
# ## Glove

# %%
embeddings_dict = {}
with open("V:/ML_projects/pretrain_vectors/glove.6B.100d.txt", 'r',encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector
def find_closest_embeddings(embedding):
    return sorted(embeddings_dict.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding))

# find_closest_embeddings(embeddings_dict["acetyl"])

# %% [markdown]
# # Sentence Transformer
#
# https://www.sbert.net/ \
# https://www.sbert.net/examples/applications/paraphrase-mining/README.html

# %%
# !pip install -U sentence-transformers

# %%
import numpy as np
import itertools
from sklearn.metrics.pairwise import cosine_similarity
from typing import List, Tuple
import nltk
from nltk.corpus import stopwords
# from nltk.tokenize import sentence
from sklearn.feature_extraction.text import TfidfVectorizer


from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("paraphrase-MiniLM-L6-v2")

# %% [markdown]
# ## Keyword Extraction And Redundant Keywords Removal

# %% [markdown]
# ### Maximal Margin Relevancy

# %%
def mmr(doc_embedding: np.ndarray,word_embeddings: np.ndarray,words,top_n,diversity):
    # Extract similarity within words, and between words and the document
    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)
    
    # Initialize candidates and already choose best keyword/keyphras
    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]
    
    for _ in range(top_n - 1):
        # Extract similarities within candidates and
        # between candidates and selected keywords/phrases
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # Calculate MMR
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # Update keywords & candidates
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)
            
    return [(words[idx], round((word_doc_similarity.reshape(1, -1)[0][idx]), 4)) for idx in keywords_idx]

# %% [markdown]
# ### Count Vectorizer and MMR

# %%
doc=abs_clean_text[0]
print(doc)

count = CountVectorizer(ngram_range=(1,1), stop_words=stop_words, min_df=1).fit([doc])
words = count.get_feature_names()
print(words)
top_n:int=10
diversity:0.8
    
    
doc_embedding=embedding_model.encode([doc])
word_embedding=embedding_model.encode(words)
keywords = mmr(doc_embedding, word_embedding, words,top_n,diversity)
print(keywords)
# Out:
# The purpose of the present invention is to provide a resin that has an excellent balance of a variety of properties, such as optical physical properties, heat resistance, mechanical properties, and heat stability, and to provide an optical film and a phase-difference film that are obtained using the resin. The present invention relates to a polycondensation resin that has a repeating structural unit that includes an aromatic structure, the resin being characterized by having a structural unit and by the content of the aromatic structure in the repeating structural unit satisfying formula (I). (I) 5 less than or equal to A less than or equal to -22.5·B+38.3, wherein 0.75 less than or equal to B less than or equal to 0.93, A is the content (in mass percent) of the aromatic structure in the repeating structural unit that constitutes the resin, and B is the ratio (R450/R550) of the phase difference (R450) at 450 nm and the phase difference (R550) at 550 nm of a stretched film that is produced from the resin.
# ['22', '38', '450', '550', '75', '93', 'aromatic', 'balance', 'characterized', 'constitutes', 'content', 'difference', 'equal', 'excellent', 'film', 'formula', 'heat', 'includes', 'invention', 'less', 'mass', 'mechanical', 'nm', 'obtained', 'optical', 'percent', 'phase', 'physical', 'polycondensation', 'present', 'produced', 'properties', 'provide', 'purpose', 'r450', 'r550', 'ratio', 'relates', 'repeating', 'resin', 'resistance', 'satisfying', 'stability', 'stretched', 'structural', 'structure', 'unit', 'using', 'variety', 'wherein']

# %% [markdown]
# ## COVID Abstracts

# %%
list_of_doc=['Impact of COVID-19 on Lung Allograft and Clinical Outcomes in Lung Transplant Recipients: A Case-Control Study.','Integrated analysis of multimodal single-cell data.','SARS-Cov-2 viral and serological screening of staff in 31 European fertility units.','Impact of COVID-19 on cancer care in India: a cohort study.','SARS-CoV-2 vaccines for all but a single dose for COVID-19 survivors.','Associations of baseline use of biologic or targeted synthetic DMARDs with COVID-19 severity in rheumatoid arthritis: Results from the COVID-19 Global Rheumatology Alliance physician registry.','COVID-19 Vaccine Acceptance Among Pregnant, Breastfeeding and Non-pregnant Reproductive Aged Women.','Changes in the incidence of invasive disease due to Streptococcus pneumoniae, Haemophilus influenzae, and Neisseria meningitidis during the COVID-19 pandemic in 26 countries and territories in the Invasive Respiratory Infection Surveillance Initiative: a prospective analysis of surveillance data.','Seroprevalence of SARS-CoV-2 antibodies in Seattle, Washington: October 2019-April 2020.','Cancer and SARS-CoV-2 Infection: A Third-Level Hospital Experience.','Differential association between inflammatory cytokines and multiorgan dysfunction in COVID-19 patients with obesity.','Urgent needs to accelerate the race for COVID-19 therapeutics.','Management of IBD Patients During the COVID-19 Pandemic.','Rapid disappearance of influenza following the implementation of COVID-19 mitigation measures in Hamilton, Ontario.','A novel strategy for SARS-CoV-2 mass screening with quantitative antigen testing of saliva: a diagnostic accuracy study.','COMMUNITY-BASED PREVALENCE ESTIMATES OF CHLAMYDIA TRACHOMATIS AND NEISSERIA GONORRHOEAE INFECTIONS AMONG GAY, BISEXUAL AND OTHER MEN WHO HAVE SEX WITH MEN IN MONTRÃ‰AL, CANADA.','Factors indicating intention to vaccinate with a COVID-19 vaccine among older U.S. adults.']
doc1=''.join([i for i in list_of_doc])
# print(doc1)

stop_words=stopwords.words('english')
count = CountVectorizer(ngram_range=(1,1),tokenizer=word_tokenize,stop_words=stop_words, min_df=1).fit([doc1])
words = count.get_feature_names()
print(words)


top_n:int=10
diversity:0.8
doc_embedding=embedding_model.encode([doc1])
# print(doc_embedding)
word_embedding=embedding_model.encode(words)
keywords = mmr(doc_embedding, word_embedding, words,top_n,diversity)
print(keywords)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:382: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# [',', '.', '2019-april', '2020.cancer', '26', '31', ':', 'accelerate', 'acceptance', 'accuracy', 'adults', 'aged', 'alliance', 'allograft', 'among', 'analysis', 'antibodies', 'antigen', 'arthritis', 'association', 'baseline', 'biologic', 'bisexual', 'breastfeeding', 'canada.factors', 'cancer', 'care', 'case-control', 'chlamydia', 'clinical', 'cohort', 'countries', 'covid-19', 'cytokines', 'data.sars-cov-2', 'data.seroprevalence', 'diagnostic', 'disappearance', 'disease', 'dmards', 'dose', 'due', 'dysfunction', 'estimates', 'european', 'experience.differential', 'fertility', 'following', 'gay', 'global', 'gonorrhoeae', 'haemophilus', 'hamilton', 'hospital', 'ibd', 'impact', 'implementation', 'incidence', 'india', 'indicating', 'infection', 'infections', 'inflammatory', 'influenza', 'influenzae', 'initiative', 'intention', 'invasive', 'lung', 'mass', 'measures', 'men', 'meningitidis', 'mitigation', 'montrã‰al', 'multimodal', 'multiorgan', 'needs', 'neisseria', 'non-pregnant', 'novel', 'obesity.urgent', 'october', 'older', 'ontario.a', 'outcomes', 'pandemic', 'pandemic.rapid', 'patients', 'physician', 'pneumoniae', 'pregnant', 'prevalence', 'prospective', 'quantitative', 'race', 'recipients', 'registry.covid-19', 'reproductive', 'respiratory', 'results', 'rheumatoid', 'rheumatology', 'saliva', 'sars-cov-2', 'screening', 'seattle', 'serological', 'severity', 'sex', 'single', 'single-cell', 'staff', 'strategy', 'streptococcus', 'study.community-based', 'study.integrated', 'study.sars-cov-2', 'surveillance', 'survivors.associations', 'synthetic', 'targeted', 'territories', 'testing', 'therapeutics.management', 'third-level', 'trachomatis', 'transplant', 'u.s.', 'units.impact', 'use', 'vaccinate', 'vaccine', 'vaccines', 'viral', 'washington', 'women.changes']
# [('registry.covid-19', 0.4663), ('lung', 0.3886), ('vaccine', 0.3688), ('study.sars-cov-2', 0.3883), ('cohort', 0.2697), ('therapeutics.management', 0.2724), ('2020.cancer', 0.2984), ('countries', 0.1908), ('chlamydia', 0.1302), ('allograft', 0.2433)]

# %% [markdown]
# ### TFIDF and MMR

# %%
doc=abs_clean_text[0]
# print(doc)
stop_words=stopwords.words('english')
count = TfidfVectorizer(ngram_range=(1,2), tokenizer=word_tokenize,stop_words=stop_words, min_df=1).fit([doc])
tf_idf_words = count.get_feature_names()
# print(tf_idf_words)
top_n:int=10
diversity:0.8
doc_embedding=embedding_model.encode([doc])
# print(doc_embedding)
word_embedding=embedding_model.encode(tf_idf_words)
keywords = mmr(doc_embedding, word_embedding,tf_idf_words,top_n,diversity)
print(keywords)


# print(doc1)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:382: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# [('constitutes resin', 0.5967), ('balance', 0.132), ('nm phase', 0.1443), ('polycondensation', 0.337), ('film', 0.2241), ('heat resistance', 0.2212), ('unit includes', 0.2223), ('purpose present', 0.322), ('variety properties', 0.2898), ('provide optical', 0.2177)]

# %%
list_of_doc=['Impact of COVID-19 on Lung Allograft and Clinical Outcomes in Lung Transplant Recipients: A Case-Control Study.','Integrated analysis of multimodal single-cell data.','SARS-Cov-2 viral and serological screening of staff in 31 European fertility units.','Impact of COVID-19 on cancer care in India: a cohort study.','SARS-CoV-2 vaccines for all but a single dose for COVID-19 survivors.','Associations of baseline use of biologic or targeted synthetic DMARDs with COVID-19 severity in rheumatoid arthritis: Results from the COVID-19 Global Rheumatology Alliance physician registry.','COVID-19 Vaccine Acceptance Among Pregnant, Breastfeeding and Non-pregnant Reproductive Aged Women.','Changes in the incidence of invasive disease due to Streptococcus pneumoniae, Haemophilus influenzae, and Neisseria meningitidis during the COVID-19 pandemic in 26 countries and territories in the Invasive Respiratory Infection Surveillance Initiative: a prospective analysis of surveillance data.','Seroprevalence of SARS-CoV-2 antibodies in Seattle, Washington: October 2019-April 2020.','Cancer and SARS-CoV-2 Infection: A Third-Level Hospital Experience.','Differential association between inflammatory cytokines and multiorgan dysfunction in COVID-19 patients with obesity.','Urgent needs to accelerate the race for COVID-19 therapeutics.','Management of IBD Patients During the COVID-19 Pandemic.','Rapid disappearance of influenza following the implementation of COVID-19 mitigation measures in Hamilton, Ontario.','A novel strategy for SARS-CoV-2 mass screening with quantitative antigen testing of saliva: a diagnostic accuracy study.','COMMUNITY-BASED PREVALENCE ESTIMATES OF CHLAMYDIA TRACHOMATIS AND NEISSERIA GONORRHOEAE INFECTIONS AMONG GAY, BISEXUAL AND OTHER MEN WHO HAVE SEX WITH MEN IN MONTRÃ‰AL, CANADA.','Factors indicating intention to vaccinate with a COVID-19 vaccine among older U.S. adults.']
doc1=''.join([i for i in list_of_doc])


stop_words=stopwords.words('english')
tfidf_count = TfidfVectorizer(ngram_range=(1,1), tokenizer=word_tokenize,stop_words=stop_words, min_df=1).fit([doc1])
tf_idf_words1 = tfidf_count.get_feature_names()

top_n:int=10
diversity=0.8
doc_embedding1=embedding_model.encode([doc1])
word_embedding1=embedding_model.encode(tf_idf_words1)


keywords = mmr(doc_embedding1, word_embedding1,tf_idf_words1,top_n,diversity)

print(tf_idf_words1)

print(keywords)
# Out:
# [',', '.', '2019-april', '2020.cancer', '26', '31', ':', 'accelerate', 'acceptance', 'accuracy', 'adults', 'aged', 'alliance', 'allograft', 'among', 'analysis', 'antibodies', 'antigen', 'arthritis', 'association', 'baseline', 'biologic', 'bisexual', 'breastfeeding', 'canada.factors', 'cancer', 'care', 'case-control', 'chlamydia', 'clinical', 'cohort', 'countries', 'covid-19', 'cytokines', 'data.sars-cov-2', 'data.seroprevalence', 'diagnostic', 'disappearance', 'disease', 'dmards', 'dose', 'due', 'dysfunction', 'estimates', 'european', 'experience.differential', 'fertility', 'following', 'gay', 'global', 'gonorrhoeae', 'haemophilus', 'hamilton', 'hospital', 'ibd', 'impact', 'implementation', 'incidence', 'india', 'indicating', 'infection', 'infections', 'inflammatory', 'influenza', 'influenzae', 'initiative', 'intention', 'invasive', 'lung', 'mass', 'measures', 'men', 'meningitidis', 'mitigation', 'montrã‰al', 'multimodal', 'multiorgan', 'needs', 'neisseria', 'non-pregnant', 'novel', 'obesity.urgent', 'october', 'older', 'ontario.a', 'outcomes', 'pandemic', 'pandemic.rapid', 'patients', 'physician', 'pneumoniae', 'pregnant', 'prevalence', 'prospective', 'quantitative', 'race', 'recipients', 'registry.covid-19', 'reproductive', 'respiratory', 'results', 'rheumatoid', 'rheumatology', 'saliva', 'sars-cov-2', 'screening', 'seattle', 'serological', 'severity', 'sex', 'single', 'single-cell', 'staff', 'strategy', 'streptococcus', 'study.community-based', 'study.integrated', 'study.sars-cov-2', 'surveillance', 'survivors.associations', 'synthetic', 'targeted', 'territories', 'testing', 'therapeutics.management', 'third-level', 'trachomatis', 'transplant', 'u.s.', 'units.impact', 'use', 'vaccinate', 'vaccine', 'vaccines', 'viral', 'washington', 'women.changes']
# [('registry.covid-19', 0.4663), ('lung', 0.3886), ('race', 0.0134), ('mitigation', 0.1883), ('adults', 0.1693), ('vaccine', 0.3688), ('montrã‰al', -0.0363), ('multimodal', 0.1349), ('gonorrhoeae', 0.0707), ('countries', 0.1908)]

# %% [markdown]
# # 2k Patent Abstract

# %%
docs=preprocessed_df['lemmatize_text']
print(docs)
Nouns_docs=pre_pat_abs_df['nouns'].apply(lambda x:' '.join(x))
# Out:
# 0       The purpose present invention provide resin ex...
# 1       A battery pack including least one battery cel...
# 2       A quaternary ammonium compound reaction produc...
# 3       A washing machine comprises outer tub inner tu...
# 4       The present invention relates ceiling type air...
#                               ...
# 1995    A control method includes establishing connect...
# 1996    A numerical controller capable determining whe...
# 1997    A magnetic resonance apparatus provided The ma...
# 1998    A fluidconveying device conveying fluid tank i...
# 1999    The present disclosure provides method treatin...
# Name: lemmatize_text, Length: 2000, dtype: object

# %%
Nouns_docs
# Out:
# 0       invention resin ha balance variety property pr...
# 1       battery pack battery cell pack case battery ce...
# 2       ammonium compound reaction product amine weigh...
# 3       machine comprises inner tub mean rotor stator ...
# 4       invention ceiling type air conditioner harness...
#                               ...
# 1995    control method connection device device connec...
# 1996    controller input value operator range limit va...
# 1997    resonance apparatus resonance apparatus proces...
# 1998    device tank pump swirl pot pump drive region r...
# 1999      disclosure wound method compound inhibits VEGFB
# Name: nouns, Length: 2000, dtype: object

# %% [markdown]
# ## TF-IDF

# %%
# count = TfidfVectorizer(ngram_range=(1,1), tokenizer=word_tokenize,stop_words=stop_words, min_df=1).fit(docs)
# tf_idf_words = count.get_feature_names()
# print(len(tf_idf_words))
# lemmatize_tfidf_tokens=[]
# for i in tf_idf_words:  
#     lemmatize_tfidf_tokens.append(lemmatizer.lemmatize(i))
# print(len(lemmatize_tfidf_tokens))

# unique_tfidf_tokens=set(lemmatize_tfidf_tokens)
# print(len(unique_tfidf_tokens))

# pos_tokens=nltk.pos_tag(unique_tfidf_tokens)
# Noun_tfidf_tokens=[pos_token for pos_token,pos in pos_tokens if pos.startswith('N')]
# len(Noun_tfidf_tokens)

# doc_embedding=embedding_model.encode(docs)
# word_embedding=embedding_model.encode(Noun_tfidf_tokens)
# df=count.transform(Noun_tfidf_tokens)
# top_n:int=10
# diversity:0.8
# import tqdm
# docs=pre_pat_abs_df['nltk_lematize']
# keywords=[]
# for index, doc in enumerate(docs):
#             doc_words = [Noun_tfidf_tokens[i] for i in df[index].nonzero()[1]]
#             if doc_words:
#                 doc_word_embeddings = np.array([word_embeddings[i] for i in df[index].nonzero()[1]])
#                 distances = cosine_similarity([doc_embeddings[index]], doc_word_embeddings)[0]
#                 doc_keywords = [(doc_words[i], round(float(distances[i]), 4)) for i in distances.argsort()[-top_n:]]
#                 keywords.append(doc_keywords)
# print(keywords)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:382: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# 13195

# %% [markdown]
# ## Count Vectorizer and MMR

# %%
countvec = CountVectorizer(ngram_range=(1,1), stop_words=stop_words, min_df=1).fit(docs)
words = countvec.get_feature_names()
df = countvec.transform(docs)
cv_doc_embeddings = embedding_model.encode(docs)
cv_word_embeddings =embedding_model.encode(words)

# %%
top_n:int=10
diversity:0.8
phrases=[]
docs=pre_pat_abs_df['nltk_lematize']
keywords=[]
for index, doc in enumerate(docs):
            doc_words = [words[i] for i in df[index].nonzero()[1]]
            if doc_words:
                doc_word_embeddings = np.array([cv_word_embeddings[i] for i in df[index].nonzero()[1]])
                distances = cosine_similarity([cv_doc_embeddings[index]], doc_word_embeddings)[0]
                doc_keywords = [(doc_words[i], round(float(distances[i]), 4)) for i in distances.argsort()[-top_n:]]
                keywords.append(doc_keywords)
# print(keywords)
for keyword in keywords:
    phrase=' '.join([key[0] for key in keyword])
    phrases.append(phrase)    
phrases
# Out:
# ['resistance invention structure phase polycondensation property mechanical aromatic structural resin',
#  'outer temperature unit closing hole flow meter pack cooling battery',
#  'substituted atom molecular ammonium alkylating reaction compound carbon acidactivated amine',
#  'dehydration rotate stator driving drive pulsator rotor tub washing machine',
#  'unit connected invention lifted lifting air attached device harness ceiling',
#  'supply battery separate separation air disposed motor suction dust cleaner',
#  'fluid comprises control start pipe driving assembly cylinder piston invention',
#  'pressurized plasticizing plasticization molten starvation thermoplastic molding starved foaming foammolded',
#  'optically film interface gate photoresponsive device charge electrode insulation semiconductor',
#  'retaining direction rod fluid floating tube piston guide slider cylinder',
#  'detects inclination controller detecting control angle sensor motorized wheel wheelchair',
#  'nacetyllcysteine food precursor cell differentiation stem pharmaceutical proliferation zinc neurogenesis',
#  'transmits access recommended book treatment method process reading read reader',
#  'surround center throughhole terminal exterior cylindrical tube outer connector highvoltage',
#  'first pattern apparatus detect direction moire grating invention detection diffraction',
#  'substance peeling apparatus peelingoff test process electrical cleaning probe inspection',
#  'control power supplied resistance controller temperature heat aerosolgenerating aerosol heater',
#  'peripheral chamber drive inner annular groove pressure casing piston actuator',
#  'application sliding flexible arm mobile rotation shaft rotate rotary swing',
#  'decoding coding reference current method unit decode memory block ctu',
#  'uplink snr communication access downlink network random transmit transmitting transmission',
#  'step onetouch accepting invention service request customer product regular delivery',
#  'substituted method adjusting ph liquid metal substrate react rinsing gas',
#  'cooling draining product purified purifying liquid oxygen argon adsorbent adsorption',
#  'user installed accommodation provided invention display device customized box settop',
#  'covering method fabricating forming surface insulating etching semiconductor substrate layer',
#  'initiating control exhaust opening gas opened pressure pump valve vacuum',
#  'external thermally tape internal surface rechargeable assembly battery electrode lithium',
#  'path leakage outer housing component mounted sensing pressure gasket sensor',
#  'structure cover folded formed folding surface forming rubber mold hinge',
#  'inorganic treatment used substance zr rinse metal reaction coating electrodeposition',
#  'solid deposition polyisocyanate extender fused polyol shear fabrication polyurethane thermoplastic',
#  'conjugate residue cysteine haptenconjugation disulfide haptenylated polypeptide toxin antibody antihapten',
#  'group represents independently represent rs atom integer monovalent hydrocarbon carbon',
#  'request mbmsgw multicast radio transmitting service broadcast mbmsgateway broadcastmulticast bmsc',
#  'carbon source producing recombinant catalyzes disclosure microorganism enzyme amine fatty',
#  'splitter refraction light invention diffraction propagation pixel modulated modulation modulator',
#  'esterification composition invention alkanesulphonic carbon solvent catalyst acid acidand hydrocarbon',
#  'channel sttibased invention vehicletox wireless stti communication vx ltti transmission',
#  'transmit power unit charging layer emitting cell lighting light solar',
#  'schedule application method parallel system server core slice gaming processing',
#  'substrate insulation irradiating surface patternsolution irradiation layer wavelengthselected photolithography coating',
#  'actuator peripheral hold sandwich surface plateshaped member portion hand substrate',
#  'determining prediction block mode transform method video coding decoding decode',
#  'cache layer processed stack application component identifier processing priority context',
#  'wrinkle sagging reducing reduce aging itchiness dryness thinning topically skin',
#  'controlling fluid position axially positioned coaxially control flange distal tubular',
#  'sucking body module invention air moving dust cleaning cleaner robot',
#  'mutant pharmaceutical cell il invention polynucleotide polypeptide interleukin immunotherapeutic immunoconjugates',
#  'convolutional detection network face cascaded embodiment subimages subimagebased embodiments cnn',
#  'unsaturated formula tgf beta used inhibitor benzotriazolederived salt compound pharmaceutically',
#  'connected structure component carrier first electrically layer conductive interconnect semiconductor',
#  'enclosure component assembling sheet ship superstructure decksheet deck welding bulkhead',
#  'blurring neural processing processed method training trained sharpening sharpeningprocessing bicyclegan',
#  'surface movable pouring microstructure invention covering molding microwave curing concrete',
#  'device lifting system lift grid storage wheel vehicle container containerhandling',
#  'control card controlled automatically device automatic invention automation testing smart',
#  'bar vertical machine inclined mechanism shuttle path movement moved drive',
#  'reaction ester nacetylchlorolserine methyl preparation hydrochloric hydroselenide nacetylselenium methyllselenocysteine lsemethylselenocysteine',
#  'protein treating vascular rna treatment viral vegf compounds inhibit inhibiting',
#  'data server calling discloses api call dataitems device request method',
#  'second objectside fifth third fourth imageside imaging refractive optical lens',
#  'heating impregnation barrel invention vacuum product vacuumizing preparation impregnatingvacuum carbongraphite',
#  'deploying method methods obtaining tangible storage request digital asset blockchain',
#  'alkyl positron phosphorylated drug preparation invention alkoxy compound tau isoquinoline',
#  'generated access uplink random process message method ta transmitting transmission',
#  'terminal problem test tested error electric temperature meter alarm outoflimit',
#  'pulse expanded vaporized highpressure liquid tube expansion valve steam compressor',
#  'current application gain brightness interest adjusting image adjust exposure imaging',
#  'connected voltage substrate phase transmission crystal wire electrode terahertz dielectric',
#  'concrete stirring assembly protective method safety feeding mechanism separation pot',
#  'good improvement quality improved performance feed goat production cornu milk',
#  'nacelle reverse system cascade gas axial reverser engine turbine thrust',
#  'control system refrigerator conveying superconductive tank refrigeration lng pump pipeline',
#  'adjustable mountainous mechanism road braking safety extruding device wheel transporting',
#  'structure electric second polar conductive core ferrous coil magnetically magnetic',
#  'audio determining method acquisition collecting video discloses segmentation processing data',
#  'driven invention driving hybrid wheel piston vehicle generator motor engine',
#  'technical printed materialsare fixing box printing material equipment rotary packaging',
#  'coated angle difference wavelength phase refractive layer coating concaveconvex optical',
#  'oxidant halogenation electrochemical oxyhalogenation electrochemically halogenating oxyhalogenating oxidizing halide oxidation',
#  'problem heat airoutlet invention working method equipment air electronic secondbody',
#  'invention cutter gelatin machine piston cylinder belt donkeyhide antisticking conveying',
#  'obtaining obtained mean suspension car overtravel method elongation invention elevator',
#  'heating softening melt pressuresensitivefree lubricant ointment material packaging thermoplastic adhesive',
#  'technical compatibility interface capability obtains application network method transmission access',
#  'voltage chip communication commonmode isolation rs transceiver circuitso circuit rsslave',
#  'stearate densitypolyethylene silane material singlewall reinforced pipe corrugated polyethylene polypropylene',
#  'rotation connected screen surface sliding slide display second electronic device',
#  'lowcarbon diethylferroene distilling ferrocene solvent boiling ethylferrocene distillation steam steamdistillation',
#  'regenerated fabric woven dyeing knitted fiber cellulosefiber textile pulp cellulose',
#  'tracking device voice gesture optical perception technology sound reality virtual',
#  'receives server collect route discloses acquisition find process method terminal',
#  'invention spring wire motor electric electrical electrically sensor temperature battery',
#  'method ceramic formed firing carbidebased manufacture manufacturing silicon furnace honeycomb',
#  'haliotidis paste fleeceflower chrysanthemum ligustici milkvetch herb antihypertensive prepared medicine',
#  'positionframe rotating rod plate bearing board wheel machine mounted mounting',
#  'cylindrical apparatus sleeve axial rotor motion control bearing annular rotary',
#  'invention internal plate portion used material pressing container aluminum electrode',
#  'device receiving downlink sending resource method terminal application information communication',
#  'mechanism tower connected fire firefighting cable pipeline cablestayed pipe bridge',
#  'cutting roller discharging waste machining machine removing pipe grinding rust',
#  'aluminum method sulfoxide preparation reaction cosolvent trifluoromethanesulfonate catalyst ethoxymethylfurfural glucose',
#  'fluoride dried surface solvent trimethylsilane material highpolymer superomniphobic antiwear titanate',
#  'layer pump greening planting trees coating pipeline lighting tree pipe',
#  'segmentation electrically output enhancement invention signal image feature calculation circuit',
#  'method program voltage prepulse programming programmed verifying verification wordlines wordline',
#  'guaranteed multiresource discloses resistance technology block share verification resource copyright',
#  'storage tobedetected similarity discloses method device object image target detection',
#  'method feature lstm accuracy training algorithm learning neural predicting prediction',
#  'delivery system carrying controller building drive platform box residential storage',
#  'circuit supplied valve booster pressure plunger liquid pressurized discharge piston',
#  'phasechange refrigerate heat cooled cooling heating thermal charging battery lithium',
#  'mounted used motor sewage antiskidding shaft hydraulic invention cleaning snail',
#  'plate fixedly shaft fixed controlled folded compressing fold folding mask',
#  'oxide uhmwpe adsorbed drying material powder composite ultrasonic graphene polyethylene',
#  'rnp method prediction dme plan raim flight invention flightplan piloting',
#  'inserted placed plane method piece part invention steel robot welding',
#  'controller clamped terminalsand connected board interface mountingcan mounting wiring stove',
#  'thereof composition formula salt use invention manufacture compound pharmaceutically pharmaceutical',
#  'module connected interface transmitting signal function invention electronic device display',
#  'method reduction preparation compound treatment nonalcoholic fatty liver aminoarylbenzamide steatohepatitis',
#  'exciter display shellwherein conductor equipment vibrationsounding shell electronic vibration vibrationconductor',
#  'domain connection obtain invention applicability node method network theopportunistic opportunistic',
#  'turbine rotate control oil gearshifting gearbox bulldozer engine torque gearshiftingcontrol',
#  'material layer conduction plate winding conductive positivepole electrode battery lithium',
#  'inner sandwich outer disposed side chain roller seal bonded plate',
#  'method system information checksum attribution ipchecksum inquiry ip invention ipv',
#  'hexagonal nitrogendoped tungsten ionic oxide titanium hydrogencontaining graphene electrode lithium',
#  'engineered ligand immunodetection vaccine surface molecule antigennanobody antigen antibody nanobody',
#  'sediment sealing driving filteringstructure removing device filtering water filter sand',
#  'mounting layer safety seat sandbox hinge gravel seatmachining machining steel',
#  'load energy utilization device controller electric grid electricity power microgrid',
#  'combined determined output quantity method sensor measuring mixture correlation gas',
#  'selfrenewal proliferation stem tumor therapeutic cytokine activating glioma cancer lif',
#  'vector compressed communication channel beam precoding compression orthogonal matrix csi',
#  'unit bias electrically device amplified frequency voltage amplifying impedance amplifier',
#  'mounting communicator authentication photography vehicle photographic device aerial photographicdevice unmanned',
#  'hardness method pvc agent anchoring hardnesschange plasticizer extender polyurethane polyether',
#  'barrel anode roll motor equipment copper machine electric shaft electroplating',
#  'rod motor device arranged pull arrangedon transverse cloth curtaincloth curtain',
#  'equipment reinforced mold material mechanical resin molded steel molding composite',
#  'squeezing gear motor processing oil flattening hydraulic roller rolling equipment',
#  'cleaned seam invention groove rubber made shaft scraped glue roller',
#  'soc enable operate awakening invention powered power device ddrio ddr',
#  'instrument sampling camera technical sampled apparatus plate clinic blade device',
#  'layer composite oxide membrane polymerization polyacrylonitrile coating ultrafiltration graphene nanofiltration',
#  'method flushing device invention cleaning cleaned spray wafer nozzle silicon',
#  'administering agonist treating peptide pharmaceutical immunecheck antagonistic cxcr therapeutically antagonist',
#  'method prompt interface screen application display displaying processing message terminal',
#  'animal flavorant veterinary introduction used embodiment surfactant ingredient invention pharmaceutical',
#  'module ddrctrl iocomponentlink halldpd software sca ddr reconfiguration configuring fpga',
#  'likethe improving construction compatibilizer improved road invention adhesivity pavement asphalt',
#  'disposed platelike rotating vehicle side portion axle dust rotor brake',
#  'apparatus message node reliability determine program detecting system method methods',
#  'channel downlink access enb equipment systems communication synchronization transmission subframe',
#  'segment protruding arcuate arc pipe hole drainage bile tube gallbladder',
#  'determination evaluated replacing signal based evaluation map disclosure static identification',
#  'sends identification request subscribed scp domain uda subscriber false udr',
#  'joint carriage armsa rubbermetal mechanical attached wheelchair vehicle wheel arm',
#  'rotating apparatus bottle process pneumatically glass flap polished grinding polishing',
#  'fluid water mounting mechanism movable spindrying cleaned cleaning rotary pump',
#  'center provides data security application request storage access requester certificate',
#  'unsubstituted hydrogen indenocarbazole compound carbazole aromatic phenoxazinyl dibenzofuranbased diphenyl diphenylamine',
#  'utilizing hash request storing data collect transaction block chain distributed',
#  'glucoside byproduct leucine glycerin bifidobacterium glycerol tryptophan protein phosphorylase sucrose',
#  'material polyurethane moisture resin polymer moisturecured uv acrylate adhesion adhesive',
#  'monitoring analysis eyelid data eye system tracker emotion method recognition',
#  'obtaining method discloses information secondhardware electronicdevice electronic device embodiment invention',
#  'addition dissolve sheet polymercopolymer use cleaning water invention washing surfactant',
#  'second traveling control current rotating speed driving wheel motor vehicle',
#  'shop system fraud management automobile purchase risk marketing control dealer',
#  'flattened product invention production method producing flattening board cutting bamboo',
#  'key authenticating device attestation signature peer verifying certificate verification pcr',
#  'material wrapped wrapping alloy reinforced prestressed tendon composite alloycontinuous fiber',
#  'device target apparatus method information electronic technology embodiment embodiments invention',
#  'panel invention platform experimental experiment teaching device test technical equipment',
#  'deformation tensile extrusion machining material heatresistant mgznsnmnal mg alloy magnesium',
#  'set signal controller driver device drive machine fsm circuit led',
#  'mixture mixed enhancement speech mix speaker noise mixer microphone audio',
#  'screw overturningrod conveying groove countersunk shaft hydraulic vehicle cylinder wheel',
#  'andor treating limiting impairment preventing prevent pharmaceutical cdk hearing inhibitor',
#  'metallurgy hydrogen oxidatively catalyze peroxide ozone ozonecontaining oxidation catalytic catalyst',
#  'control assembly pdu priority access data protocol terminal mac transmission',
#  'computer system device data storage tobemigrateddata tobemigrated migration migrate migrating',
#  'query encoded encryption request querying digest cryptographic hashing blockchain blockchainbased',
#  'compound product film alkoxymethyl emission epoxy isocyanate resin photosensitive photoacid',
#  'drive assembly steel mounted shell window driving mountingarm mounting vehicle',
#  'position nonobtrusive handlestoring recess storage stored movable cleaner handle vacuum',
#  'technical silk device ceramic fabric material preparation electrochemical lithium electrolyte',
#  'slider plunger second fluidly fluid lumen orifice test syringe barrel',
#  'crack block pressing fixed strap sliding machine clamped drilling drill',
#  'relate network resource channel control information transmission transmits disclosure downlink',
#  'composite invention layer electrode preparing photoelectric strontium preparation solar silicon',
#  'pane bent mounted discharging thermal insulation bending glass furnace mounting',
#  'implementing implemented wireless creation device communicating propagation communication electronic invention',
#  'agonist fibrotic chemotherapeutic myelofibrosis serum administering treating disclosure therapeutic amyloid',
#  'invention process intelligence control intelligent system target shootingenvironment shoot shooting',
#  'inlet sample system gradient fluidically pumping flow chromatography pump valve',
#  'device driver driving slide rotate rotates seat sliding headrest automobile',
#  'diatomaceous solidification liquid litter soil absorption absorbance particulate mixture absorbency',
#  'conveying automatically box control cleaning clean device test tube cleaningbox',
#  'safe bottom side safety antitheft wall edge ring twistopen cap',
#  'damper moulded slid polishing traction mounting rod gear machining clutch',
#  'calculated performance time adjustment determination machine arrival optimum path vehicle',
#  'parallel system chamber flowing engine upstream heat exchanger valve inlet',
#  'methylation reduction hydrochloric reaction acidification acid thiocyanate azithromycin dichloromethane erythromycin',
#  'device surface conductive layerand layer metal manufacturing interconnection substrate silicon',
#  'invention preparation compounding electrolysis corrosion tungstate graphenebismuth graphene catalytic catalyst',
#  'initial vertex invention array assembling dereferencing method arrayssupporting attribute dereference',
#  'cost server device electronic idea invention dnsrequest attack dns ddos',
#  'steel connecting girder connector cantilever embedded trussed hanging anchor anchoring',
#  'bottomis backlight part bottom side device module panel shell display',
#  'hydraulic transportation lifting attached unloading cargo batten logistics conveyingbattens conveying',
#  'circular cone outer rubber device seal wire encapsulating coil sealant',
#  'technology ray detection emit light interferometer lens mirror etalon optical',
#  'iron magnetism plate mining crusher machinery block machine ore shaft',
#  'control numerical invention cylinder device mechanical machine tool mounting machining',
#  'sliding tester turbocharger forcesensor cylinder torque turbine shaft bearing thrust',
#  'nucleotide nucleic plant influenza proteolytic plantspecific virus protein protease hemagglutinin',
#  'computing logic execution hyperthread hyperthreaded specification blockchain processor processoras core',
#  'shift vehicle rotation motor spur drive gear traction shaft planetary',
#  'disclosed receiving method smart credential user authorized control system access',
#  'microbe recycling reaction biochemical waste carbon gas hydrolysis anaerobic reactor',
#  'ester acidmethyl dimethyl dichloromethane glutamate glutamic estertertbutyl triphenylmethyl triphenylmethylglutamic triphenylchloromethane',
#  'modulation iq algorithm radiofrequency interference software machine signal simulator radar',
#  'light system algorithm thirdparty method application equipment hardware electronic android',
#  'system functionally exemplary solving application describes approach functional label design',
#  'dirty access block system capacity data distributed storage cache cacheand',
#  'shutter converter engine display head device image projection hmd optical',
#  'tubing liquid diagnostics analyzer circuit tube circuity laboratory probe pca',
#  'factor change detects facility propagation diagnosis system area abnormality detection',
#  'preparation combination invention canproduce nfib use cosmetic cisplatin antibody therapeutic',
#  'cavity rotation rotated annular rotate ball liquid filling ring balance',
#  'technical control prevention velezensis false microorganism smut bacillus invention rice',
#  'device safety speed invention controlled driver braking control driving vehicle',
#  'moving axially inner direction outer axial device automobile rim tire',
#  'control recycling screening processing pressing materialscreening machining tile polishing ceramic',
#  'scheme method balancing calling call request load service server microservice',
#  'emitted curved another second first light reflect lamp reflected reflective',
#  'device unit current resistance calculation first voltage arithmetic initial transistor',
#  'micro pressure compensation accuracy weighing method calculation precision sensor measurement',
#  'first optimization store storefront merchandise customer discloses invention method information',
#  'bottom rotate top mounting invention mechanism shaft overturning item cabinet',
#  'treating biomedical treat preparation medicine fibrillation prevent preventing arrhythmia cardamine',
#  'electrical electromagnetic suction pipeline pipe vibration pump pumping water vibrationexciters',
#  'field force needle device poweroff power electromagnetic coil magnetic charging',
#  'energy convection energysaving heated pyrolysis heat steam gas boiler furnace',
#  'frequency signal embodiments user terminal controlling controlledto sensor sampling control',
#  'connected technical equipment lte signal base device transmitting platform station',
#  'treatment plant application tumor sloanea inhibit hemsleyana extract drug antitumor',
#  'system accumulator conditioner conditioning phasechange heat refrigerant airconditioning heating defrosting',
#  'activity route low invention selective absorption pyridoimidazo oral antibacterial rifamycins',
#  'mode guide end theconnecting communicated wiring light connected connecting lamp',
#  'server medium method discloses sending disclosed instant short message invention',
#  'cu ni bridgesteel nb si heataffected ti weatherproof welding steel',
#  'hammer pipe method control thewater supplypipe water valve waterhammerarresting waterhammer',
#  'cylinder morphology elongation forming mold polyphenylene epoxy molding elastomer resin',
#  'provided preparing form intermediate method crystalline sglt methods crystallizing inhibitor',
#  'defect verification technology product manufactured invention counterfeit counterfeiting counterfeiter anticounterfeiting',
#  'component cover medical force covering concaved concave instrument surface metallic',
#  'decentralized based invention estimated use user estimating method estimation data',
#  'processing server recovering resource recovery returned determiner indoubt transactional transaction',
#  'secured reinforcing breaking relates bracket cable fiber anchor sleeve mesh',
#  'gear pipe flame carburized carbonized carburizing technical plank welding wood',
#  'harvesting shaft rod rotating screw rotate sprout cart motor garlic',
#  'method embodiment discloses invention protocol security device obtainedthereby ciphertext secure',
#  'path previoushop sending downstream method device rsvpte tunnel network srte',
#  'element side device unit mounted drive vehicle rear diffusor movable',
#  'mechanism jacking forming equipment invention methodand metal perforating anchoring machining',
#  'provides method composition expression secretion disclosure polypeptide hemecontaining',
#  'fluid pressure detent hydraulic highpressure openstepped assembly sealing spray nozzle',
#  'sulfate cured washing product invention chloride modified calcium preparation autoclaving',
#  'configured transmit remove vehicle replace second disclosure replacing pr photoresist',
#  'discloses first object keyword usergenerated generated keywords invention virtual embodiment',
#  'compound aromatic salt inhibitor ureasubstituted used dioxinoquinoline dioxinoquinazoline drug pharmaceutically',
#  'nucleophile labelling relates reagent containing polyethylene bonding conjugate protein peptide',
#  'sludge hook impurity blocked fluid prevented preventing fire extinguishing drill',
#  'reaction anthrax purification oxidization synthesizing enzyme catalyzing transanisette anisaldehyde oxygenase',
#  'effluent sedimentation nitrification nitrogen denitrifying sludge denitrification removal sewage phosphorus',
#  'unscrew disassembling movable pressing disk locking unlocking mounting hdd lockingfree',
#  'worker air flow push method inlet spray fertilizer valve pours',
#  'medicament present directed composition invention eye use compound topical semifluorinated',
#  'processing technical millisecond display processor testing subscreens synchronous multiscreen synchronization',
#  'decoupling mutual bo dc shimming current shim rf magnetic coil',
#  'unit signal scanning lightemitting plurality pixel testing test display panel',
#  'technical threelayer hollow wrapping sleeve defect coated alloy titanium welding',
#  'fourier contrast phasecontrast beam ray reconstruction ct imaging tomography xray',
#  'detection transmitting radio unmanned transmission signal millimeterwave antenna subsystem radar',
#  'coated recycling chitosan resin gel ceramic porous sewage adsorbent adsorption',
#  'conductive gate fabricating manufacturing drainelectrode dielectric layer semiconductor transistor electrode',
#  'toothed tooth axialgap machine portion core rotary yoke surface dust',
#  'sample generated decision generating prediction gain learning method trained training',
#  'skin phenformin extract inhibits inhibitor hairan berberine salt keratinocytes melanin',
#  'removing carbonizing cleaning washing dissolve remove alkaline drying stain silicon',
#  'deodorization pressure negative valve removal pipeline discharge pipe smell toilet',
#  'cavity conical tuft handle embodiment cleaning bristle head tooth oral',
#  'tomography coordinate image earthfixed pixel navigation imaginggrid target imaging sar',
#  'comprises invention according processing determining using ordering method selection taxihailing',
#  'mounted mechanism radial axis timepiece device pipe display train hand',
#  'first invention wall electronic side equipment shell shaft screen display',
#  'upper device wheel building element floor roller ceiling wall movable',
#  'predetermined securing cycle manufacturing data connected transmitting network communication scheduling',
#  'product additive material phenolicbased carbonization thermoplastic carbon blend resin fiber',
#  'housinglike carrier thermally electric vehicle device storage motor energy heatconducting',
#  'machine part problem sewn portion cut cutting tape fabric sewing',
#  'smart key invention encrypted chain contract protection privacy block blockchain',
#  'open guide opening closing body builtin hinge inside door refrigerator',
#  'reversing system tunneling port multiway cylinder hydraulic machine valvea valve',
#  'supporting use material solidphase olefin metallocene polymerisation compound catalyst catalytic',
#  'preprocessing software module databased restoration restorationmethod restoring restores machine machinemodel',
#  'wall rotate belt safety shock beam swing rotating device shockproof',
#  'visible connected device communication signal transmitting light optical transceiver underwater',
#  'deformation fluid device axial deformable pressure stator rotor motor compressor',
#  'structure field structural supportingrods bottom structurecomprises pit foundation disc retaining',
#  'palladium oxide alkynyl ligand ditbutylhindolylphosphine ditertbutylhindolylphosphine indole catalyst synthesis alkyne',
#  'groove pipe device platform connected thread rail shaft screw steel',
#  'process equipment operating code quality supplier debuggingfile system debugging software',
#  'wireless instruction slave master system remote device kitchen module control',
#  'block locking rod device wheel torsional button pin pressing shaft',
#  'movable box mobile wireless block invention rubber exhaust charging charger',
#  'invention switch network port switching communication te node transmitting tunnel',
#  'fc switch configuration backup network reconstruction system port switched fault',
#  'operate used pistontype hydraulic hingeand cylinder device hinged hinge selflocking',
#  'saline androgenetic solvent treating papilla powder preparation alopecia treatment injection',
#  'method fertilizer flower leaf flowering vine plant blossoming planting seedling',
#  'coded generate data method coding interframe feedback image frame processing',
#  'determining pattern first second using data transmission method hopping frequency',
#  'pipe mechanism plastic drainage bottle table potted irrigation office plant',
#  'invention pulling drive thethread mold core machine molding device thread',
#  'wheel vehicle controller fluid pressurized pump hydraulic piston actuator assembly',
#  'nonconstraint wireless deployment optimizea algorithm sgd optimize unmanned optimizing optimization',
#  'fixed object imu target camera image disclosure angle attitude positioning',
#  'multiedge casting cut cylinder mold pulled cutting block concrete screw',
#  'invention assembly clamping spud pole clamp vessel hydraulic cylinder dredging',
#  'phase beam sar control radiation signal method electromagnetic rf antenna',
#  'powder maple mechanical birch board adhesive flour fiber wood fiberboard',
#  'pretightening heat cap polyimide assembly composite thermal alloy insulation titanium',
#  'method plant spectral scab field determine insect screening detection wheat',
#  'traffic anchoring construction light lightemitting marking led concrete lighttransmitting concretebased',
#  'buffer layer capacitor conductivetype substrate capacitorform silicon chip resistor semiconductor',
#  'control system embodiment firstcontrol information device electronic embodiments equipment invention',
#  'shoulder lumen integrated coaxial downstream upstream sensor inlet tube flow',
#  'blood sp diagnosis proteome acm protein serum cardiomyopathy biomarker karyosome',
#  'energy device terminal problem temperature tested electric electricenergy meter alarm',
#  'accuracy frequency squint imaging azimuth range rangedoppler resampling echo sar',
#  'guaranteed detect signal power matching method detection powersystems isolation protection',
#  'transplanting rooting bud plant induction culturing plantdividing germination seedling seed',
#  'prevented device mechanism invention garbage blocked used bridge antiblocking drainage',
#  'mill invention precision technical metal method drum machine notch control',
#  'computer tomographic ct control detection thecomputer system invention fault equipment',
#  'applicator cosmetic lip',
#  'packet speed method invention networkside switching switch network device humancomputer',
#  'pole conversion switch device electronic circuitin charge voltage circuit capacitor',
#  'material ferrous recovery metal steel collecting waste recycling adsorption effluent',
#  'amplifying electromagnetic current signal detecting output detected detection outputting excrement',
#  'wearresistant drive block belt surface bearing mounted mounting roller conveyor',
#  'strand complementary expression immune helical disclosure beta binding rna oligonucleotide',
#  'cylinder equipment motor shaft draw rotating textile wheel yarn winding',
#  'invention system score receives awakened technology awakening intelligent device response',
#  'quantitative device method inletoutlet tubular volume cylindrical fluid container liquid',
#  'invention hole penetrates pipe wire outer box penetrating air knife',
#  'stability ion composition material sulfide lithium metal solid conductivity electrolyte',
#  'efficiency method control strategy technology optimization power mobile thefemtocell femtocell',
#  'arranged invention midsoles structure moreover base sol heel sole shoe',
#  'circular groove rotating gear rotate rotates rod coil magnetic mold',
#  'deren elektrische aufweist der ein kraftfahrzeuge verschieberichtung aufgenommen eingangs schichtaufbau',
#  'processing image tobeprocessed area map sphere latitude subareas division longitudelatitude',
#  'motor torque machine control rod wire circuit servo tension tensionof',
#  'resonator measurement amplitude detection coordinate harmonic method identification gyroscope lms',
#  'shallow peripheral region isolation substrate deltamax surface trench nand memory',
#  'device secured flight operate system safety systems authentication uavs uav',
#  'process operation determine load monitoring determination measurement vacuum pump exhaust',
#  'contaminant fluid ecas sensor salt dispense electrochemically electrolysis irrigator irrigation',
#  'cutting bearing stroke drive circular machine lever pipe crank shaft',
#  'lamella portion spraying flexible film substrate surface reinforcement layer polymeric',
#  'connectedto smallopening joint body multisection discloses used cover water cup',
#  'invention determine suggested based database program memory processing core route',
#  'conductive material woven membrane elastic semifinished cut fabric cutting filament',
#  'informing method client disclosed security service access servicebased server authorization',
#  'processor controller testing experiment container pump valve oxygen device detector',
#  'product hydrogenation hydroxylamine preparation synthesis compound hydrochloride synthesized oxybenzaldehyde hydroxybenzaldehyde',
#  'device dataand method configuration equipment technology system scheme fuse fusion',
#  'information system network discloses iot device ip identification classification equipment',
#  'vibration oil equipment bracket hydraulic mounting bolt piston friction pressure',
#  'cloud ip system machine virtual server domain vpc dns vpcs',
#  'score method determined peripheral sole solepressure forefoot diabetic shoe foot',
#  'information collecting technical invention identifier consumer resource method scheme data',
#  'preparation temperature insulation change composite builtin phase heat thermal heating',
#  'device panel layer light reflecting substratethe reflective substrate display reflected',
#  'request invention router discloses information network method equipment access device',
#  'base rotate trunk motor garden push cutting wheel branch pruning',
#  'chain production storage food automation foodsolution apparatus container tank fried',
#  'collection device packing compacting compact bag screw pipe box garbage',
#  'stype resistance hypersalinity salt ntype slowexpandingswelling slowexpanding swelling magneticlike granule',
#  'electrically device invention electronic rotate rotating controlling circuit fan control',
#  'reaction hydroxyl used purification compound polypeptide solvent peptide synthesis diphenylmethane',
#  'thickness throughopening seat part removal window piece casing cover shell',
#  'communication third network second terminal carrier secondary station cell radio',
#  'connecting supplying device switch current winding ac circuit transformer voltage',
#  'protection residue biopharmacy reactant pipe solution ushaped pump box oxidization',
#  'liquid residue emulsified recycling oil oilwater waste leachate desorption wastewater',
#  'subtask method efficiency task production resource distributing invention embodiments distribution',
#  'seventh objectside element fifth image refractive photographing imageside optical lens',
#  'workpiece carry unit lifting lift suction bearing device invention carrier',
#  'force mounting rotation invention ring rotating motor mixer blade shaft',
#  'direction coupled order force electrical frame vibration magnetic magnetized magnet',
#  'source artificial fourcomponent data threecomponent detecting geological lowfrequency highfrequency detector',
#  'screen electronic trigger method detection device aconventional controlling control touch',
#  'turn turning supply invention electrical switch component motor device smt',
#  'substrate detecting metal metalconnecting detected oxide detection layer goi semiconductor',
#  'data processor light unit array image signal sensing sensor pixel',
#  'waterproof inlet air assembly outer shell exhaust cooling ventilation cabinet',
#  'process manufacturing composite polyester seaming sweater cashmere woven woollen yarn',
#  'dispersed heat semiconductor electrical cooling thermal material composite platelet graphene',
#  'tabletop food disengaged hole disassembly container removal cutter antidisengagement mounting',
#  'circuit assemble cylinder lowvoltage highvoltage transformer iron coil winding alloy',
#  'removal accurate accuracy scattering extinction method laser marine radar seawater',
#  'performed equipment whichcomprises motion performing method mixing invention animation embodiment',
#  'cooperative workshop gseries industrial train highspeedtrain robot multirobot machining grinding',
#  'relates second system third group invention fourth branch pipeline valve',
#  'material shale opal surface fabric grease nano skin facial mask',
#  'connected rubber framework fullcoldcontraction cable positioning equipment device terminal cableterminal',
#  'subnode node invention determined target content determining aim method contentnodes',
#  'multiple scanning circuit area comprises region subpixel display panel pixel',
#  'muzzle shot detonation powder gun coating sprayedinto sprayed laser spraying',
#  'invention field improving improved yield kernel farmland ethanol harvesting corn',
#  'data invention equipment block stored idleblock target cache cached caching',
#  'fixture method controlled tip block pressed machining stator pressing blade',
#  'formed cleavage method semicircle surface groove forming propagation semiconductor wafer',
#  'method volcanic methods zone additive contaminated subterranean gas mud drilling',
#  'wearable two assembly equipment connection invention connected link connecting chain',
#  'smooth film substrate optical protective coated hydrophobic wearresistant moistureproof mildewproof',
#  'system automatic technology device controlled valve pressurizing pressurizable heater oxygen',
#  'resistance steel atomization spraying antistatic atomizing polyester cotton ultrasonic yarn',
#  'durability invention reliability technology supply electronic power device equipment electrical',
#  'phase timing fuel control pmax torque combustion engine ignition cylinder',
#  'position detect positionbased jitter sensing device force touch sensor input',
#  'resource subway recycling residual gravel pit mud backfill tunneling soil',
#  'problem controlled temperature control power water method combustion gas heater',
#  'delay device equipment target method switching timeperiod driving vehicles vehicle',
#  'determining device invention position step adjusting display discloses second method',
#  'preparation heterocyclic used receptor compound adenosine antagonist antagonistic pharmaceutical aminopyrimidine',
#  'oil aeruginosa degradation centrifuge pseudomonas sewage oilcontaining bacterial bacteria bacterium',
#  'safety dust roadbed technical gas mechanism removal machine equipment culvert',
#  'obtaining chat invention technical task system software messaging machine instant',
#  'comprisingerror method controller error substrate information device electronic equipment invention',
#  'discharge pipe nozzle aim sand spray blasting spraying gun blast',
#  'conditioner sinusoidal harmonic outdoor unit air noise device invention motor',
#  'air starting operate mode control device invention method temperature conditioner',
#  'nan',
#  'graphic image effect background code frame invention video encoding embodiment',
#  'device measurement electric velocity voltage electromagnetic ion plume exhaust thruster',
#  'system control technical device invention target method clothing material equipment',
#  'fruit sleeve planting problem aim flexible sleeved tree device adjustable',
#  'surface groove block piece assembly dust workbench hopper machine milling',
#  'preservation fixing gear automatically rack placement locking device biomedical dish',
#  'readable method current accuracy conditioner device detection calibration sensor photoelectric',
#  'sealant compounded chsi catalyst si silane photovoltaic polydimethylsiloxane silicone polysiloxane',
#  'described present salt isoxazoline compound parasitic parasiticidal pesticidal pesticide invention',
#  'generated information image acquisition technical equipment device electronic jigsaw invention',
#  'issuing smart encryption equipment security authenticationprocess authentication invention device fingerprint',
#  'data computing independently remote remotely metadata parallel synchronous storage replication',
#  'heating aluminate lightemitting silane stirring magnesium silicatelight silicate silicatebased magnesiumstrontium',
#  'hang wire nail invention tag mechanical metal welded machine welding',
#  'treatment tool spring using bronze pin hardness beryllium heat block',
#  'power optimization energy battery charging electric fuel hybrid vehicle engine',
#  'assemble detector cylindrical assembly inserted slide attached sensor tube electrode',
#  'supplied part periphery positioned solution side outer rotated rotating hydrogel',
#  'groove beam emitter fixing invention embedded emitting beamand cylinder laser',
#  'model technicalfield utility generated field induction magnetism generator magnetic magnet',
#  'connected used application agent identifier module device method electronic bluetooth',
#  'tissue agent invention reused molten bonded coating material embedding mold',
#  'fluid made material lining bearing disc shaft rubber butterfly valve',
#  'layer electronic chip electrode multilayer ceramic piezoelectric dielectric composite capacitor',
#  'cell cancer method andor form pharmaceutical compound crystalline tautomers octylmethylhpyrazolylthienopyrimidinone',
#  'clustering ts filtering method target tracked estimation fuzzy estimationvalue tracking',
#  'radial relates adapt part connection pipe connecting partthe adjustable connected',
#  'film layer thickness indiumtin nm oxide resistance transparent conductive amorphous',
#  'saltcrystallized protective salt sodium corrosion protection pipe chloride pipeline brine',
#  'force system driven controlling actuator torque vehicle control wheel steering',
#  'agent method relates composition treating disclosure disorder isolated mitochondrion mitochondrial',
#  'information sends network terminal semipersistent configure configures resource scheduling configuration',
#  'equipment technology connecting connected cell modulein solder bus module solar',
#  'carboxy particle solvent polymerization magnetic carboxyl nano nanoparticles polystyrene microspheres',
#  'process producing layer strip drying oven lacquercoated electric lacquer insulation',
#  'application space filling device material interval board electronic assembly circuit',
#  'water preparation hydrothermal tubular lithium dyewater ceramic superhydrophilicity membrane nanofiltration',
#  'method object objectis technology information knowledge icon feature invention informationand',
#  'pressure operate flow control appliance assembly equipment water distributorcan distributor',
#  'building piece keel modularized edge fabricated unit module wall partitionwall',
#  'obtaining electronic disclosed discloses determination method sensor invention sensing scheme',
#  'assembly disposed vehicle stowage lid barrel lock compartment hinge bin',
#  'adjustable staple signature control pattern saddle fold sheet folding machine',
#  'predetermined setting assigns driving unit device defining designating control motor',
#  'gene oe pollen cultivation seedling plant crop maizeoe phosphorus maize',
#  'operation invention scheme method handling safety system equipment technical train',
#  'specifically also bind aggregation cd therapeutic monoclonal hemagglutination platelet antibody',
#  'resin protection carbon composite coating polyol polypropylene graphene polyurethane graphenemodified',
#  'able display embodiments circuit recognition pen device pentouchsensing touch touchsensing',
#  'exterior signal second described speaker membrane processor mobile device acoustic',
#  'terminal detecting fx detection upstream fyprimer polymorphism nucleotide snp primer',
#  'groove dy hole scheme plate slidably sliding punchingdie screw punching',
#  'item layer foilwherein particlesa particle surface foil glossiness copper roughening',
#  'oil product machine elastomer wear polyurethane polyester material thermoplastic wearresistant',
#  'flow delivery system method accessing disclosed request server process form',
#  'structural plastic structure box screen interior motor rear tailgate vehicle',
#  'device streaming application electronic medium virtual object technical target invention',
#  'equipment crop core pot wheel device machine seedling transplantation transplanting',
#  'pressure air main power unit train vehicle motor cylinder compressor',
#  'equipment impeller cylinder door vacuum gas airflow air heat cooling',
#  'imaging mirror spherical broadband diffraction waveband device mediumshort infrared optical',
#  'application provides treatment drug protein urinespecimen biomarker osteoarthritisrelated osteoarthritis adirf',
#  'production cleaned conveying cleaning agricultural spraywashing assembly container cultivation cultivationcontainers',
#  'housing recessed box renovation junction electrical light plug socket lighting',
#  'organic cover buffering salt fiber drying softening cloth downproof fabric',
#  'providing forminga proteinase rna prepared preparation dressing polysaccharide microbial cellulose',
#  'method collector communicating sent carrier power communication sending electric meter',
#  'second portion bit boom edge machine shaft cutting mining cutter',
#  'movable adjusting rotating nut rotation device seating vehicle motor seat',
#  'electronic equipment created developed program device target substrate controller invention',
#  'estimation fhog frame residual extracting filtering target extraction tracking filter',
#  'invention method sensing mouse setting parameter turnon device pointer input',
#  'layer prefabricated solar furnace thinfilm heating selenium lightabsorption copper copperindiumgallium',
#  'conveying stop block control arm device fastened pulled mechanism screw',
#  'supply controlled comfort indoor air device control conditioning conditioner invention',
#  'camera detection zone target fixing defect setup temperature thermal device',
#  'invention optic modulation diver digital electronics light lamp subsea underwater',
#  'melt metal material crco titanium cooling heating assemble assembly carbon',
# ...
#  'bottom slidably advertisement rolling outdoor device gear wind rack windproof',
#  'invention compound derivative medicine antitumor indolone drug spirothiazolone spirotetrahydrothiazolone spirocyclopropane',
#  'protective surface lead wire mounting heat temperature sensor heating electrode',
#  'aerating aeration ammonia coagulating flocculant flocculate mno wastewater manganese manganesecontaining',
#  'leakage detect engine method technical sealing metal sealingring test testing',
#  'clutch device control rotor actuator turned turning motor gear wheel',
#  'preparation structural polyhedral material layered composite sintering coated coating ceramic',
#  'technical tank vibrationfor device multilayer screened fertilizer equipment screening machine',
#  'system regeneration device acharging electrically invention power electrical energy charging',
#  'guide comprises component portion electronic electrically electronics invention busbar magnetic',
#  'control sensitivity selfturning strategy parameter applied solar controller method pi',
#  'apparatus administrator management device method user privilege ledger permission blockchain',
#  'control data receive radio sta beacon access wake method wakeup',
#  'aminoethyl pdmaemapolydimethyl synthesized compound chemical aromatic polymer polystyrenesulfonate polyacrylamide polyamide',
#  'sealed sensor sealing glass coating silver quartzglass ceramic pressure piezoelectric',
#  'wind invention rain accessory mechanism fog mirror driver rearview automobile',
#  'area image video chrominance brightness background color photographing processing segmentation',
#  'rear connected implantation handle device tube locking anchor anchoring tendon',
#  'plastic preparation foaming adsorption building glass hydrogencontaining material waterproof prefabricated',
#  'potency invention compound receptor prolactin inhibitory pharmaceutical olanzapine drug schizophrenia',
#  'convolution interpolation prediction tobeforecasted pollution ofpollutants pollutant tobepredicted atmospheric wind',
#  'frame classification histogram method video image ultrasonic abdominal ultrasound segmentation',
#  'electromagnetic applied bottom outer magnetorheological anticollision rod coil rack pipe',
#  'alkalinity visiblelight aluminum preparation oxide oxidesupported nitrate silicate ammonia photocatalyst',
#  'ventilation method controlled controlling invention control air car automobile airconditioner',
#  'method recovery experiment optimization process breaking pressing breaker crack gel',
#  'converting heterogeneous bifunctional conversion converted reactor hydrocarbon catalyzed ethanol catalyst',
#  'inlet drymixed machine conveying bottom bearing packaging pipe mortarcan mortar',
#  'attaching plate platethe clamping machine automobile shell repairing polishing paint',
#  'resistance compound styrene polybutadiene compounding acryl rubberfilling thermosetting resin thermoplastic',
#  'used device equipment tobesealed glue leakage leaking gasket gasketand sealing',
#  'used design bench probe test automobile fixing sensor lamp machining',
#  'cimdhi recombinant invention malate acid catalyze coli gene nucleotide dehydrogenase',
#  'flour powder fungus fireproof material plantbased materialand biobased preparation mold',
#  'device section moving board movingtowards guide door rail invention elevator',
#  'prepared titanium design method alloy invention preparation pouring mold casting',
#  'nano dye chitosan dialdehyde adsorption nanocellulose cellulose graphene graphenechitosan aerogel',
#  'similarity segmentation multilabel text fasttext predicting textlabel prediction classification label',
#  'air inlet tube airflow chamber flow shaft motor impeller blower',
#  'invention movable sealing groove dustproof charging rubber suckeris sucker bottle',
#  'network device wireless invention disclose method information system transmit transmission',
#  'spectroscopy papermaking process raman method ph detection acid silver wastewater',
#  'multilayered region producing center twolayered strip crumpling adjacent edge padding',
#  'ofsheep energy control system insulating temperature sheep house heating cooling',
#  'determining impact method device playback adjusting adjustment electronic audio interference',
#  'use equipment air method controlling invention control scheme conditioning conditioner',
#  'based ground invention control module autonomous sensor grinded robot grinding',
#  'chno nm succinate salt preparation monoclinicsystem pentanediamine crystallizing pentamethylenediamine crystal',
#  'heterozygous allele rnas biallelic modifying modified modification composition genome genomic',
#  'resource method embodiment information equipment embodiments lte communication invention subframe',
#  'preprocessing based screening evaluation warning method preset preloan data approval',
#  'centigrade stability formed prepared chemically pressure film dry boiling resist',
#  'terminal controlling method mode mobile reduce storage playback power video',
#  'gravity torsional build composite modular material rigidity bending chassis rolling',
#  'surround device display control screen window tool workpiece machine machining',
#  'synergistic lutein compound lycopene tomato acid inhibitsuppress inflammation antiinflammatory astaxanthin',
#  'liyxzpyxpxszxz lipsx ion composition material conductivity lithium metal solid electrolyte',
#  'auditing unit invention attribute cost construction project workload engineering constructionproject',
#  'limnf metal composite charging highvoltage nanometer electrode nanotube battery lithium',
#  'overcoming problem concrete limiting settlement plate limitingand pier block bridge',
#  'connected outerwall wall current insulation coil eddy heating barbecue grill',
#  'connected bottom surface ceiling downstream bowl discharge toilet flush conduit',
#  'nonmebrane valve driven system ceramic groove driving hydraulic pump piezoelectric',
#  'interface displaying fullscreen displaysthe execution executing display target application terminal',
#  'identification tampered xpath extracting method url static webpage detection tampering',
#  'outer oleopneumatic landing cylinder shockabsorber absorber gear air piston aerospace',
#  'connected thread force push mechanical cutting work equipment rope worktable',
#  'contact pipe gear oral tongue swallowing saliva mouth anesthesia drymouth',
#  'patient disposed therapeutically bronchial cytostatic balloon distal injection cytotoxic catheter',
#  'detected bend alarm fracture screen flexible bending deformation display flexiblescreen',
#  'derivative pharmaceutically halogen heteroaryl phenyl compound ch cycloalkyl alkyl indolinone',
#  'dynamic path tracking trajectory parked motion kinematic kinematics vehicle parking',
#  'aluminum cooling air shaft core filler machine ventilation laminated rotor',
#  'load connection computing traffic network mobility mobile vehicle networkcost networking',
#  'amplifier current connected capacitor resistor circuit inductor charging transistor voltage',
#  'placed material sewn seating manufacturing assembly vehicle sewing cushion seat',
#  'meerschaum solvent moulded sprayed trichlorosilane polyurethane meerschaumpolyurethane superhydrophobicsuperoleophobic paint coating',
#  'material atom invention irradiation zinc photoluminescent light silver emits sodalite',
#  'multipath interlink channel acoustic underwater interference propagation transmitting transmission multiplexing',
#  'furnace wafer pecvd vapor preparation deposition invention plasma silicon sic',
#  'due assembly invention vehicle walking wheel cross crossing robot obstacle',
#  'conductive packaging communication aspects aspect integrated event ingestible device invention',
#  'air upstream cleaner portion hose pipesolution combustion piping engine pipe',
#  'conductivity chemical insulating covering centigrade surface thermal oxide insulated tuckstone',
#  'pressure duct tracer control seal detecting sensing checking sealing drone',
#  'derivative industry storage use phenol agrifood solid polymer compound invention',
#  'body axis radially oscillating device rotatable resonating rotation damping pendulum',
#  'presseddown engine system controlling sensor vehicle transmission pedal control clutch',
#  'support two cover invention device end vehicle attached undercarriage undercarriagefig',
#  'surface ball manufacturing material invention electronic board daughterboards daughterboard motherboard',
#  'residue base coring formed head core forming leaf cutting lettuce',
#  'method circuit motor fault invention gas blowby crankcase machine engine',
#  'invention indication using information customized data medicationinduced classifying artificial method',
#  'current surface connected cap assembly discharging rechargeable charging battery electrode',
#  'part relates deformation protrusion bent direction terminal aspect invention bulb',
#  'accommodated embedded conditioner air indoor suction ceiling ventilated wifi ventilator',
#  'container technology beverage display liquid supply extracting process extracted extraction',
#  'polyvinyl propylene surfactant acrylic polypropylene binder moulding polymer polymeric copolymer',
#  'generate generating position determining method current block candidate mpm prediction',
#  'andor seq cell virus ifitm gene embryo chicken invention avian',
#  'clearance spool offposition mechanism shaft pin pinion gear bearing clutch',
#  'central direct formed electromagnetic relay current direction formation magnet arc',
#  'drive binding robot control rear rebar bind rebars binder wheel',
#  'unit position visible picture driver control optical display projection head',
#  'panel display conversion quantum block layer color liquid crystal copolymer',
#  'outer invention comprises joint mounting machine washing flange shaft tub',
#  'treat treatment cure information method drug category data classifying disclosure',
#  'veneer building material panel core fibre wood surface layer sublayer',
#  'air purchased weight unused transaction airplane sold weighing cargo baggage',
#  'driver signal frequency drive surgical tip tool mechanical ultrasonic handpiece',
#  'map module transmitting feedback system microcomputer testing device satellite gnss',
#  'housing insulating interior streetlight light surface sink led heat cooling',
#  'skimmer collecting adjustable hingecoupled collect tank floated floating water flotation',
#  'top chip sidewall disposed surface led sterilization sterilized uv sterilizer',
#  'nitrifying water method manipulate apparatus control aquatic controlling microbial microbe',
#  'facing position controllable image surface hole shape display device stretchable',
#  'includes separator direction interposed thickness edge tab stack assembly electrode',
#  'coming introduction dynamic exchanger heat hydrolyzed sludge cooling heating mixer',
#  'second communication touch computing phone method apparatus inputoutput tablet device',
#  'bed direct bottom fluidized inlet fluidizing reactor flow nozzle gas',
#  'process equipment microorganism hygiene powder invention mold production manufacturing manufacture',
#  'flexible region touch panel electrically layer sensor pixel display electrode',
#  'signal receiving message interface ars transmitting telephone call method caller',
#  'elastic force unit handle side frame blocking spool attached reel',
#  'network second cell signalling message station transmission transmit radio transmits',
#  'first anticlogging chamber inlet capillary mixing multichannel fluid microfluidic microfluidics',
#  'obtained comprises acquire apparatus output unit acquisition processing image imagecapturing',
#  'embodiment affixed characterizing image representing marking marked document identification imprint',
#  'pin pulled protect copper hand safety trigger invention handle gasbag',
#  'method store energy vehicle motor charging charger',
#  'amplitude correlation currentwaveform method power wavelet stroke transmission arrester lightning',
#  'logement destine ladite dancrage en darrimage de etre personne organe',
#  'system secret key privacy ciphertext encrypted encrypting encryption secretkey reencryption',
#  'includes package structure second board die chip circuit disposed spacer',
#  'scheme department invention shaft andaims medicine otorhinolaryngologic device used spraying',
#  'stored generating processing sleep method information audio device wake electronic',
#  'module mechanical control circuit electric electromechanical bus controller robot motor',
#  'frame panorama photograph electronic camera invention image device photographing equipment',
#  'recognition control key computer intelligent box invention fingerprint system device',
#  'fixing rotating safety rod bolt device mounting gear rack gearcan',
#  'detecting detected peroxidaselabeled probe plate aptamer biotin enzymelinked enzymelabeled aflatoxin',
#  'method device mode positioning position control set setting motor servo',
#  'communication vehicle safety control bus invention train device ebcus ebcu',
#  'groove partially line layer manufacturing substrate drain gate tunneling transistor',
#  'singlechain doublechain sgrna pcmvdcpfrrebe dna oligonucleotide recombinant plasmid gene plbcpfsgrna',
#  'pushed technical information method pushing device push invention pushmethod advertisement',
#  'unitare outer air production outdoor alsobe conditioner metal coating shell',
#  'preparation polymer reaction solvent chloride antitermite catalyst ratproof reactor polyurethane',
#  'mounting utilizing gridmesh thread mesh invention connected ion device grid',
#  'doublecolumn tendon cap doublelayer block selfresetting brace doublepier bridge pier',
#  'treatment pretreatment diphenylethylene aftertreatment drying finishing material procedure working fabric',
#  'detection device vehicle detecting voltage insulation charging electric resistor highvoltage',
#  'protruding area bottom surround substrate opening panel surface layer display',
#  'bonding stack preparation assembling proton electrode membrane cell hydrogen fuel',
#  'tin workshop fiber preparation tread catalyst selfrepairing polyurethane tire rubber',
#  'accepting process consensus query rejecting submitted method submission blockchain blockchainbased',
#  'apparatus inlet drainage drainageport cleaning department tube flushing pipe flusher',
#  'surface layer adsorption antibacterium wrap cleaning sterile fabric garment cleanroom',
#  'concrete rail cutting sawblades road dust wheel construction cutter saw',
#  'assembly motor unit embodiment invention wall side train welded welding',
#  'connected third switch dc limiter multipole current pole electric electrical',
#  'navigation rear plate tip tail stabilizer front lowerfin ship fin',
#  'force combine vertical transverse device wall unit material invention formwork',
#  'solid waste technical filling slurry material preparation mining curing tailing',
#  'plunger unit system testing pipeline sensor device valve tool pump',
#  'gradient tobediagnosed displaying temperature infrared method thermogram coefficient insulator porcelain',
#  'control method device vx equipment automobile detection vehicleroad vehicle driving',
#  'pattern accessing terminal information device communication indication application method ssb',
#  'user real invention score processand application theplaying quality playing video',
#  'bottom flushedout flow shell floor sliding sewage cleaning drainage drain',
#  'cylindrical penetrating two hole direction invention lateral groove bracelet shaft',
#  'control subspace splicing subprojectionimages device image identification imaging holographic projection',
#  'fft interference multipleinputmultipleoutput transducer decoded transmitting acoustic hydrophones transmit demodulation',
#  'system id invention target embodiment sample label feature binningcondition binning',
#  'rotate unoutboard aim multichannel circular hplane rotary antenna straightwaveguide waveguide',
#  'building method tj step iot operation invention dispatching robot elevator',
#  'block extruding machining injection screw machine molding ejector flow plastic',
#  ...]

# %% [markdown]
# # Visualization

# %%
# !pip install kmapper
import kmapper as km

# %%
# Project all of the "sentences" down into a 2D representation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import Isomap
from sklearn.preprocessing import MinMaxScaler


from sklearn import cluster


mapper = km.KeplerMapper(verbose=2)
projected_X = mapper.fit_transform(np.array(phrases),
projection=[TfidfVectorizer(analyzer="char",
                            ngram_range=(1,6),
                            max_df=0.83,
                            min_df=0.05),
            TruncatedSVD(n_components=100,
                         random_state=1729),
            Isomap(n_components=2,
                   n_jobs=-1)],
scaler=[None, None, MinMaxScaler()])

print("SHAPE",projected_X.shape)
# print(projected_X.getfield())
# Out:
# KeplerMapper(verbose=2)
# ..Composing projection pipeline of length 3:
# 	Projections: TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.83, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
# 		TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
# 		Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
# 	Distance matrices: False
# False
# False
# 	Scalers: None
# None
# MinMaxScaler(copy=True, feature_range=(0, 1))
# ..Projecting on data shaped (2000,)
#
# ..Projecting data using:
# 	TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.83, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
#
#
# ..Created projection shaped (2000, 945)
# ..Projecting on data shaped (2000, 945)
#
# ..Projecting data using:
# 	TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
#
# ..Projecting on data shaped (2000, 100)
#
# ..Projecting data using:
# 	Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
#
#
# ..Scaling with: MinMaxScaler(copy=True, feature_range=(0, 1))
#
# SHAPE (2000, 2)

# %%
# Cluster the projected data
graph = mapper.map(projected_X, clusterer=cluster.DBSCAN(eps=0.5, min_samples=3))
# Out:
# Mapping on data shaped (2000, 2) using lens shaped (2000, 2)
#
# Minimal points in hypercube before clustering: 3
# Creating 100 hypercubes.
#    > Found 1 clusters in hypercube 0.
#    > Found 1 clusters in hypercube 1.
#    > Found 1 clusters in hypercube 2.
#    > Found 1 clusters in hypercube 3.
# Cube_4 is empty.
#
#    > Found 1 clusters in hypercube 5.
#    > Found 1 clusters in hypercube 6.
#    > Found 1 clusters in hypercube 7.
#    > Found 1 clusters in hypercube 8.
#    > Found 1 clusters in hypercube 9.
#    > Found 1 clusters in hypercube 10.
#    > Found 1 clusters in hypercube 11.
#    > Found 1 clusters in hypercube 12.
#    > Found 1 clusters in hypercube 13.
#    > Found 1 clusters in hypercube 14.
#    > Found 1 clusters in hypercube 15.
#    > Found 1 clusters in hypercube 16.
#    > Found 1 clusters in hypercube 17.
#    > Found 1 clusters in hypercube 18.
#    > Found 1 clusters in hypercube 19.
#    > Found 1 clusters in hypercube 20.
#    > Found 1 clusters in hypercube 21.
#    > Found 1 clusters in hypercube 22.
#    > Found 1 clusters in hypercube 23.
#    > Found 1 clusters in hypercube 24.
#    > Found 1 clusters in hypercube 25.
#    > Found 1 clusters in hypercube 26.
#    > Found 1 clusters in hypercube 27.
#    > Found 1 clusters in hypercube 28.
#    > Found 1 clusters in hypercube 29.
# Cube_30 is empty.
#
#    > Found 1 clusters in hypercube 31.
#    > Found 1 clusters in hypercube 32.
#    > Found 1 clusters in hypercube 33.
#    > Found 1 clusters in hypercube 34.
#    > Found 1 clusters in hypercube 35.
#    > Found 1 clusters in hypercube 36.
#    > Found 1 clusters in hypercube 37.
#    > Found 1 clusters in hypercube 38.
#    > Found 1 clusters in hypercube 39.
#    > Found 1 clusters in hypercube 40.
#    > Found 1 clusters in hypercube 41.
#    > Found 1 clusters in hypercube 42.
#    > Found 1 clusters in hypercube 43.
#    > Found 1 clusters in hypercube 44.
#    > Found 1 clusters in hypercube 45.
#    > Found 1 clusters in hypercube 46.
#    > Found 1 clusters in hypercube 47.
#    > Found 1 clusters in hypercube 48.
#    > Found 1 clusters in hypercube 49.
#    > Found 1 clusters in hypercube 50.
#    > Found 1 clusters in hypercube 51.
#    > Found 1 clusters in hypercube 52.
#    > Found 1 clusters in hypercube 53.
#    > Found 1 clusters in hypercube 54.
#    > Found 1 clusters in hypercube 55.
#    > Found 1 clusters in hypercube 56.
#    > Found 1 clusters in hypercube 57.
#    > Found 1 clusters in hypercube 58.
#    > Found 1 clusters in hypercube 59.
#    > Found 1 clusters in hypercube 60.
#    > Found 1 clusters in hypercube 61.
#    > Found 1 clusters in hypercube 62.
#    > Found 1 clusters in hypercube 63.
#    > Found 1 clusters in hypercube 64.
#    > Found 1 clusters in hypercube 65.
#    > Found 1 clusters in hypercube 66.
#    > Found 1 clusters in hypercube 67.
#    > Found 1 clusters in hypercube 68.
#    > Found 1 clusters in hypercube 69.
#    > Found 1 clusters in hypercube 70.
#    > Found 1 clusters in hypercube 71.
#    > Found 1 clusters in hypercube 72.
#    > Found 1 clusters in hypercube 73.
#    > Found 1 clusters in hypercube 74.
#    > Found 1 clusters in hypercube 75.
#    > Found 1 clusters in hypercube 76.
#    > Found 1 clusters in hypercube 77.
#    > Found 1 clusters in hypercube 78.
#    > Found 1 clusters in hypercube 79.
#    > Found 1 clusters in hypercube 80.
#    > Found 1 clusters in hypercube 81.
#
# Created 163 edges and 80 nodes in 0:00:00.112974.

# %%
X=docs
# Get counts of phrases from data (to be used for the label and for cluster statistics)
vec = TfidfVectorizer(analyzer="word",
                  strip_accents="unicode",
                  stop_words="english",
                  ngram_range=(1,3),
                  max_df=0.97,
                  min_df=0.02)

interpretable_inverse_X = vec.fit_transform(X).toarray()
interpretable_inverse_X_names = vec.get_feature_names()

print("SHAPE", interpretable_inverse_X.shape)
print("FEATURE NAMES SAMPLE",
interpretable_inverse_X_names[:400])
# Out:
# SHAPE (2000, 496)
# FEATURE NAMES SAMPLE ['access', 'according', 'according invention', 'according method', 'accuracy', 'accurate', 'accurately', 'achieve', 'achieved', 'acid', 'acquiring', 'acquisition', 'action', 'active', 'added', 'adding', 'addition', 'adjacent', 'adjusted', 'adjusting', 'adjustment', 'adopted', 'adopting', 'advantage', 'agent', 'air', 'algorithm', 'analysis', 'andor', 'angle', 'apparatus', 'application', 'application thereof', 'applied', 'area', 'arranged', 'art', 'assembly', 'associated', 'automatic', 'automatically', 'avoided', 'away', 'axis', 'base', 'based', 'basis', 'battery', 'beam', 'bearing', 'belongs', 'belongs field', 'belongs technical', 'belongs technical field', 'better', 'block', 'body', 'box', 'calculating', 'calculation', 'capable', 'carried', 'carrying', 'caused', 'cavity', 'cell', 'center', 'central', 'certain', 'chamber', 'change', 'channel', 'characteristic', 'characterized', 'circuit', 'clamping', 'cleaning', 'close', 'coating', 'collecting', 'combination', 'combined', 'communication', 'compared', 'completed', 'component', 'composite', 'composition', 'compound', 'comprises', 'comprises following', 'comprises following step', 'comprises step', 'comprising', 'computer', 'condition', 'configuration', 'configured', 'connected', 'connecting', 'connection', 'consumption', 'contact', 'containing', 'content', 'control', 'control method', 'controlled', 'controller', 'controlling', 'convenient', 'conveniently', 'conveying', 'cooling', 'core', 'corresponding', 'correspondingly', 'cost', 'coupled', 'cover', 'current', 'cutting', 'cylinder', 'data', 'degree', 'design', 'detected', 'detecting', 'detection', 'determined', 'determining', 'device', 'device comprises', 'device includes', 'device method', 'difference', 'different', 'direction', 'directly', 'disclosed', 'discloses', 'discloses method', 'disclosure', 'display', 'disposed', 'distance', 'distributed', 'distribution', 'drive', 'driven', 'driving', 'drying', 'easy', 'edge', 'effect', 'effectively', 'efficiency', 'efficiency improved', 'electric', 'electrode', 'electronic', 'electronic equipment', 'element', 'embodiment', 'embodiment invention', 'end', 'energy', 'ensured', 'environment', 'equal', 'equipment', 'excellent', 'existing', 'extending', 'external', 'face', 'feature', 'feeding', 'field', 'film', 'filtering', 'finally', 'fixed', 'fixedly', 'fixedly connected', 'fixing', 'flexible', 'flow', 'following', 'following step', 'force', 'form', 'formed', 'forming', 'formula', 'frame', 'frequency', 'function', 'gas', 'generate', 'generated', 'generating', 'generation', 'good', 'greatly', 'groove', 'group', 'guaranteed', 'guide', 'head', 'heat', 'heating', 'high', 'higher', 'hole', 'image', 'improve', 'improved', 'improving', 'include', 'includes', 'including', 'increased', 'information', 'inlet', 'inner', 'input', 'inside', 'installed', 'instruction', 'intelligent', 'interface', 'internal', 'interval', 'invention', 'invention belongs', 'invention belongs technical', 'invention discloses', 'invention discloses method', 'invention provides', 'invention relates', 'invention relates technical', 'large', 'layer', 'le', 'left', 'length', 'level', 'life', 'light', 'like', 'line', 'liquid', 'load', 'located', 'low', 'lower', 'lower end', 'machine', 'main', 'management', 'manner', 'manufacturing', 'matched', 'material', 'mean', 'measurement', 'mechanical', 'mechanism', 'medium', 'meet', 'member', 'metal', 'method', 'method based', 'method comprises', 'method comprises following', 'method comprises step', 'method device', 'method includes', 'method method', 'method thereof', 'middle', 'mode', 'model', 'module', 'monitoring', 'motor', 'mounted', 'mounting', 'movable', 'moving', 'multiple', 'need', 'network', 'node', 'normal', 'number', 'object', 'obtain', 'obtained', 'obtaining', 'ofthe', 'oil', 'opening', 'operation', 'opposite', 'optical', 'order', 'original', 'outer', 'outlet', 'output', 'outside', 'panel', 'parameter', 'particle', 'particular', 'particularly', 'path', 'p ...

# %%
html = mapper.visualize(graph,X=interpretable_inverse_X,
                        X_names=interpretable_inverse_X_names,
                        path_html="Abstract1.html",
                        lens=projected_X,
                        lens_names=["ISOMAP1", "ISOMAP2"],
                        title="Visualizing Text - Abstract",
                        )
# Out:
# Wrote visualization to: Abstract1.html

# %%
# Out:
# <style>div.output_scroll { height: 44em; }</style>

# %%
from kmapper import jupyter
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 74em; }</style>"))

jupyter.display(path_html="Abstract1.html")
# Out:
# <style>div.output_scroll { height: 74em; }</style>
# <style>
#         .container { width:100% !important; }
#         .output_scroll {height: 800px !important;}
#         </style>
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=Abstract1.html width=100%% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ## BERT and  BlueBERT

# %%
# from transformers import BertTokenizer, BertModel
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# model = BertModel.from_pretrained("bert-base-uncased")

# %%
# path='V:/ML_projects/NLP_pipeline/pretrain_model/BlueBERT/'
from transformers import BertTokenizer
from transformers import BertModel
import torch

# %%
blueBERT_tokenizer=BertTokenizer.from_pretrained('bionlp/bluebert_pubmed_uncased_L-12_H-768_A-12')
blueBERT_tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='bionlp/bluebert_pubmed_uncased_L-12_H-768_A-12', vocab_size=30522, model_max_len=1000000000000000019884624838656, is_fast=False, padding_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
# text = doc
marked_text = "[CLS] " + doc + " [SEP]"

# Tokenize our sentence with the BERT tokenizer.
tokenized_text = blueBERT_tokenizer.tokenize(marked_text)

# Print out the tokens.
print (tokenized_text)

# Map the token strings to their vocabulary indeces.
indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)

# Display the words with their indeces.
for tup in zip(tokenized_text, indexed_tokens):
    print('{:<12} {:>6,}'.format(tup[0], tup[1]))

    
# Mark each of the tokens as belonging to sentence.
segments_ids = [1] * len(tokenized_text)
print (segments_ids)

# Convert inputs to PyTorch tensors
tokens_tensor = torch.tensor([indexed_tokens])
segments_tensors = torch.tensor([segments_ids])
list(blueBERT_tokenizer.vocab.keys())[4000:4020]   


# Load pre-trained model (weights)
model = BertModel.from_pretrained('bionlp/bluebert_pubmed_uncased_L-12_H-768_A-12',
                                  output_hidden_states = True, # Whether the model returns all hidden-states.)

                                  
# Put the model in "evaluation" mode, meaning feed-forward operation.
model.eval()

                                  
with torch.no_grad():
    outputs = model(tokens_tensor, segments_tensors)
    hidden_states = outputs[2]

# %%
print ("Number of layers:", len(hidden_states), "  (initial embeddings + 12 BERT layers)")
layer_i = 0
print ("Number of batches:", len(hidden_states[layer_i]))
batch_i = 0
print ("Number of tokens:", len(hidden_states[layer_i][batch_i]))
token_i = 0
print ("Number of hidden units:", len(hidden_states[layer_i][batch_i][token_i]))


token_i = 5
layer_i = 5
vec = hidden_states[layer_i][batch_i][token_i]

# Plot the values as a histogram to show their distribution.
plt.figure(figsize=(10,10))
plt.hist(vec, bins=200)
plt.show()
# Out:
# Number of layers: 13   (initial embeddings + 12 BERT layers)
# Number of batches: 1
# Number of tokens: 227
# Number of hidden units: 768
# <img src="data:image/png;base64,..." width="1000">

# %%
doc=abs_clean_text[5]
def keywordextract(sentence):
    text = sentence
    tkns = blueBERT_tokenizer.tokenize(text)
    print(tkns)
    indexed_tokens = blueBERT_tokenizer.convert_tokens_to_ids(tkns)
    
    segments_ids = [0] * len(tkns)
    tokens_tensor = torch.tensor([indexed_tokens]).to(device)
    segments_tensors = torch.tensor([segments_ids]).to(device)
    model.eval()
    prediction = []
    logit = model(tokens_tensor, token_type_ids=None,attention_mask=segments_tensors)[0]

    logit = logit.detach().cpu().numpy()
    prediction.extend([list(p) for p in np.argmax(logit, axis=2)])
    for k, j in enumerate(prediction[0]):
        if j==1 or j==0:
            print(blueBERT_tokenizer.convert_ids_to_tokens(tokens_tensor[0].to('cpu').numpy())[k], j)
            
print(doc)
keywordextract(doc)
# Out:
# A cleaner includes: a suction motor that generates suction force; a dust separation unit disposed under the suction motor and separates dust from air; a handle disposed behind the suction motor; and a battery disposed under the handle and behind the dust separation unit to supply power to the suction motor.
# ['a', 'cleaner', 'includes', ':', 'a', 'su', '##ction', 'motor', 'that', 'generates', 'su', '##ction', 'force', ';', 'a', 'dust', 'separation', 'unit', 'disposed', 'under', 'the', 'su', '##ction', 'motor', 'and', 'separates', 'dust', 'from', 'air', ';', 'a', 'handle', 'disposed', 'behind', 'the', 'su', '##ction', 'motor', ';', 'and', 'a', 'battery', 'disposed', 'under', 'the', 'handle', 'and', 'behind', 'the', 'dust', 'separation', 'unit', 'to', 'supply', 'power', 'to', 'the', 'su', '##ction', 'motor', '.']
