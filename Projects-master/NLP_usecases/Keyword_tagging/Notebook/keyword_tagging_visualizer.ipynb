# %% [markdown]
# # Keyword Tagging & Normalization Skeleton
# ## [1.Data Extraction_&_Preprocessing](#1.Data_Extraction_&_Preprocessing)
#
# ### Dataset
# ### Type of Dataset: Patent Data Abstract: Patbase
# ### Size of Dataset: 2000k Records
#
# ### Preprocessing
#
# 1) We used <b>NLTK</b> to tokenize and Lemmatize the Text
#
# ### Improvements
#
# #### Word Tokenization and Lemmatization can be improved with POS Tagging
#
# ## [2.Keyword_&_Phrase_Extraction](#2.Keyword_&_Phrase_Extraction)
#
# 1) Used <b>Count Vectorizer and Tfidf</b> to get candidate keywords \
# 2) <b>Paraphrase mining sentence embedding</b> used to get sentence embedding link:https://www.sbert.net/examples/applications/paraphrase-mining/README.html \
# 3) <b>Maximum Marginal Retrival</b> to check cosine similarity across documents to consolidate candidate terms with terms across documents
#
# ### Improvements
# #### After CV and TFIDF we can apply lemmatization with adding vectors to increase weightage across similar words with same meaning to reduce redundancy.
# #### Encoder Decoder Model with self Attention can be utilized to get better embedding with context and similarity
# ####  Pretrained BERT can be used to get better contextual similarity
#
# ### [3.Visualization](#3.Visualization)
# #### Motivation
# To get View of Textual Meaning and Relation of keyowrds and phrases across documents to get better intuition.
#
# steps
# 1) Used <b>KMapper</b> to visualize top keyowrds across documeents \
# 2) Used <b>DBScan Clustering Algorithm</b> to combine various phrases within documents AND across documents with TFIDF & Ngram
#
# ### Conclusion
# 1) Here is implementation workflow for Keyphrase Extraction with visualization
# 2) We can see there is duplicate and redundant terms which can be

# %%
import string
import re
import numpy as np
import pandas as pd
import codecs
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from gensim.models import Word2Vec
from gensim.models.fasttext import FastText
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
from scipy import spatial


import nltk
from nltk.corpus import wordnet,stopwords
from nltk.stem import WordNetLemmatizer 
from nltk import WordNetLemmatizer, pos_tag, word_tokenize



from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

from scipy import stats

import spacy
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])


import tqdm

# doc=nlp(text)

from gensim.summarization import keywords
stop_words=stopwords.words('english')
lemmatizer = WordNetLemmatizer()
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %% [markdown]
# # 1.Data_Extraction_&_Preprocessing

# %%
pat_data=pd.read_csv('V:/ML_projects/Merckgroup/NLP/Data/patbase_extract/patbase_bib_csv200020210716_.csv')
abs_text=pat_data['Abstract']
print(type(abs_text))

sample_data=pd.read_excel('V:/ML_projects/Merckgroup/Keyword_tagging/data/Keyword_validation.xlsx')
sample_abs_data=sample_data['Abstract']
sample_abs_data
# Out:
# <class 'pandas.core.series.Series'>
# 0      pooled crispr libraries are widely used in hig...
# 1      crispr loci consist of an array of short repea...
# 2      the simplicity and precision of crispr/cas9 sy...
# 3      the battle for survival between bacteria and t...
# 4      despite the advances made in genetic engineeri...
#                              ...
# 195    crispr-cas are adaptive immune systems that de...
# 196    a widespread system used by bacteria for prote...
# 197    the cas9 nuclease from streptococcus pyogenes ...
# 198    the clustered regularly interspaced short pali...
# 199    the crispr/cas9 system was recently developed ...
# Name: Abstract, Length: 200, dtype: object

# %%
def text_cleaning(text):
    cleaned_txt = re.sub('<[^<]+>', ' ', str(text))
    cleaned_txt = re.sub( r'\[.*?\]', ' ',cleaned_txt)  #remove brackets
#     cleaned_txt = re.sub('\d+', ' ', cleaned_txt)
#     cleaned_txt = re.sub('\(\w+\)', ' ', cleaned_txt)
#     cleaned_txt=text.translate(str.maketrans(' ', ' ',string.punctuation)) 
    return cleaned_txt
   
def stopword_removal(text):
    cleaned_txt = ' '.join([token for token in word_tokenize(text) if token not in stop_words])
    return cleaned_txt
def lemmatize_text(text):
    cleaned_txt=' '.join([lemmatizer.lemmatize(token) for token in word_tokenize(text)])

    return cleaned_txt

def preprocessed_text(df):
    
    col=['nltk_tokens','nouns_verbs','lemmatize_text']
    preprocess_txt=pd.DataFrame(columns=col)
    abs_clean_text=df.apply(text_cleaning)
    
    stopword_removed_text=abs_clean_text.apply(stopword_removal)         
    preprocess_txt['lemmatize_text']=stopword_removed_text.apply(lemmatize_text)
  
    for ind,text in preprocess_txt['lemmatize_text'].iteritems():       
        tokens=word_tokenize(text)
        pos_tokens=nltk.pos_tag(tokens)
        preprocess_txt.at[ind,'nouns_verbs']=[pos_token for pos_token,pos in pos_tokens if pos.startswith('N' or 'V')]
        preprocess_txt.at[ind,'nltk_tokens']=tokens     
    return preprocess_txt

# %%
# preprocessed_df=preprocessed_text(abs_text)
# preprocessed_df

preprocessed_df1=preprocessed_text(sample_abs_data)
preprocessed_df1
# Out:
#                                            nltk_tokens  \
# 0    [pooled, crispr, library, widely, used, high-t...
# 1    [crispr, locus, consist, array, short, repeat,...
# 2    [simplicity, precision, crispr/cas9, system, b...
# 3    [battle, survival, bacteria, virus, infect, (,...
# 4    [despite, advance, made, genetic, engineering,...
# ..                                                 ...
# 195  [crispr-cas, adaptive, immune, system, degrade...
# 196  [widespread, system, used, bacteria, protectio...
# 197  [cas9, nuclease, streptococcus, pyogenes, (, s...
# 198  [clustered, regularly, interspaced, short, pal...
# 199  [crispr/cas9, system, recently, developed, pow...
#
#                                            nouns_verbs  \
# 0    [library, high-throughput, screening, study, p...
# 1    [crispr, locus, array, repeat, sequence, match...
# 2    [simplicity, precision, crispr/cas9, system, e...
# 3    [battle, survival, bacteria, phage, evolution,...
# 4    [advance, engineering, saccharomyces, cerevisi...
# ..                                                 ...
# 195  [immune, system, element, archaea, bacteria, f...
# 196  [system, bacteria, protection, dna, molecule, ...
# 197  [cas9, nuclease, streptococcus, pyogenes, spca...
# 198  [repeat, gene, system, bacteria, plasmid, bact...
# 199  [crispr/cas9, system, technology, engineering\...
#
#                                         lemmatize_text
# 0    pooled crispr library widely used high-through...
# 1    crispr locus consist array short repeat separa...
# 2    simplicity precision crispr/cas9 system brough...
# 3    battle survival bacteria virus infect ( phage ...
# 4    despite advance made genetic engineering sacch...
# ..                                                 ...
# 195  crispr-cas adaptive immune system degrade fore...
# 196  widespread system used bacteria protection pot...
# 197  cas9 nuclease streptococcus pyogenes ( spcas9 ...
# 198  clustered regularly interspaced short palindro...
# 199  crispr/cas9 system recently developed powerful...
#
# [200 rows x 3 columns]

# %% [markdown]
# # 2.Keyword_&_Phrase_Extraction

# %% [markdown]
# ### keyphrase extraction workflow
#
# 1. Extraction of keywords using count vectorizer,Tfidf,spacy, gensim
# 2. Generating Sentence embedding from Pretrained Model for each document
# 3. Duplicate and Redundant removal with MMR for single document ,Doc_word cosine Simililarity for Multiple document

# %% [markdown]
# ## Single doc

# %%
# !pip install wget

# %%
def cv_word_doc_embedding(doc):
    cv_countvec = CountVectorizer(ngram_range=(1,1), stop_words=stop_words, min_df=1).fit([doc])
    cv_words = cv_countvec.get_feature_names()
    cv_doc_embeddings = embedding_model.encode([doc])
    cv_word_embeddings =embedding_model.encode(cv_words)
    return cv_word_embeddings,cv_doc_embeddings,cv_words

# %%
def tfidf_word_doc_embedding(doc):
    tfidf_countvec = TfidfVectorizer(ngram_range=(1,2), stop_words=stop_words, min_df=0.8).fit([doc])
    tfidf_words = tfidf_countvec.get_feature_names()    

    tfidf_doc_embeddings = embedding_model.encode([doc])
    tfidf_word_embeddings = embedding_model.encode(tfidf_words)
    return tfidf_word_embeddings,tfidf_doc_embeddings,tfidf_words

# %%
top_n=10
diversity=0.3
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("paraphrase-MiniLM-L6-v2")

# %%
def mmr(doc_embedding: np.ndarray,word_embeddings: np.ndarray,words,top_n,diversity):
    # Extract similarity within words, and between words and the document
    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)
    
    # Initialize candidates and already choose best keyword/keyphras
    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]
    
    for _ in range(top_n - 1):
        # Extract similarities within candidates and
        # between candidates and selected keywords/phrases
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # Calculate MMR
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]
        
        # Update keywords & candidates
        if mmr_idx:
            keywords_idx.append(mmr_idx)
            candidates_idx.remove(mmr_idx)
            
    return [(words[idx], round((word_doc_similarity.reshape(1, -1)[0][idx]), 4)) for idx in keywords_idx]

# %%
doc=preprocessed_df1['lemmatize_text']
cv_keywords=[]
tfidf_keywords=[]
cv_phrases=[]
tfidf_phrases=[]
for i in doc:
    cv_word_embed,cv_doc_embed,cv_words=cv_word_doc_embedding(i)
    if cv_words:
        cv_keywords_doc=mmr(cv_doc_embed,cv_word_embed,cv_words,top_n,diversity)
        cv_keywords_doc=','.join([key[0] for key in cv_keywords_doc])
        cv_phrases_doc=''.join([key[0] for key in cv_keywords_doc])
        cv_keywords.append(cv_keywords_doc)
        cv_phrases.append(cv_phrases_doc)
    
    tfidf_word_embed,tfidf_doc_embed,tfidf_words=tfidf_word_doc_embedding(i)
    tfidf_keywords_doc=mmr(tfidf_doc_embed,tfidf_word_embed,tfidf_words,5,0.2)
    tfidf_keywords_doc=','.join([key[0] for key in tfidf_keywords_doc])
    tfidf_phrases_doc=''.join([key[0] for key in tfidf_keywords_doc])
#     print('cv_keywords',cv_keywords_doc)
#     print('cv_phrases',cv_phrases_doc)
 
#     print('tfidf_keywords',tfidf_keywords_doc)
#     print('tfidf_phrases',tfidf_phrases_doc)
    
    tfidf_keywords.append(tfidf_keywords_doc)
    tfidf_phrases.append(tfidf_phrases_doc)
# Out:
# cv_keywords crispr,pooled,libraries,screening,throughput,cas9,gene,modified,researcher,method
# cv_phrases crispr,pooled,libraries,screening,throughput,cas9,gene,modified,researcher,method
# tfidf_keywords pooled crispr,crispr library,create pooled,crispr screening,gene crispr
# tfidf_phrases pooled crispr,crispr library,create pooled,crispr screening,gene crispr
# cv_keywords crispr,plasmid,locus,genome,deletion,virus,antisense,decoys,epidermidis,prokaryote
# cv_phrases crispr,plasmid,locus,genome,deletion,virus,antisense,decoys,epidermidis,prokaryote
# tfidf_keywords crispr locus,transcription crispr,crispr deletion,crispr immunity,virus plasmid
# tfidf_phrases crispr locus,transcription crispr,crispr deletion,crispr immunity,virus plasmid
# cv_keywords crispr,sequencing,cas9,dav
# cv_phrases crispr,sequencing,cas9,dav
# tfidf_keywords crispr data,crispr ng,crispr cas9,crispr dav,analyze crispr
# tfidf_phrases crispr data,crispr ng,crispr cas9,crispr dav,analyze crispr
# cv_keywords crispr,bacterial,phage,inhibits,protein,cas,virus,interactor,immune,gene
# cv_phrases crispr,bacterial,phage,inhibits,protein,cas,virus,interactor,immune,gene
# tfidf_keywords crispr proteins,phage inhibit,inhibit crispr,bacteria defend,crispr protein
# tfidf_phrases crispr proteins,phage inhibit,inhibit crispr,bacteria defend,crispr protein
# cv_keywords crispr,saccharomyces,genomic,multicopy,polymerase,plasmid,cerevisiae,genome,delta,pathway
# cv_phrases crispr,saccharomyces,genomic,multicopy,polymerase,plasmid,cerevisiae,genome,delta,pathway
# tfidf_keywords crispr delta,multicopy genomic,cerevisiae genome,cerevisiae multicopy,integration crispr
# tfidf_phrases crispr delta,multicopy genomic,cerevisiae genome,cerevisiae multicopy,integration crispr
# cv_keywords crispr,genes,clustered
# cv_phrases crispr,genes,clustered
# tfidf_keywords inhibitor crispr,acr proteins,crispr acr,control crispr,crispr associated
# tfidf_phrases inhibitor crispr,acr proteins,crispr acr,control crispr,crispr associated
# cv_keywords crispr,phage
# cv_phrases crispr,phage
# tfidf_keywords crispr resistance,acr phage,acr genes,phage blocking,crispr acr
# tfidf_phrases crispr resistance,acr phage,acr genes,phage blocking,crispr acr
# cv_keywords crispr,sgrnas,prioritizes,gene,throughput,filter,cas9,editing,efficient,cistrome
# cv_phrases crispr,sgrnas,prioritizes,gene,throughput,filter,cas9,editing,efficient,cistrome
# tfidf_keywords sgrnas crispr,prioritize sgrnas,gene crispr,based crispr,prioritizes sgrnas
# tfidf_phrases sgrnas crispr,prioritize sgrnas,gene crispr,based crispr,prioritizes sgrnas
# cv_keywords crispr,genome,inhibitor,cas9,modulate,optogenetic,photosensor,streptococcus,potent,acriia4
# cv_phrases crispr,genome,inhibitor,cas9,modulate,optogenetic,photosensor,streptococcus,potent,acriia4
# tfidf_keywords crispr biology,crispr cas9,anti crispr,protein crispr,crispr variant
# tfidf_phrases crispr biology,crispr cas9,anti crispr,protein crispr,crispr variant
# cv_keywords crispr,alignment,genome,tool,mismatch,accuracy,sequences,blat,component,biotechnology
# cv_phrases crispr,alignment,genome,tool,mismatch,accuracy,sequences,blat,component,biotechnology
# tfidf_keywords sequence alignment,existing crispr,genome editing,alignment tools,site crispr
# tfidf_phrases sequence alignment,existing crispr,genome editing,alignment tools,site crispr
# cv_keywords crispr,cloning,genome,cas9n,paste,polymerase,tinkering,gibson,virus,plasmid
# cv_phrases crispr,cloning,genome,cas9n,paste,polymerase,tinkering,gibson,virus,plasmid
# tfidf_keywords cloning crispr,crispr cas9,crispr cloning,template crispr,crispr application
# tfidf_phrases cloning crispr,crispr cas9,crispr cloning,template crispr,crispr application
# cv_keywords crispr,gene,sgrna,bioinformatics,selection,rna,cas9,regulatory,genome,zebrafish
# cv_phrases crispr,gene,sgrna,bioinformatics,selection,rna,cas9,regulatory,genome,zebrafish
# tfidf_keywords genome crispr,sgrna efficiency,optimization crispr,gene knockout,spcas9 crispr
# tfidf_phrases genome crispr,sgrna efficiency,optimization crispr,gene knockout,spcas9 crispr
# cv_keywords crispr,inhibitor,rna,cas9,gene,inactivate,ca,streptococcus,nucleic,oligonucleotides
# cv_phrases crispr,inhibitor,rna,cas9,gene,inactivate,ca,streptococcus,nucleic,oligonucleotides
# tfidf_keywords crispr rna,inactivate crispr,control crispr,inhibition cas9,crispr cas
# tfidf_phrases crispr rna,inactivate crispr,control crispr,inhibition cas9,crispr cas
# cv_keywords crispr,gene,editing,recombination,analyzer,mouse,genome,deletion,revolutionized,regularly
# cv_phrases crispr,gene,editing,recombination,analyzer,mouse,genome,deletion,revolutionized,regularly
# tfidf_keywords crispr genome,gene editing,recombination crispr,documentation crispr,gene therapy
# tfidf_phrases crispr genome,gene editing,recombination crispr,documentation crispr,gene therapy
# cv_keywords crispr,bioinformatics,cas,genome,editing,crrnas,system,c2c2,rna,researcher
# cv_phrases crispr,bioinformatics,cas,genome,editing,crrnas,system,c2c2,rna,researcher
# tfidf_keywords crispr rna,system crispr,crispr cas,research crispr,genome editing
# tfidf_phrases crispr rna,system crispr,crispr cas,research crispr,genome editing
# cv_keywords genome,crispr,prokaryote,cas1,polymerases,protein,plasmid,replication,dna,superfamily
# cv_phrases genome,crispr,prokaryote,cas1,polymerases,protein,plasmid,replication,dna,superfamily
# tfidf_keywords polymerase crispr,prokaryote operonically,associated cas1,genome stability,crispr cas
# tfidf_phrases polymerase crispr,prokaryote operonically,associated cas1,genome stability,crispr cas
# cv_keywords streptomycetes,crispr,genes,generate,edits,plasmid,bioactive,organisms,toolkit,clone
# cv_phrases streptomycetes,crispr,genes,generate,edits,plasmid,bioactive,organisms,toolkit,clone
# tfidf_keywords streptomycete genome,crispr toolkit,advance genome,clone crispr,streptomycetes provide
# tfidf_phrases streptomycete genome,crispr toolkit,advance genome,clone crispr,streptomycetes provide
# cv_keywords crispr,genomes,cas9,protein,bacterial,bioinformatics,archaeal,engineered,immune,gene
# cv_phrases crispr,genomes,cas9,protein,bacterial,bioinformatics,archaeal,engineered,immune,gene
# tfidf_keywords crispr cas9,bacterial genomes,gene editing,crispr associated,crispr cas
# tfidf_phrases crispr cas9,bacterial genomes,gene editing,crispr associated,crispr cas
# cv_keywords crispr,gene,cas9,modifying,immune,preclinic,therapy,genome,regularly,genetic
# cv_phrases crispr,gene,cas9,modifying,immune,preclinic,therapy,genome,regularly,genetic
# tfidf_keywords treatment crispr,genome editing,gene therapy,crispr cas9,based gene
# tfidf_phrases treatment crispr,genome editing,gene therapy,crispr cas9,based gene
# cv_keywords eccdnas,gene,crispr,biosensor,eccdna,fluorescence,dna,chromosome,genetic,fibroblast
# cv_phrases eccdnas,gene,crispr,biosensor,eccdna,fluorescence,dna,chromosome,genetic,fibroblast
# tfidf_keywords dna eccdna,crispr gene,biogenesis eccdnas,eccdna biosensor,generate eccdnas
# tfidf_phrases dna eccdna,crispr gene,biogenesis eccdnas,eccdna biosensor,generate eccdnas
# cv_keywords crispr,extinction,cas9,genome,critter,prevention,likely,novel,nonhuman,frivolous
# cv_phrases crispr,extinction,cas9,genome,critter,prevention,likely,novel,nonhuman,frivolous
# tfidf_keywords crispr cas9,us crispr,application crispr,crispr,crispr critter
# tfidf_phrases crispr cas9,us crispr,application crispr,crispr,crispr critter
# cv_keywords crispr,sgrnas,gene,screening,selection,robustness,identifier,rna,editing,clone
# cv_phrases crispr,sgrnas,gene,screening,selection,robustness,identifier,rna,editing,clone
# tfidf_keywords furthermore crispr,assessment gene,probability crispr,identical sgrnas,pooled crispr
# tfidf_phrases furthermore crispr,assessment gene,probability crispr,identical sgrnas,pooled crispr
# cv_keywords crispr,cas6,rna,immune,cmr,type,virus,coli,genetic,prokaryotic
# cv_phrases crispr,cas6,rna,immune,cmr,type,virus,coli,genetic,prokaryotic
# tfidf_keywords rna crispr,crispr cas,systems crispr,crispr rna,iii crispr
# tfidf_phrases rna crispr,crispr cas,systems crispr,crispr rna,iii crispr
# cv_keywords crispr,plasmids,gene,inhibitory,cas3,bacteriophage,helicase,nucleic,resistance,immune
# cv_phrases crispr,plasmids,gene,inhibitory,cas3,bacteriophage,helicase,nucleic,resistance,immune
# tfidf_keywords protein crispr,anti crispr,crispr protein,bind crispr,crispr system
# tfidf_phrases protein crispr,anti crispr,crispr protein,bind crispr,crispr system
# cv_keywords crispr,cpf1,bioinformatics,genome,grnas,selection,clustered,regularly,editing,rna
# cv_phrases crispr,cpf1,bioinformatics,genome,grnas,selection,clustered,regularly,editing,rna
# tfidf_keywords crispr cpf1,grnas crispr,efficiency crispr,cpf1 grnas,genome editing
# tfidf_phrases crispr cpf1,grnas crispr,efficiency crispr,cpf1 grnas,genome editing
# cv_keywords crispr,biotechnologies,genome,improved,cas,targeting,tool,nanotechnology,editing,robust
# cv_phrases crispr,biotechnologies,genome,improved,cas,targeting,tool,nanotechnology,editing,robust
# tfidf_keywords crispr technology,advancement crispr,development crispr,crispr cas,application crispr
# tfidf_phrases crispr technology,advancement crispr,development crispr,crispr cas,application crispr
# cv_keywords crispr,rnai,gene,cas9,therapy,modulation,biomedical,genome,protein,combination
# cv_phrases crispr,rnai,gene,cas9,therapy,modulation,biomedical,genome,protein,combination
# tfidf_keywords rnai crispr,gene therapy,cas9 crispr,capability crispr,gene editing
# tfidf_phrases rnai crispr,gene therapy,cas9 crispr,capability crispr,gene editing
# cv_keywords crispr,bacterial,genome,inhibit,archaeal,biomolecules,type,cas,enzyme,regulator
# cv_phrases crispr,bacterial,genome,inhibit,archaeal,biomolecules,type,cas,enzyme,regulator
# tfidf_keywords inhibit crispr,crispr regulator,bacterial archaeal,genome editing,mechanism crispr
# tfidf_phrases inhibit crispr,crispr regulator,bacterial archaeal,genome editing,mechanism crispr
# cv_keywords crispr,immune,gene,cas9
# cv_phrases crispr,immune,gene,cas9
# tfidf_keywords crispr gene,acrs immune,inhibit crispr,crispr cas9,distributed bacteria
# tfidf_phrases crispr gene,acrs immune,inhibit crispr,crispr cas9,distributed bacteria
# cv_keywords crispr,genomic,pcr,maximum,dna,hybridization,gene,genome,capture,dsdna
# cv_phrases crispr,genomic,pcr,maximum,dna,hybridization,gene,genome,capture,dsdna
# tfidf_keywords scalable crispr,dna maximum,pcr hybridization,target gene,dna based
# tfidf_phrases scalable crispr,dna maximum,pcr hybridization,target gene,dna based
# cv_keywords crispr,archaeal,virus,nucleotide,bacteria,domain6,immunity,cas10,genetic,protein
# cv_phrases crispr,archaeal,virus,nucleotide,bacteria,domain6,immunity,cas10,genetic,protein
# tfidf_keywords enzyme crispr,bacteria archaea,antiviral response7,viral dna,pathogen interactions11
# tfidf_phrases enzyme crispr,bacteria archaea,antiviral response7,viral dna,pathogen interactions11
# cv_keywords haplotype,crispr,aspam,genome,protospacer,mutation,ttr,snp,combination,haplotyping
# cv_phrases haplotype,crispr,aspam,genome,protospacer,mutation,ttr,snp,combination,haplotyping
# tfidf_keywords snp crispr,haplotype specific,aspam crispr,crispr hapc,crispr database
# tfidf_phrases snp crispr,haplotype specific,aspam crispr,crispr hapc,crispr database
# cv_keywords crispr,biotechnology,cas9,revolutionized,toolbox,gene,breakthrough,diversification,innovation,impact
# cv_phrases crispr,biotechnology,cas9,revolutionized,toolbox,gene,breakthrough,diversification,innovation,impact
# tfidf_keywords crispr genome,revolutionized biotechnology,cas9 versatile,crispr cas9,diversification crispr
# tfidf_phrases crispr genome,revolutionized biotechnology,cas9 versatile,crispr cas9,diversification crispr
# cv_keywords crispr
# cv_phrases crispr
# tfidf_keywords crispr cas9,acriic2nme inhibits,crispr protein,inhibition cas9,anti crisprs
# tfidf_phrases crispr cas9,acriic2nme inhibits,crispr protein,inhibition cas9,anti crisprs
# cv_keywords crispr,gene,cas9,modification,clustered,regularly,genomic,genome,mediated,domain
# cv_phrases crispr,gene,cas9,modification,clustered,regularly,genomic,genome,mediated,domain
# tfidf_keywords specificity crispr,crispr cas9,activate gene,advantage crispr,crispr associated
# tfidf_phrases specificity crispr,crispr cas9,activate gene,advantage crispr,crispr associated
# cv_keywords crispr,rna,reagent,biosensing,immune,genome,cas9,rnp,regularly,adaptive
# cv_phrases crispr,rna,reagent,biosensing,immune,genome,cas9,rnp,regularly,adaptive
# tfidf_keywords detection crispr,genome editing,crispr protein,repeat crispr,crispr cas9
# tfidf_phrases detection crispr,genome editing,crispr protein,repeat crispr,crispr cas9
# cv_keywords crispr,adaptation,prokaryotic,immunity,genetic,prespacers,nucleic,suppressing,clustered,pcr
# cv_phrases crispr,adaptation,prokaryotic,immunity,genetic,prespacers,nucleic,suppressing,clustered,pcr
# tfidf_keywords autoimmunity crispr,crispr adaptation,prokaryotic adaptive,study crispr,crispr clustered
# tfidf_phrases autoimmunity crispr,crispr adaptation,prokaryotic adaptive,study crispr,crispr clustered
# cv_keywords crispr,cas,genomes,operon,spacer,bacterial,system,combination,type,recombination
# cv_phrases crispr,cas,genomes,operon,spacer,bacterial,system,combination,type,recombination
# tfidf_keywords crispr cas,genome spacers,gene crispr,isolated crispr,diversification crispr
# tfidf_phrases crispr cas,genome spacers,gene crispr,isolated crispr,diversification crispr
# cv_keywords crispr,cas9,genome,technology,editing,method
# cv_phrases crispr,cas9,genome,technology,editing,method
# tfidf_keywords crispr cas9,genome editing,widely used,crispr,novel method
# tfidf_phrases crispr cas9,genome editing,widely used,crispr,novel method
# cv_keywords prokaryote,crisprs,virus,arm,molecular,evolve,similarity,genetic,protein,fight
# cv_phrases prokaryote,crisprs,virus,arm,molecular,evolve,similarity,genetic,protein,fight
# tfidf_keywords prokaryote virus,molecular arm,crispr protein,virus evolve,virus prokaryote
# tfidf_phrases prokaryote virus,molecular arm,crispr protein,virus evolve,virus prokaryote
# cv_keywords crispr,revolutionized,gene,diversify,discovery,toolbox,improve,rapid,nucleic,genome
# cv_phrases crispr,revolutionized,gene,diversify,discovery,toolbox,improve,rapid,nucleic,genome
# tfidf_keywords crispr revolutionized,discovery crispr,gene editing,crispr technology,improve crispr
# tfidf_phrases crispr revolutionized,discovery crispr,gene editing,crispr technology,improve crispr
# cv_keywords crispr,archaea,virus,genomes,prokaryotes,plasmid,bacteria,immune,rna,control
# cv_phrases crispr,archaea,virus,genomes,prokaryotes,plasmid,bacteria,immune,rna,control
# tfidf_keywords prokaryote crispr,crispr locus,archaea bacteria,virus plasmid,rna based
# tfidf_phrases prokaryote crispr,crispr locus,archaea bacteria,virus plasmid,rna based
# cv_keywords cas9,gene,crispr,fungus,guideline,targeting,sgrna,mutagenize,marker,protocol
# cv_phrases cas9,gene,crispr,fungus,guideline,targeting,sgrna,mutagenize,marker,protocol
# tfidf_keywords crispr cas9,gene targeting,fungi genetic,cas9 relevant,implementation crispr
# tfidf_phrases crispr cas9,gene targeting,fungi genetic,cas9 relevant,implementation crispr
# cv_keywords crispr,cas9,disable,acriia4,genome,dcas9,binding,fda,acr,editing
# cv_phrases crispr,cas9,disable,acriia4,genome,dcas9,binding,fda,acr,editing
# tfidf_keywords crispr cas9,genome editing,biosafety crispr,cas9 editing,anti crispr
# tfidf_phrases crispr cas9,genome editing,biosafety crispr,cas9 editing,anti crispr
# cv_keywords transposon,crispr,genetic,cast,chromosomal,type,dna,unique,immune,encoded
# cv_phrases transposon,crispr,genetic,cast,chromosomal,type,dna,unique,immune,encoded
# tfidf_keywords crispr transposon,cast chromosomal,transposon cast,encoded crispr,cast type
# tfidf_phrases crispr transposon,cast chromosomal,transposon cast,encoded crispr,cast type
# cv_keywords cas12a,crisprs,genome,cpf1,crrnas,plasmid,bacteriophage,acrva4,inhibitors,rna
# cv_phrases cas12a,crisprs,genome,cpf1,crrnas,plasmid,bacteriophage,acrva4,inhibitors,rna
# tfidf_keywords crispr cas12a,crispr rna,cas12a crrna,transcription crispr,cas12a cpf1
# tfidf_phrases crispr cas12a,crispr rna,cas12a crrna,transcription crispr,cas12a cpf1
# cv_keywords crispr,genome,plasmid,epigenetic,primer,edit,researcher,gene,clustered,system
# cv_phrases crispr,genome,plasmid,epigenetic,primer,edit,researcher,gene,clustered,system
# tfidf_keywords crispr application,development crispr,crispr derived,crispr associated,primer crispr
# tfidf_phrases crispr application,development crispr,crispr derived,crispr associated,primer crispr
# cv_keywords crispr,amaurosis,gene,retinal,future,repeat,efficacy,congenital,genome,ophthalmic
# cv_phrases crispr,amaurosis,gene,retinal,future,repeat,efficacy,congenital,genome,ophthalmic
# tfidf_keywords efficacy crispr,crispr genome,amaurosis crispr,repeat crispr,ophthalmic genome
# tfidf_phrases efficacy crispr,crispr genome,amaurosis crispr,repeat crispr,ophthalmic genome
# cv_keywords genome,crispr,profiling,rna,genomic,transcriptomic,epigenomic,protein,facile,cas
# cv_phrases genome,crispr,profiling,rna,genomic,transcriptomic,epigenomic,protein,facile,cas
# tfidf_keywords programmability crispr,genomic transcriptomic,rna guided,crispr clustered,genome programmability
# tfidf_phrases programmability crispr,genomic transcriptomic,rna guided,crispr clustered,genome programmability
# cv_keywords crispr,labeling,chromatin,genome,cas9,microscopy,binding,targeting,catalytically,optogenetic
# cv_phrases crispr,labeling,chromatin,genome,cas9,microscopy,binding,targeting,catalytically,optogenetic
# tfidf_keywords crispr labeling,crispr cas9,binding crispr,inducible crispr,chromatin architecture
# tfidf_phrases crispr labeling,crispr cas9,binding crispr,inducible crispr,chromatin architecture
# cv_keywords crispr3,enterococcus,multidrug,genome,resistance,plasmid,clustered,codistribution,isolates,mdr
# cv_phrases crispr3,enterococcus,multidrug,genome,resistance,plasmid,clustered,codistribution,isolates,mdr
# tfidf_keywords genes crispr3,codistribution crispr,resistance enterococcal,genome multidrug,repeat crispr
# tfidf_phrases genes crispr3,codistribution crispr,resistance enterococcal,genome multidrug,repeat crispr
# cv_keywords arm,virus,race,crispr,evolution,prokaryotic,biological,immune,protein,parasite
# cv_phrases arm,virus,race,crispr,evolution,prokaryotic,biological,immune,protein,parasite
# tfidf_keywords arm race,parasite crispr,biological arm,anti virus,evolution anti
# tfidf_phrases arm race,parasite crispr,biological arm,anti virus,evolution anti
# cv_keywords crispr,genes,csa3b,activates,factor,promoter,cmr,plasmid,deletion,memory
# cv_phrases crispr,genes,csa3b,activates,factor,promoter,cmr,plasmid,deletion,memory
# tfidf_keywords regulation crispr,csa3b gene,crispr associated,adaptation crispr,crispr interference
# tfidf_phrases regulation crispr,csa3b gene,crispr associated,adaptation crispr,crispr interference
# cv_keywords crispr,archaea,immune,genetic,cas1,adaptive,virus,protein,memory,defend
# cv_phrases crispr,archaea,immune,genetic,cas1,adaptive,virus,protein,memory,defend
# tfidf_keywords rna crispr,invaders crispr,crispr memory,governing crispr,crispr cas
# tfidf_phrases rna crispr,invaders crispr,crispr memory,governing crispr,crispr cas
# cv_keywords crispr,bacteriophage,cas1,genomic,spacer,isolates,crisr,bacterial,mechanism,mirabilis
# cv_phrases crispr,bacteriophage,cas1,genomic,spacer,isolates,crisr,bacterial,mechanism,mirabilis
# tfidf_keywords crispr bacterial,isolates crispr,gene spacer,mechanism bacteriophage,crispr spacer
# tfidf_phrases crispr bacterial,isolates crispr,gene spacer,mechanism bacteriophage,crispr spacer
# cv_keywords crispr,bacteriophage,viruses,immune,gene,predation,phage,mechanism,bacterial,inhibitor
# cv_phrases crispr,bacteriophage,viruses,immune,gene,predation,phage,mechanism,bacterial,inhibitor
# tfidf_keywords crispr mediated,predation viruses,bacterial adaptive,crispr protein,anti crispr
# tfidf_phrases crispr mediated,predation viruses,bacterial adaptive,crispr protein,anti crispr
# cv_keywords crispr,patent,cas9,months,gene,bioethical,breakthrough,germlines,sciences,altering
# cv_phrases crispr,patent,cas9,months,gene,bioethical,breakthrough,germlines,sciences,altering
# tfidf_keywords crispr cas9,year gene,patent may,dispute crispr,influential scientific
# tfidf_phrases crispr cas9,year gene,patent may,dispute crispr,influential scientific
# cv_keywords crispr,bacteria,use,gene,type,cas9,control,editing,development,disadvantage
# cv_phrases crispr,bacteria,use,gene,type,cas9,control,editing,development,disadvantage
# tfidf_keywords development crispr,bacteria focus,genome editing,focus type,disadvantage crispr
# tfidf_phrases development crispr,bacteria focus,genome editing,focus type,disadvantage crispr
# cv_keywords crispr,ethics,genetic,didactic,scientist,commonly,editing,interview,genome,palindromic
# cv_phrases crispr,ethics,genetic,didactic,scientist,commonly,editing,interview,genome,palindromic
# tfidf_keywords crispr interview,crispr associated,abbreviated crispr,genome editing,clinically ethically
# tfidf_phrases crispr interview,crispr associated,abbreviated crispr,genome editing,clinically ethically
# cv_keywords rna,crispr,listeriaphage,cas13,acrvia1,crrna,antiviral,nucleases,counteract,immunity
# cv_phrases rna,crispr,listeriaphage,cas13,acrvia1,crrna,antiviral,nucleases,counteract,immunity
# tfidf_keywords crispr rna,describe listeriaphage,cas13a preventing,rna crrna,acrvia1 interacts
# tfidf_phrases crispr rna,describe listeriaphage,cas13a preventing,rna crrna,acrvia1 interacts
# cv_keywords yeast,crispr,gene,cas9,rnase,schizosaccharomyces,crrnas,multiplex,rrk1,class
# cv_phrases yeast,crispr,gene,cas9,rnase,schizosaccharomyces,crrnas,multiplex,rrk1,class
# tfidf_keywords crispr cas12a,yeast transformation,gene editing,crrna cas12a,crispr cas9
# tfidf_phrases crispr cas12a,yeast transformation,gene editing,crrna cas12a,crispr cas9
# cv_keywords genome,prokaryotic,streptococcus,immune,cas9,crispr,pyogenes,biotechnological,pathogen,knowledge
# cv_phrases genome,prokaryotic,streptococcus,immune,cas9,crispr,pyogenes,biotechnological,pathogen,knowledge
# tfidf_keywords prokaryotic crispr,revolution genome,streptococcus pyogenes,evolution pathogen,discovery crispr
# tfidf_phrases prokaryotic crispr,revolution genome,streptococcus pyogenes,evolution pathogen,discovery crispr
# cv_keywords acrid1,crispr,archaeal,immunity,cas10d,gene
# cv_phrases acrid1,crispr,archaeal,immunity,cas10d,gene
# tfidf_keywords inhibitor crispr,archaeal acrs,acrid1 inhibits,acr protein,crispr acr
# tfidf_phrases inhibitor crispr,archaeal acrs,acrid1 inhibits,acr protein,crispr acr
# cv_keywords crispr,therapies,hereditary,screening,disrupt,regulatory,research,likely,ethical,hurdle
# cv_phrases crispr,therapies,hereditary,screening,disrupt,regulatory,research,likely,ethical,hurdle
# tfidf_keywords crispr diagnostic,crispr therapeutic,crispr diagnostics,argue crispr,relevant crispr
# tfidf_phrases crispr diagnostic,crispr therapeutic,crispr diagnostics,argue crispr,relevant crispr
# cv_keywords crispr,mutations,cas9,sequencing,nucleic,gene,biosensing,targeted,mutagenesis,specie
# cv_phrases crispr,mutations,cas9,sequencing,nucleic,gene,biosensing,targeted,mutagenesis,specie
# tfidf_keywords identify crispr,crispr cas9,screening crispr,mutation detection,efficiency crispr
# tfidf_phrases identify crispr,crispr cas9,screening crispr,mutation detection,efficiency crispr
# cv_keywords crispr,gene,edit,bacterial,nucleotide,orthopaedic,genome,regularly,molecular,modification
# cv_phrases crispr,gene,edit,bacterial,nucleotide,orthopaedic,genome,regularly,molecular,modification
# tfidf_keywords crispr genome,gene editing,repeat crispr,disease crispr,crispr molecules
# tfidf_phrases crispr genome,gene editing,repeat crispr,disease crispr,crispr molecules
# cv_keywords crispr,acr,genes,phage,inhibit,protein,conservation
# cv_phrases crispr,acr,genes,phage,inhibit,protein,conservation
# tfidf_keywords acr gene,inhibit crispr,crispr acr,acr protein,acr genes
# tfidf_phrases acr gene,inhibit crispr,crispr acr,acr protein,acr genes
# cv_keywords crispr,nuclease,targeting,gene,repeat,zfns,toolbox,clustered,revolutionized,easily
# cv_phrases crispr,nuclease,targeting,gene,repeat,zfns,toolbox,clustered,revolutionized,easily
# tfidf_keywords research crispr,crispr technology,repeat crispr,crispr system,example crispr
# tfidf_phrases research crispr,crispr technology,repeat crispr,crispr system,example crispr
# cv_keywords crispr,screening,microenvironment,vivo,recapitulate,transplant,mutagenesis
# cv_phrases crispr,screening,microenvironment,vivo,recapitulate,transplant,mutagenesis
# tfidf_keywords vivo crispr,crispr screening,repeat crispr,process crispr,crispr screen
# tfidf_phrases vivo crispr,crispr screening,repeat crispr,process crispr,crispr screen
# cv_keywords gene,pseudomonas,crispr,immune,mge,aeruginosa,inhibiting,cas3,nuclease,phage
# cv_phrases gene,pseudomonas,crispr,immune,mge,aeruginosa,inhibiting,cas3,nuclease,phage
# tfidf_keywords aeruginosa crispr,gene anti,pseudomonas aeruginosa,anti crispr,inhibiting aeruginosa
# tfidf_phrases aeruginosa crispr,gene anti,pseudomonas aeruginosa,anti crispr,inhibiting aeruginosa
# cv_keywords crispr,gene,shigella,clustered,virulence,subtypes,bacteria,polymorphism,specie,crrna
# cv_phrases crispr,gene,shigella,clustered,virulence,subtypes,bacteria,polymorphism,specie,crrna
# tfidf_keywords crispr shigella,crispr locus,crispr sequence,crispr associated,analyzed crispr
# tfidf_phrases crispr shigella,crispr locus,crispr sequence,crispr associated,analyzed crispr
# cv_keywords crispr,acrif9,dsdna,protein,genetic,nucleic,inhibit,phage,acr,bind
# cv_phrases crispr,acrif9,dsdna,protein,genetic,nucleic,inhibit,phage,acr,bind
# tfidf_keywords crispr acrif1,crispr rna,inhibit crispr,crispr protein,block dna
# tfidf_phrases crispr acrif1,crispr rna,inhibit crispr,crispr protein,block dna
# cv_keywords crispr,prokaryote,virus,crrnas,genome,archaeal,bacteria,controlled,immunity,nuclease
# cv_phrases crispr,prokaryote,virus,crrnas,genome,archaeal,bacteria,controlled,immunity,nuclease
# tfidf_keywords crispr archaea,crispr rna,genomic crispr,prokaryote constantly,attack virus
# tfidf_phrases crispr archaea,crispr rna,genomic crispr,prokaryote constantly,attack virus
# cv_keywords crispr,future,genetic,chemist,frontier,research,rapid,creative,pressing,genome
# cv_phrases crispr,future,genetic,chemist,frontier,research,rapid,creative,pressing,genome
# tfidf_keywords crispr researchers,engineering crispr,approach genetic,future genome,crispr
# tfidf_phrases crispr researchers,engineering crispr,approach genetic,future genome,crispr
# cv_keywords crispr,hdad5,gene,transplantation,thalassemia,cas9,vitro,adenovirus,hematopoietic,progenitor
# cv_phrases crispr,hdad5,gene,transplantation,thalassemia,cas9,vitro,adenovirus,hematopoietic,progenitor
# tfidf_keywords hdad crispr,gene therapy,cas9 gene,crispr cas9,sickle cell
# tfidf_phrases hdad crispr,gene therapy,cas9 gene,crispr cas9,sickle cell
# cv_keywords crispr,cas9,bacterial,genome,fncas9,targeting,endonuclease,nuclease,novicida,type
# cv_phrases crispr,cas9,bacterial,genome,fncas9,targeting,endonuclease,nuclease,novicida,type
# tfidf_keywords bacterial crispr,crispr targeting,crispr cas,diverse crispr,crispr strategy
# tfidf_phrases bacterial crispr,crispr targeting,crispr cas,diverse crispr,crispr strategy
# cv_keywords crispr,bacteria,rnase,acriiib1,cas,virus,subtype,immunity,protein,archaea
# cv_phrases crispr,bacteria,rnase,acriiib1,cas,virus,subtype,immunity,protein,archaea
# tfidf_keywords crispr cas,bacteria archaea,diversity crispr,inhibits crispr,collateral rnase
# tfidf_phrases crispr cas,bacteria archaea,diversity crispr,inhibits crispr,collateral rnase
# cv_keywords crisprs,bacteria,evolve,phage,anti,counterstrategies,protein,mechanism,race,immune
# cv_phrases crisprs,bacteria,evolve,phage,anti,counterstrategies,protein,mechanism,race,immune
# tfidf_keywords crisprs bacterial,phage evolve,evolve counterstrategies,bacterial evolution,development crispr
# tfidf_phrases crisprs bacterial,phage evolve,evolve counterstrategies,bacterial evolution,development crispr
# cv_keywords crispr,prokaryote,resistance,gene,pseudomonas,phage,cas,type,inhibitor,hypothesis
# cv_phrases crispr,prokaryote,resistance,gene,pseudomonas,phage,cas,type,inhibitor,hypothesis
# tfidf_keywords crispr gene,phage resistance,gene phage,inhibit type,anti crispr
# tfidf_phrases crispr gene,phage resistance,gene phage,inhibit type,anti crispr
# cv_keywords crispr,bacterial,facilitation,phage,blocking,spacer,sequence,mechanism,immunity,adaptation
# cv_phrases crispr,bacterial,facilitation,phage,blocking,spacer,sequence,mechanism,immunity,adaptation
# tfidf_keywords facilitation crispr,role bacterial,blocking phage,sequence adaptation,sequence crispr
# tfidf_phrases facilitation crispr,role bacterial,blocking phage,sequence adaptation,sequence crispr
# cv_keywords crispr,liposome,cas9,formulation,liposomal,ligand,carriers,pegylated,delivery,barrier
# cv_phrases crispr,liposome,cas9,formulation,liposomal,ligand,carriers,pegylated,delivery,barrier
# tfidf_keywords liposomal crispr,systemic crispr,liposomal carrier,carrier crispr,crispr cas9
# tfidf_phrases liposomal crispr,systemic crispr,liposomal carrier,carrier crispr,crispr cas9
# cv_keywords crispr,gene,cas1,adaptation,memory,fragment,core,spacer,conserved,reduction
# cv_phrases crispr,gene,cas1,adaptation,memory,fragment,core,spacer,conserved,reduction
# tfidf_keywords crispr adaptation,adaptation gene,region crispr,leader crispr,memory formation
# tfidf_phrases crispr adaptation,adaptation gene,region crispr,leader crispr,memory formation
# cv_keywords genome,crispr,prokaryote,catalytic,pathway,gene,efficient,biology,engineered,metabolic
# cv_phrases genome,crispr,prokaryote,catalytic,pathway,gene,efficient,biology,engineered,metabolic
# tfidf_keywords genome editing,gene pathway,development crispr,engineering genome,effective metabolic
# tfidf_phrases genome editing,gene pathway,development crispr,engineering genome,effective metabolic
# cv_keywords genome,cas9,cpf1,crispr,bacteria,biotechnology,immunity,nuclease,mutagenesis,rna
# cv_phrases genome,cas9,cpf1,crispr,bacteria,biotechnology,immunity,nuclease,mutagenesis,rna
# tfidf_keywords crispr rna,genome editing,crispr cas9,mutagenesis cpf1,bacteria achieve
# tfidf_phrases crispr rna,genome editing,crispr cas9,mutagenesis cpf1,bacteria achieve
# cv_keywords crispr,genome,cas9,modification,regularly,clustered,system,protein,rapid,repeat
# cv_phrases crispr,genome,cas9,modification,regularly,clustered,system,protein,rapid,repeat
# tfidf_keywords repeat crispr,genome editing,crispr cas9,improvement crispr,advance crispr
# tfidf_phrases repeat crispr,genome editing,crispr cas9,improvement crispr,advance crispr
# cv_keywords crispr,genomics,antiviral,research,bioinformatics,genome,microbial,acronym,regularly,archaea
# cv_phrases crispr,genomics,antiviral,research,bioinformatics,genome,microbial,acronym,regularly,archaea
# tfidf_keywords crispr research,crispr antiviral,genomics microbial,discovery crispr,crispr acronym
# tfidf_phrases crispr research,crispr antiviral,genomics microbial,discovery crispr,crispr acronym
# cv_keywords crispr,kidney,nuclease,gene,therapy,organoids,control,validate,nephrotic,pluripotent
# cv_phrases crispr,kidney,nuclease,gene,therapy,organoids,control,validate,nephrotic,pluripotent
# tfidf_keywords crispr kidney,crispr nuclease,disease crispr,gene editing,study crispr
# tfidf_phrases crispr kidney,crispr nuclease,disease crispr,gene editing,study crispr
# cv_keywords crispr,cyanobacteria,genome,cas1,pcc,type,spacer,strains,clustered,recombination
# cv_phrases crispr,cyanobacteria,genome,cas1,pcc,type,spacer,strains,clustered,recombination
# tfidf_keywords diversity crispr,cyanobacteria diversity,potential genome,crispr cas,system crispr
# tfidf_phrases diversity crispr,cyanobacteria diversity,potential genome,crispr cas,system crispr
# cv_keywords streptococci,crispr,microbiota,genetic,immunity,bacteria,type,protein,respiratory,urogenital
# cv_phrases streptococci,crispr,microbiota,genetic,immunity,bacteria,type,protein,respiratory,urogenital
# tfidf_keywords streptococci one,crispr associated,host microbiota,streptococci reviewed,system streptococci
# tfidf_phrases streptococci one,crispr associated,host microbiota,streptococci reviewed,system streptococci
# cv_keywords sgrnas,crispr,bioinformatics,cas9,genome,rna,efficacy,system,editing,sgrna
# cv_phrases sgrnas,crispr,bioinformatics,cas9,genome,rna,efficacy,system,editing,sgrna
# tfidf_keywords crispr rna,design sgrnas,potent sgrnas,efficiency sgrnas,sgrnas improved
# tfidf_phrases crispr rna,design sgrnas,potent sgrnas,efficiency sgrnas,sgrnas improved
# cv_keywords crispr,acriic3,cas9,inhibits,bacterial,dna,protein,neisseria,meningitidis,acrs
# cv_phrases crispr,acriic3,cas9,inhibits,bacterial,dna,protein,neisseria,meningitidis,acrs
# tfidf_keywords crispr cas9,cas9 acriic3,protein acrs,cas9 inhibition,anti crispr
# tfidf_phrases crispr cas9,cas9 acriic3,protein acrs,cas9 inhibition,anti crispr
# cv_keywords crispr,bacteria,nuclease,genome,plasmid,immunity,phagemids,engineered,antimicrobials,targeting
# cv_phrases crispr,bacteria,nuclease,genome,plasmid,immunity,phagemids,engineered,antimicrobials,targeting
# tfidf_keywords targeting crispr,lethal bacteria,crispr cas,nuclease bacteria,development crispr
# tfidf_phrases targeting crispr,lethal bacteria,crispr cas,nuclease bacteria,development crispr
# cv_keywords crispr,bacterial,cas1,adaptation,genome,integrase,immunity,step,virus,spacers
# cv_phrases crispr,bacterial,cas1,adaptation,genome,integrase,immunity,step,virus,spacers
# tfidf_keywords bacterial crispr,adaptation step,crispr adaptation,cas2 integrase,adaptation protein
# tfidf_phrases bacterial crispr,adaptation step,crispr adaptation,cas2 integrase,adaptation protein
# cv_keywords crispr,cas12a,genome,cpf1,immune,bioinformatic,microbial,targeting,nuclease,protein
# cv_phrases crispr,cas12a,genome,cpf1,immune,bioinformatic,microbial,targeting,nuclease,protein
# tfidf_keywords cpf1 crispr,crispr cas12a,crisprs microbial,genome editing,cas9 crispr
# tfidf_phrases cpf1 crispr,crispr cas12a,crisprs microbial,genome editing,cas9 crispr
# cv_keywords crispr,rna,seminal,bacteria,gene,prokaryote,system,cas,dna,type
# cv_phrases crispr,rna,seminal,bacteria,gene,prokaryote,system,cas,dna,type
# tfidf_keywords crispr system,rna targets,tool bacteria,seminal study,gene editing
# tfidf_phrases crispr system,rna targets,tool bacteria,seminal study,gene editing
# cv_keywords crispr,sequencing,perturb,bacterial,component,ca,gene,cas,editing,genome
# cv_phrases crispr,sequencing,perturb,bacterial,component,ca,gene,cas,editing,genome
# tfidf_keywords crispr ca,crispr genetic,adaptation crispr,crispr knockout,referred crispr
# tfidf_phrases crispr ca,crispr genetic,adaptation crispr,crispr knockout,referred crispr
# cv_keywords crispr,patent,biosciences,coronavirus,companies,nuclease,nanotechnology,research,application,technology
# cv_phrases crispr,patent,biosciences,coronavirus,companies,nuclease,nanotechnology,research,application,technology
# tfidf_keywords crispr patent,crispr technology,patented crispr,crispr nuclease,application crispr
# tfidf_phrases crispr patent,crispr technology,patented crispr,crispr nuclease,application crispr
# cv_keywords crispr,cas13,biotechnologies,nuclease,genome,reshaped,discus,mechanism,nucleic,immune
# cv_phrases crispr,cas13,biotechnologies,nuclease,genome,reshaped,discus,mechanism,nucleic,immune
# tfidf_keywords crispr gene,cas9 crispr,genome editing,crispr cas12a,mechanism crispr
# tfidf_phrases crispr gene,cas9 crispr,genome editing,crispr cas12a,mechanism crispr
# cv_keywords leptospira,genetic,pathogenic,crispr,inaccessibility,bacteria,leptospirosis,serotypes,zoonotic,genome
# cv_phrases leptospira,genetic,pathogenic,crispr,inaccessibility,bacteria,leptospirosis,serotypes,zoonotic,genome
# tfidf_keywords genome leptospira,genetic inaccessibility,pathogenic leptospira,inaccessibility leptospira,gene crispr
# tfidf_phrases genome leptospira,genetic inaccessibility,pathogenic leptospira,inaccessibility leptospira,gene crispr
# cv_keywords cas9,crispr,crrnas,plasmid,virus,rna,dgcc7710,streptococcus,csn,type
# cv_phrases cas9,crispr,crrnas,plasmid,virus,rna,dgcc7710,streptococcus,csn,type
# tfidf_keywords crrnas crispr,cas9 protein,crispr cas,virus plasmid,biogenesis crispr
# tfidf_phrases crrnas crispr,cas9 protein,crispr cas,virus plasmid,biogenesis crispr
# cv_keywords crispr2,gene,mdr,enterococcus,resistant,cas,crispr,multidrug,genome,prokaryote
# cv_phrases crispr2,gene,mdr,enterococcus,resistant,cas,crispr,multidrug,genome,prokaryote
# tfidf_keywords crispr locus,resistant mdr,crispr cas,crispr2 lacking,genome defense
# tfidf_phrases crispr locus,resistant mdr,crispr cas,crispr2 lacking,genome defense
# cv_keywords crispr,cas9,biotechnology,screening,gene,influence,editing,pharmaceutical,genomic,discovery
# cv_phrases crispr,cas9,biotechnology,screening,gene,influence,editing,pharmaceutical,genomic,discovery
# tfidf_keywords crispr screening,crispr cas9,discovery crispr,genomic strategy,validation crispr
# tfidf_phrases crispr screening,crispr cas9,discovery crispr,genomic strategy,validation crispr
# cv_keywords crispr,hiv,screening,cas9,genome,virology,throughput,virus,discovery,assay
# cv_phrases crispr,hiv,screening,cas9,genome,virology,throughput,virus,discovery,assay
# tfidf_keywords hiv crispr,crispr screening,screening crispr,crispr cas9,efficient screening
# tfidf_phrases hiv crispr,crispr screening,screening crispr,crispr cas9,efficient screening
# cv_keywords bacterial,crispr,cas9,inhibitors,bacteriophage,genome,listeria,protein,type,spacer
# cv_phrases bacterial,crispr,cas9,inhibitors,bacteriophage,genome,listeria,protein,type,spacer
# tfidf_keywords bacterial crispr,defend bacteriophage,bacterial genome,crispr cas9,listeria monocytogenes
# tfidf_phrases bacterial crispr,defend bacteriophage,bacterial genome,crispr cas9,listeria monocytogenes
# cv_keywords crispr,epigenetic,clustered,control,protein,regularly,genome,cas,modulation,arbitrarily
# cv_phrases crispr,epigenetic,clustered,control,protein,regularly,genome,cas,modulation,arbitrarily
# tfidf_keywords inducible crispr,control crispr,crispr associated,repeat crispr,crispr cas
# tfidf_phrases inducible crispr,control crispr,crispr associated,repeat crispr,crispr cas
# cv_keywords crispr,pseudomonas,crrna,protein,immunity,bacteriophage,acrf2,clustered,nucleotide,phage
# cv_phrases crispr,pseudomonas,crrna,protein,immunity,bacteriophage,acrf2,clustered,nucleotide,phage
# tfidf_keywords crispr rna,complex crispr,ca protein,crrna acrf2,infects pseudomonas
# tfidf_phrases crispr rna,complex crispr,ca protein,crrna acrf2,infects pseudomonas
# cv_keywords gene,crispr,cpf1,plant,targeting,genome,development,epfl9,phenotypic,editing
# cv_phrases gene,crispr,cpf1,plant,targeting,genome,development,epfl9,phenotypic,editing
# tfidf_keywords gene generation,crispr cpf1,gene targeting,development crispr,capable genome
# tfidf_phrases gene generation,crispr cpf1,gene targeting,development crispr,capable genome
# cv_keywords prokaryotic,crispr,viral,crrnas,genome,cas9,invader,protein,rna,bacteriology
# cv_phrases prokaryotic,crispr,viral,crrnas,genome,cas9,invader,protein,rna,bacteriology
# tfidf_keywords crispr rna,prokaryotic immunity,viral predator,invading genomes,crispr locus
# tfidf_phrases crispr rna,prokaryotic immunity,viral predator,invading genomes,crispr locus
# cv_keywords crispr,genome,edit,cas9,treatment,mutation,hemophila,alzheimer,chapter,vitro
# cv_phrases crispr,genome,edit,cas9,treatment,mutation,hemophila,alzheimer,chapter,vitro
# tfidf_keywords genome editing,crispr cas9,use genome,edit dna,protein crispr
# tfidf_phrases genome editing,crispr cas9,use genome,edit dna,protein crispr
# cv_keywords cas9,crispr,mir,gene,targeted,hepatocytes,cardiac,sgrnas,acriic1,therapy
# cv_phrases cas9,crispr,mir,gene,targeted,hepatocytes,cardiac,sgrnas,acriic1,therapy
# tfidf_keywords crispr cas,mirna regulated,cas9 sgrnas,cas9 efficiently,crispr protein
# tfidf_phrases crispr cas,mirna regulated,cas9 sgrnas,cas9 efficiently,crispr protein
# cv_keywords crispr,plasmid,clone,bacteriophage,nucleic,protospacer,resistance,genomic,prokaryote,cas
# cv_phrases crispr,plasmid,clone,bacteriophage,nucleic,protospacer,resistance,genomic,prokaryote,cas
# tfidf_keywords genomic crispr,crispr activated,crispr mediated,crispr cas,crispr locus
# tfidf_phrases genomic crispr,crispr activated,crispr mediated,crispr cas,crispr locus
# cv_keywords crispr,viral,cas9,therapy,repeat,revolutionized,furthering,genome,tool,effective
# cv_phrases crispr,viral,cas9,therapy,repeat,revolutionized,furthering,genome,tool,effective
# tfidf_keywords crispr viral,development crispr,repeat crispr,crispr cas9,genome surgery
# tfidf_phrases crispr viral,development crispr,repeat crispr,crispr cas9,genome surgery
# cv_keywords crispr,spotlight,rounding,still
# cv_phrases crispr,spotlight,rounding,still
# tfidf_keywords beginning crispr,crispr journey,spotlight crispr,crispr still,crispr
# tfidf_phrases beginning crispr,crispr journey,spotlight crispr,crispr still,crispr
# cv_keywords crispr,gene,disruptive,zebrafish,cas9,immune,bacteria,mechanism,efficacy,mutational
# cv_phrases crispr,gene,disruptive,zebrafish,cas9,immune,bacteria,mechanism,efficacy,mutational
# tfidf_keywords applicability crispr,gene editing,crispr cas9,gene therapies,model gene
# tfidf_phrases applicability crispr,gene editing,crispr cas9,gene therapies,model gene
# cv_keywords crispr,cas13a,rna,plasmid,virus,immunity,gene,bacteria,vi,repurposing
# cv_phrases crispr,cas13a,rna,plasmid,virus,immunity,gene,bacteria,vi,repurposing
# tfidf_keywords crispr cas13a,protection rna,infection crispr,plasmid dna,viral gene
# tfidf_phrases crispr cas13a,protection rna,infection crispr,plasmid dna,viral gene
# cv_keywords crispr,diagnostic,better,molecular,sensitivity,cas,tool,rapid,pathogen,assay
# cv_phrases crispr,diagnostic,better,molecular,sensitivity,cas,tool,rapid,pathogen,assay
# tfidf_keywords specificity crispr,crispr cas,sensitive crispr,diagnostic platforms,crispr predominant
# tfidf_phrases specificity crispr,crispr cas,sensitive crispr,diagnostic platforms,crispr predominant
# cv_keywords bacteria,crispr,archaea,rna,cas9,immune,nucleic,metagenomic,virus,plasmid
# cv_phrases bacteria,crispr,archaea,rna,cas9,immune,nucleic,metagenomic,virus,plasmid
# tfidf_keywords archaea crispr,bacteria archaea,rna guided,bacteriophage virus,cas9 protein
# tfidf_phrases archaea crispr,bacteria archaea,rna guided,bacteriophage virus,cas9 protein
# cv_keywords crispr,nuclease,genome,chromatin,modulating,tool,dna,versatile,clustered,repeat
# cv_phrases crispr,nuclease,genome,chromatin,modulating,tool,dna,versatile,clustered,repeat
# tfidf_keywords application crispr,elevate crispr,engineering crispr,crispr including,crispr tool
# tfidf_phrases application crispr,elevate crispr,engineering crispr,crispr including,crispr tool
# cv_keywords crispr,archaea,immunity,genetic,adaptive,phage,inactivate,bacteria,proteins,widespread
# cv_phrases crispr,archaea,immunity,genetic,adaptive,phage,inactivate,bacteria,proteins,widespread
# tfidf_keywords crispr proteins,adaptive immune,bacteria archaea,inactivate crispr,crispr cas
# tfidf_phrases crispr proteins,adaptive immune,bacteria archaea,inactivate crispr,crispr cas
# cv_keywords crispr,testing,coronavirus,nucleic,pcr,orf1ab,cas12b,fluorescence,assay,diagnostic
# cv_phrases crispr,testing,coronavirus,nucleic,pcr,orf1ab,cas12b,fluorescence,assay,diagnostic
# tfidf_keywords existing crispr,crispr cas12b,crispr mediated,diagnostic test,amplification crispr
# tfidf_phrases existing crispr,crispr cas12b,crispr mediated,diagnostic test,amplification crispr
# cv_keywords crispr,genomic,editing,biomedical,regularly,cas9s,optimized,research,genome,engineered
# cv_phrases crispr,genomic,editing,biomedical,regularly,cas9s,optimized,research,genome,engineered
# tfidf_keywords development crispr,genomic editing,engineered crispr,crispr use,repeat crispr
# tfidf_phrases development crispr,genomic editing,engineered crispr,crispr use,repeat crispr
# cv_keywords crispr,enzyme,testing,cas13,assay,covid,reaction,surge,pandemic,analytical
# cv_phrases crispr,enzyme,testing,cas13,assay,covid,reaction,surge,pandemic,analytical
# tfidf_keywords crispr enzyme,crispr diagnostics,crispr reaction,crispr diagnostic,enzyme kinetics
# tfidf_phrases crispr enzyme,crispr diagnostics,crispr reaction,crispr diagnostic,enzyme kinetics
# cv_keywords crispr,crrnas,nucleic,cas,plasmid,protein,clustered,virus,immunity,spacers
# cv_phrases crispr,crrnas,nucleic,cas,plasmid,protein,clustered,virus,immunity,spacers
# tfidf_keywords crispr rna,crispr cas,crispr mediated,biogenesis crispr,archaea crispr
# tfidf_phrases crispr rna,crispr cas,crispr mediated,biogenesis crispr,archaea crispr
# cv_keywords crispr,genome
# cv_phrases crispr,genome
# tfidf_keywords discovery crispr,genome evolution,crispr cas,adaptive immune,role crispr
# tfidf_phrases discovery crispr,genome evolution,crispr cas,adaptive immune,role crispr
# cv_keywords genome,crispr,prokaryotic,immunity,subtypes,archaeal,bacteria,clustered,phylogenetic,genomic
# cv_phrases genome,crispr,prokaryotic,immunity,subtypes,archaeal,bacteria,clustered,phylogenetic,genomic
# tfidf_keywords subtypes crispr,bacterial genome,gene repertoire,cas genomic,prokaryotic adaptive
# tfidf_phrases subtypes crispr,bacterial genome,gene repertoire,cas genomic,prokaryotic adaptive
# cv_keywords biosecurity,crispr,revolutionizing,biotechnologies,risk,research,reduce,genome,misuse,technology
# cv_phrases biosecurity,crispr,revolutionizing,biotechnologies,risk,research,reduce,genome,misuse,technology
# tfidf_keywords sciences crispr,reduce biosecurity,misuse biotechnologies,biosecurity risk,crispr genome
# tfidf_phrases sciences crispr,reduce biosecurity,misuse biotechnologies,biosecurity risk,crispr genome
# cv_keywords crispr,recombinants,genome,plasmid,cpf1,bacteria,cas12a,gene,deletions,recombineering
# cv_phrases crispr,recombinants,genome,plasmid,cpf1,bacteria,cas12a,gene,deletions,recombineering
# tfidf_keywords bacteria crispr,effective genome,crispr cas12a,recombinants efficient,genome editing
# tfidf_phrases bacteria crispr,effective genome,crispr cas12a,recombinants efficient,genome editing
# cv_keywords crispr,bacteriophage,protein,crrna,susceptibility,coli,cse1,phage,genome,immunology
# cv_phrases crispr,bacteriophage,protein,crrna,susceptibility,coli,cse1,phage,genome,immunology
# tfidf_keywords crispr mediated,bacteriophage p1,protein crp,crispr cas,crispr deletion
# tfidf_phrases crispr mediated,bacteriophage p1,protein crp,crispr cas,crispr deletion
# cv_keywords crispr,immune,genome,bacteriophage,nucleic,decode,control,biomedical,immunotherapy,adoption
# cv_phrases crispr,immune,genome,bacteriophage,nucleic,decode,control,biomedical,immunotherapy,adoption
# tfidf_keywords crispr technology,immunotherapy crispr,crispr provides,application crispr,review crispr
# tfidf_phrases crispr technology,immunotherapy crispr,crispr provides,application crispr,review crispr
# cv_keywords crispr,rna,targeting,cas9,bacterial,plasmid,dna,clustered,molecular,endonuclease
# cv_phrases crispr,rna,targeting,cas9,bacterial,plasmid,dna,clustered,molecular,endonuclease
# tfidf_keywords crispr rna,target dna,crispr cas9,bacterial clustered,rna target
# tfidf_phrases crispr rna,target dna,crispr cas9,bacterial clustered,rna target
# cv_keywords sgrnas,crispr,endonuclease,protospacer,rna,targeting,pam,program,efficient,biootools
# cv_phrases sgrnas,crispr,endonuclease,protospacer,rna,targeting,pam,program,efficient,biootools
# tfidf_keywords flexible sgrna,application crispr,designing sgrna,rna guided,rna sgrnas
# tfidf_phrases flexible sgrna,application crispr,designing sgrna,rna guided,rna sgrnas
# cv_keywords crf,crispr,bioinfolab,classifier,clustered,genome,accuracy,spacers,filter,regularly
# cv_phrases crf,crispr,bioinfolab,classifier,clustered,genome,accuracy,spacers,filter,regularly
# tfidf_keywords crf crispr,accuracy crf,crispr detection,crf filter,repeat classifier
# tfidf_phrases crf crispr,accuracy crf,crispr detection,crf filter,repeat classifier
# cv_keywords crispr,rna,bacterial,genomic,nucleic,untranslated,transcription,cas,immunity,sequence
# cv_phrases crispr,rna,bacterial,genomic,nucleic,untranslated,transcription,cas,immunity,sequence
# ...
# tfidf_keywords crispr associated,genome editing,crispr cas9,response crispr,studied crispr
# tfidf_phrases crispr associated,genome editing,crispr cas9,response crispr,studied crispr
# cv_keywords genome,crisprs,cas,prokaryote,immune,locus,nucleic,spacer,deactivate,genomic
# cv_phrases genome,crisprs,cas,prokaryote,immune,locus,nucleic,spacer,deactivate,genomic
# tfidf_keywords crispr genomic,ca locus,crisprs genome,locus crisprs,gene crispr
# tfidf_phrases crispr genomic,ca locus,crisprs genome,locus crisprs,gene crispr
# cv_keywords crispr,plasmid,cas9,ca,targeted,genome,viral,spacer,dosage,regularly
# cv_phrases crispr,plasmid,cas9,ca,targeted,genome,viral,spacer,dosage,regularly
# tfidf_keywords required crispr,crispr cas9,delivery crispr,crispr component,vivo crispr
# tfidf_phrases required crispr,crispr cas9,delivery crispr,crispr component,vivo crispr
# cv_keywords cyanobacterial,crispr,cas12a,genome,photosynthetic,co2,chemical,microorganism,capable,type
# cv_phrases cyanobacterial,crispr,cas12a,genome,photosynthetic,co2,chemical,microorganism,capable,type
# tfidf_keywords engineering cyanobacteria,synthetic crispr,cyanobacterial genomics,cyanobacteria synthetic,genome engineering
# tfidf_phrases engineering cyanobacteria,synthetic crispr,cyanobacterial genomics,cyanobacteria synthetic,genome engineering
# cv_keywords bacterial,crispr,immunity,extracellular,virulence,nucleic,prokaryotic,adapt,effect,regulation
# cv_phrases bacterial,crispr,immunity,extracellular,virulence,nucleic,prokaryotic,adapt,effect,regulation
# tfidf_keywords regulation crispr,bacterial cell,respond extracellular,adaptive immunity,invading nucleic
# tfidf_phrases regulation crispr,bacterial cell,respond extracellular,adaptive immunity,invading nucleic
# cv_keywords cloning,sgrna,crispr,gene,plasmid,cas9,modify,sccrispr,recombination,genomic
# cv_phrases cloning,sgrna,crispr,gene,plasmid,cas9,modify,sccrispr,recombination,genomic
# tfidf_keywords gene editing,sgrna plasmid,cloning crispr,crispr gene,plasmid cloning
# tfidf_phrases gene editing,sgrna plasmid,cloning crispr,crispr gene,plasmid cloning
# cv_keywords crispr,prevotella,genome,cpf1,repeat,clustered,editing,cas9,protein,francisella
# cv_phrases crispr,prevotella,genome,cpf1,repeat,clustered,editing,cas9,protein,francisella
# tfidf_keywords crispr prevotella,efficient genome,repeat crispr,protein crispr,crispr cas9
# tfidf_phrases crispr prevotella,efficient genome,repeat crispr,protein crispr,crispr cas9
# cv_keywords crispr,mirnas,inhibited,cas9,gene,rnai,editing,enoxacin,enhancer,targeting
# cv_phrases crispr,mirnas,inhibited,cas9,gene,rnai,editing,enoxacin,enhancer,targeting
# tfidf_keywords inhibited crispr,rnai enhancer,artificial mirnas,crispr cas9,genome editing
# tfidf_phrases inhibited crispr,rnai enhancer,artificial mirnas,crispr cas9,genome editing
# cv_keywords crispr,grna,molecular,design,curation,gene,amino,cpu,tool,protein
# cv_phrases crispr,grna,molecular,design,curation,gene,amino,cpu,tool,protein
# tfidf_keywords protein crispr,grna design,molecular engineering,protein grna,gene centric
# tfidf_phrases protein crispr,grna design,molecular engineering,protein grna,gene centric
# cv_keywords crispr,bacterial,inhibitory,cas,immune,genetic,encode,rna,adaptive,phage
# cv_phrases crispr,bacterial,inhibitory,cas,immune,genetic,encode,rna,adaptive,phage
# tfidf_keywords bacterial crispr,crispr cas,adaptive immune,anti crispr,protein crispr
# tfidf_phrases bacterial crispr,crispr cas,adaptive immune,anti crispr,protein crispr
# cv_keywords crispr,saccharomyces,gene,plasmid,mutagenizing,recombination,dsdna,cerevisiae,cas9,clustered
# cv_phrases crispr,saccharomyces,gene,plasmid,mutagenizing,recombination,dsdna,cerevisiae,cas9,clustered
# tfidf_keywords gene crispr,gene disruption,simultaneously cerevisiae,repeat crispr,dsdna mutagenizing
# tfidf_phrases gene crispr,gene disruption,simultaneously cerevisiae,repeat crispr,dsdna mutagenizing
# cv_keywords crispr,microinjection,mouse,genome,6n,optimized,genotyping,c57bl,embryo,pronuclear
# cv_phrases crispr,microinjection,mouse,genome,6n,optimized,genotyping,c57bl,embryo,pronuclear
# tfidf_keywords microinjecting crispr,mouse generation,crispr reagent,developed crispr,genome editing
# tfidf_phrases microinjecting crispr,mouse generation,crispr reagent,developed crispr,genome editing
# cv_keywords crispr,genome,modified,recombination,cas,regularly,epigenetic,clustered,protein,targeting
# cv_phrases crispr,genome,modified,recombination,cas,regularly,epigenetic,clustered,protein,targeting
# tfidf_keywords regulation crispr,crispr component,genome editing,targeted crispr,repeat crispr
# tfidf_phrases regulation crispr,crispr component,genome editing,targeted crispr,repeat crispr
# cv_keywords crispr,photoactivation,gene,control,cas9
# cv_phrases crispr,photoactivation,gene,control,cas9
# tfidf_keywords application crispr,control gene,targeted gene,photoactivation multiple,crispr cas9
# tfidf_phrases application crispr,control gene,targeted gene,photoactivation multiple,crispr cas9
# cv_keywords crispr,genome,plasmid,editing,virus,research,mutations,yeast,endogenous,molecular
# cv_phrases crispr,genome,plasmid,editing,virus,research,mutations,yeast,endogenous,molecular
# tfidf_keywords endogenous crispr,genome editing,plasmid crispr,search crispr,crispr mechanism
# tfidf_phrases endogenous crispr,genome editing,plasmid crispr,search crispr,crispr mechanism
# cv_keywords crispr,vision,modification,gene,zebrafish,cas,targeted,ca,stem,etiology
# cv_phrases crispr,vision,modification,gene,zebrafish,cas,targeted,ca,stem,etiology
# tfidf_keywords implementation crispr,eye development,gene therapy,modification zebrafish,enhance genome
# tfidf_phrases implementation crispr,eye development,gene therapy,modification zebrafish,enhance genome
# cv_keywords crispr,dnase,biosensing,gene,cas12a,clustered,minireview,repeat,rna,nuclease
# cv_phrases crispr,dnase,biosensing,gene,cas12a,clustered,minireview,repeat,rna,nuclease
# tfidf_keywords crispr promising,cas12a crispr,biosensing gene,repeat crispr,mechanism crispr
# tfidf_phrases crispr promising,cas12a crispr,biosensing gene,repeat crispr,mechanism crispr
# cv_keywords crispr,genome,editing,repeat,oligonucleotides,synthesis,rapid,programmability,clustered,targeted
# cv_phrases crispr,genome,editing,repeat,oligonucleotides,synthesis,rapid,programmability,clustered,targeted
# tfidf_keywords programmability crispr,repeat crispr,genome editing,crispr system,crispr using
# tfidf_phrases programmability crispr,repeat crispr,genome editing,crispr system,crispr using
# cv_keywords crispr,cas9,genome,screening,versatility,grnas,libraries,rna,experiment,knockout
# cv_phrases crispr,cas9,genome,screening,versatility,grnas,libraries,rna,experiment,knockout
# tfidf_keywords crispr cas9,crispr libraries,crispr library,suited genome,using crispr
# tfidf_phrases crispr cas9,crispr libraries,crispr library,suited genome,using crispr
# cv_keywords crispr,antiviral,genome,revolutionized,bacterial,editing,immunotherapy,technologies,boosting,mutant
# cv_phrases crispr,antiviral,genome,revolutionized,bacterial,editing,immunotherapy,technologies,boosting,mutant
# tfidf_keywords development crispr,application crispr,engineered crispr,crispr technology,editing crispr
# tfidf_phrases development crispr,application crispr,engineered crispr,crispr technology,editing crispr
# cv_keywords crispr,genome,modification,cas9,endonuclease,immune,selection,mutation,targeting,microbial
# cv_phrases crispr,genome,modification,cas9,endonuclease,immune,selection,mutation,targeting,microbial
# tfidf_keywords genome editing,crispr system,performs gene,endowing genome,modification cas9
# tfidf_phrases genome editing,crispr system,performs gene,endowing genome,modification cas9
# cv_keywords genomic,crispr,immune,prokaryotic,microbial,virus,coevolution,metagenomic,innate,archaea
# cv_phrases genomic,crispr,immune,prokaryotic,microbial,virus,coevolution,metagenomic,innate,archaea
# tfidf_keywords crispr microbial,prokaryotic genomic,ancestral immune,virus coevolution,genomic conservation
# tfidf_phrases crispr microbial,prokaryotic genomic,ancestral immune,virus coevolution,genomic conservation
# cv_keywords crispr,prediction,bias,gene,ots,optimized,benchmark,overestimated,data,avoid
# cv_phrases crispr,prediction,bias,gene,ots,optimized,benchmark,overestimated,data,avoid
# tfidf_keywords benchmark crispr,ots prediction,crispr based,crispr gene,crispr target
# tfidf_phrases benchmark crispr,ots prediction,crispr based,crispr gene,crispr target
# cv_keywords microbiome,crispr,virus,genome,prokaryotic,bacteriophage,organism,bacterial,microorganism,immune
# cv_phrases microbiome,crispr,virus,genome,prokaryotic,bacteriophage,organism,bacterial,microorganism,immune
# tfidf_keywords bacteriophage crispr,microbiome finally,eukaryote virus,genome gut,prokaryotic crispr
# tfidf_phrases bacteriophage crispr,microbiome finally,eukaryote virus,genome gut,prokaryotic crispr
# cv_keywords crispr,genetic,would,healthy,modification,potential,embryos,compete,cas9,moral
# cv_phrases crispr,genetic,would,healthy,modification,potential,embryos,compete,cas9,moral
# tfidf_keywords claim crispr,healthy genetically,crispr life,crispr modification,genetic modification
# tfidf_phrases claim crispr,healthy genetically,crispr life,crispr modification,genetic modification
# cv_keywords crispr,rna,plasmid,cas9,genome,prokaryotic,immune,nucleic,protein,bacteriophage
# cv_phrases crispr,rna,plasmid,cas9,genome,prokaryotic,immune,nucleic,protein,bacteriophage
# tfidf_keywords crispr rna,prokaryotic crispr,genome crispr,crispr cas,crispr derived
# tfidf_phrases crispr rna,prokaryotic crispr,genome crispr,crispr cas,crispr derived
# cv_keywords viruses,crispr,prokaryotes,genome,resistance,immunity,cas9,nucleic,bacteriophage,mammal
# cv_phrases viruses,crispr,prokaryotes,genome,resistance,immunity,cas9,nucleic,bacteriophage,mammal
# tfidf_keywords prokaryotes crispr,combat virus,cas9 crispr,virus eukaryotes,destroy nucleic
# tfidf_phrases prokaryotes crispr,combat virus,cas9 crispr,virus eukaryotes,destroy nucleic
# cv_keywords crispr,archaeal,immune,nucleic,intergenomic,crrnas,targeting,likely,rna,cmr
# cv_phrases crispr,archaeal,immune,nucleic,intergenomic,crrnas,targeting,likely,rna,cmr
# tfidf_keywords archaeal crispr,crispr rna,crrnas targeting,based immune,crispr locus
# tfidf_phrases archaeal crispr,crispr rna,crrnas targeting,based immune,crispr locus
# cv_keywords crispr,cas6,rna,crea,toxin,bacteriostatic,immunity,regulates,gene,protein
# cv_phrases crispr,cas6,rna,crea,toxin,bacteriostatic,immunity,regulates,gene,protein
# tfidf_keywords crispr rna,crea crispr,bacterial crispr,cas regulation,crispr cas
# tfidf_phrases crispr rna,crea crispr,bacterial crispr,cas regulation,crispr cas
# cv_keywords genome,recombination,crispr,deletion,chromosomal,pcd,replacement,strand,manipulating,homologous
# cv_phrases genome,recombination,crispr,deletion,chromosomal,pcd,replacement,strand,manipulating,homologous
# tfidf_keywords genome manipulation,chromosomal deletion,versatile genome,homologous recombination,genome editing
# tfidf_phrases genome manipulation,chromosomal deletion,versatile genome,homologous recombination,genome editing
# cv_keywords crispr,nanocarriers,gene,delivery,cas9,liposomes,clustered,viral,nanoparticle,targeting
# cv_phrases crispr,nanocarriers,gene,delivery,cas9,liposomes,clustered,viral,nanoparticle,targeting
# tfidf_keywords delivery crispr,development crispr,technology crispr,deliver crispr,crispr cas9
# tfidf_phrases delivery crispr,development crispr,technology crispr,deliver crispr,crispr cas9
# cv_keywords crispr,gene,cas9,endonuclease,deletions,nucleoprotein,modification,biotechnology,genome,rna
# cv_phrases crispr,gene,cas9,endonuclease,deletions,nucleoprotein,modification,biotechnology,genome,rna
# tfidf_keywords gene crispr,crispr rna,crispr cas9,genome modification,modification crispr
# tfidf_phrases gene crispr,crispr rna,crispr cas9,genome modification,modification crispr
# cv_keywords hiv,therapeutic,antiretroviral,proviral,antibody,adherence,receptor,viral,deactivation,targeting
# cv_phrases hiv,therapeutic,antiretroviral,proviral,antibody,adherence,receptor,viral,deactivation,targeting
# tfidf_keywords hiv therapeutic,strategy hiv,hiv cure,antiretroviral therapy,hiv target
# tfidf_phrases hiv therapeutic,strategy hiv,hiv cure,antiretroviral therapy,hiv target
# cv_keywords genome,cas9,crispr,immune,cancer,research,adaptive,genomics,bacteria,gene
# cv_phrases genome,cas9,crispr,immune,cancer,research,adaptive,genomics,bacteria,gene
# tfidf_keywords gene crispr,cas9 therapeutic,genome activate,crispr cas9,change genome
# tfidf_phrases gene crispr,cas9 therapeutic,genome activate,crispr cas9,change genome
# cv_keywords crispr,gene,cas9,method,efficient,mosaicism,genotyping,embryo,mechanism,mutation
# cv_phrases crispr,gene,cas9,method,efficient,mosaicism,genotyping,embryo,mechanism,mutation
# tfidf_keywords crispr technology,efficient gene,crispr cas9,using crispr,gene disruption
# tfidf_phrases crispr technology,efficient gene,crispr cas9,using crispr,gene disruption
# cv_keywords crispr,microbial,genome,immune,cas9,viral,adaptive,microbe,biological,targeted
# cv_phrases crispr,microbial,genome,immune,cas9,viral,adaptive,microbe,biological,targeted
# tfidf_keywords crispr rna,genome microbial,addressing crispr,viral genome,crispr cas9
# tfidf_phrases crispr rna,genome microbial,addressing crispr,viral genome,crispr cas9
# cv_keywords hbv,antigen,crispr,hepatitis,virus,cas9,plasmid,rna,replication,bacteria
# cv_phrases hbv,antigen,crispr,hepatitis,virus,cas9,plasmid,rna,replication,bacteria
# tfidf_keywords inhibits hbv,crispr cas9,virus hbv,antigen hbsag,assay hbv
# tfidf_phrases inhibits hbv,crispr cas9,virus hbv,antigen hbsag,assay hbv
# cv_keywords crispr,genome,zfn,repeat,clustered,talen,cas9,rapidly,immune,genetic
# cv_phrases crispr,genome,zfn,repeat,clustered,talen,cas9,rapidly,immune,genetic
# tfidf_keywords repeat crispr,problem genome,crispr consideration,genome editing,potential crispr
# tfidf_phrases repeat crispr,problem genome,crispr consideration,genome editing,potential crispr
# cv_keywords crispr,bacteria,bioinformatics,nucleic,genomic,immune,crrna,rna,repeat,crispridentify
# cv_phrases crispr,bacteria,bioinformatics,nucleic,genomic,immune,crrna,rna,repeat,crispridentify
# tfidf_keywords identified crispr,transcript crispr,region crispr,crispr detection,component crispr
# tfidf_phrases identified crispr,transcript crispr,region crispr,crispr detection,component crispr
# cv_keywords crispr,pseudomonas,genome,bacteriophage,infecting,bacteria,aeruginosa,rna,cas,interference
# cv_phrases crispr,pseudomonas,genome,bacteriophage,infecting,bacteria,aeruginosa,rna,cas,interference
# tfidf_keywords genome crispr,infecting pseudomonas,genome bacteriophage,eukaryotes crispr,crispr gene
# tfidf_phrases genome crispr,infecting pseudomonas,genome bacteriophage,eukaryotes crispr,crispr gene
# cv_keywords crispr,spcas9,nuclease,elegans,optimizing,multicellular,effector,cas9,diversity,microorganism
# cv_phrases crispr,spcas9,nuclease,elegans,optimizing,multicellular,effector,cas9,diversity,microorganism
# tfidf_keywords optimizing crispr,enzyme crispr,crispr effectors,crispr efficiency,crispr technology
# tfidf_phrases optimizing crispr,enzyme crispr,crispr effectors,crispr efficiency,crispr technology
# cv_keywords crispr,spacer,bacterium,genomic,pseudotuberculosis,protospacers,plasmid,locus,pyptb32953,clustered
# cv_phrases crispr,spacer,bacterium,genomic,pseudotuberculosis,protospacers,plasmid,locus,pyptb32953,clustered
# tfidf_keywords gene crispr,spacer sequence,spacers crispr,pyptb32953 spacer,crispr locus
# tfidf_phrases gene crispr,spacer sequence,spacers crispr,pyptb32953 spacer,crispr locus
# cv_keywords sgrnas,crispr,genome,efficient,cas9,design,regulation,editing,targeted,bioinformatics
# cv_phrases sgrnas,crispr,genome,efficient,cas9,design,regulation,editing,targeted,bioinformatics
# tfidf_keywords design sgrnas,genome editing,sgrnas efficient,use crispr,genome engineering
# tfidf_phrases design sgrnas,genome editing,sgrnas efficient,use crispr,genome engineering

# %% [markdown]
# ## Multiple  documents

# %%
import numpy as np
import itertools
from sklearn.metrics.pairwise import cosine_similarity
from typing import List, Tuple
import nltk
from nltk.corpus import stopwords
# from nltk.tokenize import sentence
from sklearn.feature_extraction.text import TfidfVectorizer


from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("paraphrase-MiniLM-L6-v2")

# %% [markdown]
# ## Count Vectorizer

# %%
def phrase_generator(docs,words,countvec):
    
    top_n:int=10
    diversity:0.5
    df = countvec.transform(docs)
    
    keywords=[]    
    phrases=[]
    
    
    for index, doc in enumerate(docs):
        doc_words = [words[i] for i in df[index].nonzero()[1]]
        if doc_words:
            doc_word_embeddings = np.array([cv_word_embeddings[i] for i in df[index].nonzero()[1]])
            distances = cosine_similarity([cv_doc_embeddings[index]], doc_word_embeddings)[0]
            doc_keywords = [(doc_words[i], round(float(distances[i]), 4)) for i in distances.argsort()[-top_n:]]
            doc_keywords=','.join([key[0] for key in doc_keywords])
            doc_phrases=''.join([key[0] for key in doc_keywords])
            keywords.append(doc_keywords)
            phrases.append(doc_phrases)                                 
    return keywords,phrases

# %%
# docs=preprocessed_df['lemmatize_text']
docs1=preprocessed_df1['lemmatize_text']
# Nouns_docs=preprocessed_df1['nouns_verbs'].apply(lambda x:' '.join(x))

CV_countvec = CountVectorizer(ngram_range=(1,1), stop_words=stop_words, min_df=1).fit(docs1)
CV_words = CV_countvec.get_feature_names()

cv_doc_embeddings = embedding_model.encode(docs1)
cv_word_embeddings =embedding_model.encode(CV_words)

# cv_keywords,cv_phrases=countvec_phrase_generator(docs)
cv_keywords_doc,cv_phrases_doc=phrase_generator(docs1,CV_words,CV_countvec)

# %% [markdown]
# ## TFIDF

# %%
tfidf_countvec = TfidfVectorizer(ngram_range=(1,1), stop_words=stop_words, min_df=1).fit(docs1)
tfidf_words = tfidf_countvec.get_feature_names()

tfidf_doc_embeddings = embedding_model.encode(docs1)
tfidf_word_embeddings = embedding_model.encode(tfidf_words)

tfidf_keywords_doc,tfidf_phrases_doc=phrase_generator(docs1,tfidf_words,tfidf_countvec)

# %%
sample_data['mmr_cv_keywords']=cv_keywords
sample_data['mmr_tfidf_bigram_keywords']=tfidf_keywords
sample_data['cv_doc_keywords']=cv_phrases_doc
sample_data['tfidf_doc_keywords']=tfidf_phrases_doc

# %%
sample_data.to_excel('V:/ML_projects/Merckgroup/Keyword_tagging/data/Keyword_validation_output_final.xlsx')
sample_data

# %% [markdown]
# # 3.Visualization

# %% [markdown]
# ## KEPPLER MAPPER
# ### A scikit library that provides the functionality to project data visually, to cluster it, and to create connections between it.
# #### source: git clone https://github.com/MLWave/kepler-mapper
#
#
# ### Goal :
#   1) Convert Documents into Features matrix \
#   2) Phrase combine with keywords for Projection \
#   3) Check keywords or phrases which are common and uncommon across all documents \
#
# ### Steps:
#
#  1) List of 2D representations of each of our sentences into features using TFIDF
#  2) Dimensionality Reduction: TruncatedSVD , Isomap \
#  3) Cluster: DBSCAN we’re going to cluster the Phrase sentences \
#  4) Common Keyphrase in Cluster : TF-IDF ngrams (1-3) to help us identify each cluster i.e.Phrases of length 3 which are most common.
#
# ### Benefits
# 1. The sentences in a cluster do have overlap in meaning (that’s why they’re clustered together)
# 2. To get overview of various and most important phrases with feature words that are group together
#
#  ### Analysis of Graph and Usage
#  1. Node Label: Most common word or Phrase in all sentence in that cluster
#  2. + Cluster details: Above and below average feature words with Members associated and with their
#  3. Links shows relation across keywords across the clusters
#
# ## Takeaway Points and Further steps
# ### 1. As we can still see same word has associated with different cluster.
# ### 2. Development with Analysis of this graph will be crucial step to bring contextual changes with our workflow in timely manner.
# ### 3. Variation in input documents will be analyzed i.e. document with Noun Phrase joined to be feeded in Graph.
# ### 4. Sentence similarity will be Replaced <b>Universal sentence encoder</b> while taking to Development phase
# ### 5. BERT Pretrained model can be used for preparing vectors with development phase.
# ### 6. Generalized Encoder and Decoder can be Productionized which can be useful in other modules

# %%
import kmapper as km
# Project all of the "sentences" down into a 2D representation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import Isomap
from sklearn.preprocessing import MinMaxScaler
from sklearn import cluster

# %%
def keyphrase_mapper(phrases):
    mapper = km.KeplerMapper(verbose=2)

    projected_X = mapper.fit_transform(np.array(phrases),
    projection=[TfidfVectorizer(analyzer="char",
                            ngram_range=(1,6),
                            max_df=0.85,
                            min_df=0.05),
            TruncatedSVD(n_components=100,
                         random_state=1729),
            Isomap(n_components=2,
                   n_jobs=-1)],
    scaler=[None, None, MinMaxScaler()])

    print("SHAPE",projected_X.shape)

    return projected_X

# %%
# Cluster the projected data
def cluster_visualization(docs,projected_X,path):
    mapper = km.KeplerMapper(verbose=2)
    graph = mapper.map(projected_X, clusterer=cluster.DBSCAN(eps=0.5, min_samples=3))
    # Get counts of phrases from data (to be used for the label and for cluster statistics)
    vec = TfidfVectorizer(analyzer="word",
                  strip_accents="unicode",
                  stop_words="english",
                  ngram_range=(1,3),
                  max_df=0.9,
                  min_df=0.02)

    interpretable_inverse_X = vec.fit_transform(docs).toarray()
    interpretable_inverse_X_names = vec.get_feature_names()

    print("SHAPE", interpretable_inverse_X.shape)
    print("FEATURE NAMES SAMPLE",
    interpretable_inverse_X_names[:400])
    html = mapper.visualize(graph,X=interpretable_inverse_X,
                        X_names=interpretable_inverse_X_names,
                        path_html=path,
                        lens=projected_X,
                        lens_names=["ISOMAP1", "ISOMAP2"],
                        title="Visualizing Text - Abstract",
                        )

# %%
projected_X=keyphrase_mapper(cv_phrases)
projected_tfidf_X=keyphrase_mapper(tfidf_phrases)

cluster_visualization(docs1,projected_X,'Abstract_CV_mmr.html')
cluster_visualization(docs1,projected_tfidf_X,'Abstract_tfidf_mmr.html')
# Out:
# KeplerMapper(verbose=2)
# ..Composing projection pipeline of length 3:
# 	Projections: TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.85, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
# 		TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
# 		Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
# 	Distance matrices: False
# False
# False
# 	Scalers: None
# None
# MinMaxScaler(copy=True, feature_range=(0, 1))
# ..Projecting on data shaped (200,)
#
# ..Projecting data using:
# 	TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.85, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
#
#
# ..Created projection shaped (200, 1283)
# ..Projecting on data shaped (200, 1283)
#
# ..Projecting data using:
# 	TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
#
# ..Projecting on data shaped (200, 100)
#
# ..Projecting data using:
# 	Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
#
#
# ..Scaling with: MinMaxScaler(copy=True, feature_range=(0, 1))
#
# SHAPE (200, 2)
# KeplerMapper(verbose=2)
# ..Composing projection pipeline of length 3:
# 	Projections: TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.85, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
# 		TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
# 		Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
# 	Distance matrices: False
# False
# False
# 	Scalers: None
# None
# MinMaxScaler(copy=True, feature_range=(0, 1))
# ..Projecting on data shaped (200,)
#
# ..Projecting data using:
# 	TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.85, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
#
#
# ..Created projection shaped (200, 1104)
# ..Projecting on data shaped (200, 1104)
#
# ..Projecting data using:
# 	TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
#
# ..Projecting on data shaped (200, 100)
#
# ..Projecting data using:
# 	Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
#
#
# ..Scaling with: MinMaxScaler(copy=True, feature_range=(0, 1))
#
# SHAPE (200, 2)
# KeplerMapper(verbose=2)
# Mapping on data shaped (200, 2) using lens shaped (200, 2)
#
# Minimal points in hypercube before clustering: 3
# Creating 100 hypercubes.
# Cube_0 is empty.
#
#    > Found 1 clusters in hypercube 1.
# Cube_2 is empty.
#
# Cube_3 is empty.
#
# Cube_4 is empty.
#
# Cube_5 is empty.
#
#    > Found 1 clusters in hypercube 6.
#    > Found 1 clusters in hypercube 7.
# Cube_8 is empty.
#
#    > Found 1 clusters in hypercube 9.
# Cube_10 is empty.
#
#    > Found 1 clusters in hypercube 11.
#    > Found 1 clusters in hypercube 12.
#    > Found 1 clusters in hypercube 13.
# Cube_14 is empty.
#
# Cube_15 is empty.
#
# Cube_16 is empty.
#
#    > Found 1 clusters in hypercube 17.
#    > Found 1 clusters in hypercube 18.
#    > Found 1 clusters in hypercube 19.
#    > Found 1 clusters in hypercube 20.
# Cube_21 is empty.
#
# Cube_22 is empty.
#
# Cube_23 is empty.
#
#    > Found 1 clusters in hypercube 24.
#    > Found 1 clusters in hypercube 25.
#    > Found 1 clusters in hypercube 26.
#    > Found 1 clusters in hypercube 27.
# Cube_28 is empty.
#
# Cube_29 is empty.
#
# Cube_30 is empty.
#
# Cube_31 is empty.
#
# Cube_32 is empty.
#
# Cube_33 is empty.
#
# Cube_34 is empty.
#
# Cube_35 is empty.
#
# Cube_36 is empty.
#
# Cube_37 is empty.
#
#    > Found 1 clusters in hypercube 38.
# Cube_39 is empty.
#
# Cube_40 is empty.
#
# Cube_41 is empty.
#
# Cube_42 is empty.
#
# Cube_43 is empty.
#
# Cube_44 is empty.
#
# Cube_45 is empty.
#
# Cube_46 is empty.
#
#    > Found 1 clusters in hypercube 47.
# Cube_48 is empty.
#
# Cube_49 is empty.
#
#
# Created 8 edges and 17 nodes in 0:00:00.032999.
# SHAPE (200, 1223)
# FEATURE NAMES SAMPLE ['ability', 'able', 'accurate', 'achieve', 'acid', 'acquired', 'acquisition', 'acr', 'acr gene', 'acr protein', 'acriia', 'acrs', 'action', 'activate', 'activation', 'active', 'activity', 'activity crispr', 'activity crispr cas', 'adaptation', 'adapted', 'adaptive', 'adaptive immune', 'adaptive immunity', 'addition', 'additionally', 'address', 'adjacent', 'adjacent motif', 'adopted', 'advance', 'advance crispr', 'advancement', 'advantage', 'aeruginosa', 'affect', 'affinity', 'agent', 'agriculture', 'aim', 'algorithm', 'allele', 'allow', 'allowed', 'allowing', 'allows', 'alteration', 'altering', 'alternative', 'analysis', 'analyze', 'analyzed', 'animal', 'anti', 'anti crispr', 'anti crispr protein', 'anti crisprs', 'antiviral', 'applicability', 'applicable', 'application', 'application crispr', 'application crispr cas', 'applications', 'applied', 'approach', 'approaches', 'archaea', 'archaea bacteria', 'archaeal', 'archaeal bacterial', 'area', 'arm', 'arm race', 'array', 'arrays', 'article', 'article discus', 'aspect', 'assay', 'assembly', 'associated', 'associated ca', 'associated gene', 'associated nuclease', 'associated protein', 'associated protein ca', 'associated sequence', 'attention', 'available', 'available bioinformatics', 'available bioinformatics online', 'available http', 'avenue', 'bacteria', 'bacteria archaea', 'bacterial', 'bacterial crispr', 'bacterial crispr cas', 'bacterial genome', 'bacteriophage', 'bacteriophage plasmid', 'barrier', 'base', 'base editing', 'base pair', 'based', 'based crispr', 'based technology', 'based therapy', 'based tool', 'basic', 'battle', 'better', 'bind', 'binding', 'binding activity', 'biochemical', 'biogenesis', 'bioinformatics', 'bioinformatics online', 'bioinformatics tool', 'biological', 'biological research', 'biologist', 'biology', 'biomedical', 'biomedical research', 'biotechnological', 'biotechnology', 'block', 'bound', 'break', 'broad', 'brought', 'built', 'ca', 'ca ca', 'ca crispr', 'ca crispr associated', 'ca dna', 'ca gene', 'ca inhibitor', 'ca protein', 'ca variant', 'called', 'cancer', 'candidate', 'capable', 'carrying', 'cas', 'cas activity', 'cas adaptive', 'cas adaptive immune', 'cas based', 'cas clustered', 'cas clustered regularly', 'cas complex', 'cas component', 'cas crispr', 'cas delivery', 'cas function', 'cas gene', 'cas genome', 'cas genome editing', 'cas immune', 'cas immunity', 'cas locus', 'cas mediated', 'cas prokaryotic', 'cas provide', 'cas provides', 'cas subtype', 'cas systems', 'cas technology', 'cas tool', 'cas used', 'cas widely', 'cascade', 'case', 'cassette', 'cell', 'cell crispr', 'cells', 'cellular', 'challenge', 'challenging', 'change', 'chapter', 'characteristic', 'characterization', 'characterized', 'chemical', 'chromatin', 'chromosomal', 'chromosome', 'class', 'classification', 'cleavage', 'cleavage activity', 'cleave', 'cleaves', 'cleaving', 'clinical', 'clinical application', 'clinical trial', 'clone', 'closely', 'clustered', 'clustered regularly', 'clustered regularly interspaced', 'cmr', 'coding', 'coli', 'combination', 'combined', 'combining', 'common', 'comparative', 'comparative analysis', 'compared', 'complementary', 'complete', 'complex', 'complex crispr', 'complexes', 'component', 'composition', 'comprehensive', 'computational', 'concept', 'concern', 'condition', 'conjugative', 'conservation', 'conserved', 'consideration', 'considering', 'consist', 'constant', 'constantly', 'construct', 'construction', 'containing', 'content', 'context', 'contrast', 'contribute', 'control', 'control gene', 'convenient', 'conventional', 'copy', 'copy number', 'cost', 'cpf', 'create', 'creating', 'crispr adaptation', 'crispr application', 'crispr array', 'crispr associated', 'crispr associated gene', 'crispr associated nuclease', 'crispr associated protein', 'crispr based', 'crispr cas', 'crispr cas activity', 'crispr cas adaptive', 'crispr cas based', 'crispr cas clustered', 'crispr cas complex', 'crispr cas crispr', 'crispr  ...
# Wrote visualization to: Abstract_CV_mmr.html
# KeplerMapper(verbose=2)
# Mapping on data shaped (200, 2) using lens shaped (200, 2)
#
# Minimal points in hypercube before clustering: 3
# Creating 100 hypercubes.
#    > Found 1 clusters in hypercube 0.
# Cube_1 is empty.
#
# Cube_2 is empty.
#
# Cube_3 is empty.
#
# Cube_4 is empty.
#
# Cube_5 is empty.
#
# Cube_6 is empty.
#
#    > Found 1 clusters in hypercube 7.
#    > Found 1 clusters in hypercube 8.
# Cube_9 is empty.
#
#    > Found 1 clusters in hypercube 10.
# Cube_11 is empty.
#
#    > Found 1 clusters in hypercube 12.
#    > Found 1 clusters in hypercube 13.
# Cube_14 is empty.
#
#    > Found 1 clusters in hypercube 15.
# Cube_16 is empty.
#
# Cube_17 is empty.
#
#    > Found 1 clusters in hypercube 18.
#    > Found 1 clusters in hypercube 19.
#    > Found 1 clusters in hypercube 20.
#    > Found 1 clusters in hypercube 21.
#    > Found 1 clusters in hypercube 22.
#    > Found 1 clusters in hypercube 23.
# Cube_24 is empty.
#
# Cube_25 is empty.
#
# Cube_26 is empty.
#
#    > Found 1 clusters in hypercube 27.
# Cube_28 is empty.
#
#    > Found 1 clusters in hypercube 29.
#    > Found 1 clusters in hypercube 30.
#    > Found 1 clusters in hypercube 31.
# Cube_32 is empty.
#
#    > Found 1 clusters in hypercube 33.
#    > Found 1 clusters in hypercube 34.
#    > Found 1 clusters in hypercube 35.
#    > Found 1 clusters in hypercube 36.
# Cube_37 is empty.
#
# Cube_38 is empty.
#
# Cube_39 is empty.
#
#    > Found 1 clusters in hypercube 40.
#    > Found 1 clusters in hypercube 41.
# Cube_42 is empty.
#
#    > Found 1 clusters in hypercube 43.
#    > Found 1 clusters in hypercube 44.
# Cube_45 is empty.
#
#    > Found 1 clusters in hypercube 46.
# Cube_47 is empty.
#
# Cube_48 is empty.
#
# Cube_49 is empty.
#
#    > Found 1 clusters in hypercube 50.
#    > Found 1 clusters in hypercube 51.
#    > Found 1 clusters in hypercube 52.
# Cube_53 is empty.
#
# Cube_54 is empty.
#
# Cube_55 is empty.
#
# Cube_56 is empty.
#
#    > Found 1 clusters in hypercube 57.
# Cube_58 is empty.
#
#    > Found 1 clusters in hypercube 59.
#    > Found 1 clusters in hypercube 60.
#    > Found 1 clusters in hypercube 61.
# Cube_62 is empty.
#
# Cube_63 is empty.
#
# Cube_64 is empty.
#
# Cube_65 is empty.
#
#    > Found 1 clusters in hypercube 66.
# Cube_67 is empty.
#
# Cube_68 is empty.
#
#    > Found 1 clusters in hypercube 69.
#    > Found 1 clusters in hypercube 70.
# Cube_71 is empty.
#
# Cube_72 is empty.
#
# Cube_73 is empty.
#
#    > Found 1 clusters in hypercube 74.
# Cube_75 is empty.
#
# Cube_76 is empty.
#
# Cube_77 is empty.
#
#    > Found 1 clusters in hypercube 78.
# Cube_79 is empty.
#
# Cube_80 is empty.
#
# Cube_81 is empty.
#
#
# Created 26 edges and 38 nodes in 0:00:00.033001.
# SHAPE (200, 1223)
# FEATURE NAMES SAMPLE ['ability', 'able', 'accurate', 'achieve', 'acid', 'acquired', 'acquisition', 'acr', 'acr gene', 'acr protein', 'acriia', 'acrs', 'action', 'activate', 'activation', 'active', 'activity', 'activity crispr', 'activity crispr cas', 'adaptation', 'adapted', 'adaptive', 'adaptive immune', 'adaptive immunity', 'addition', 'additionally', 'address', 'adjacent', 'adjacent motif', 'adopted', 'advance', 'advance crispr', 'advancement', 'advantage', 'aeruginosa', 'affect', 'affinity', 'agent', 'agriculture', 'aim', 'algorithm', 'allele', 'allow', 'allowed', 'allowing', 'allows', 'alteration', 'altering', 'alternative', 'analysis', 'analyze', 'analyzed', 'animal', 'anti', 'anti crispr', 'anti crispr protein', 'anti crisprs', 'antiviral', 'applicability', 'applicable', 'application', 'application crispr', 'application crispr cas', 'applications', 'applied', 'approach', 'approaches', 'archaea', 'archaea bacteria', 'archaeal', 'archaeal bacterial', 'area', 'arm', 'arm race', 'array', 'arrays', 'article', 'article discus', 'aspect', 'assay', 'assembly', 'associated', 'associated ca', 'associated gene', 'associated nuclease', 'associated protein', 'associated protein ca', 'associated sequence', 'attention', 'available', 'available bioinformatics', 'available bioinformatics online', 'available http', 'avenue', 'bacteria', 'bacteria archaea', 'bacterial', 'bacterial crispr', 'bacterial crispr cas', 'bacterial genome', 'bacteriophage', 'bacteriophage plasmid', 'barrier', 'base', 'base editing', 'base pair', 'based', 'based crispr', 'based technology', 'based therapy', 'based tool', 'basic', 'battle', 'better', 'bind', 'binding', 'binding activity', 'biochemical', 'biogenesis', 'bioinformatics', 'bioinformatics online', 'bioinformatics tool', 'biological', 'biological research', 'biologist', 'biology', 'biomedical', 'biomedical research', 'biotechnological', 'biotechnology', 'block', 'bound', 'break', 'broad', 'brought', 'built', 'ca', 'ca ca', 'ca crispr', 'ca crispr associated', 'ca dna', 'ca gene', 'ca inhibitor', 'ca protein', 'ca variant', 'called', 'cancer', 'candidate', 'capable', 'carrying', 'cas', 'cas activity', 'cas adaptive', 'cas adaptive immune', 'cas based', 'cas clustered', 'cas clustered regularly', 'cas complex', 'cas component', 'cas crispr', 'cas delivery', 'cas function', 'cas gene', 'cas genome', 'cas genome editing', 'cas immune', 'cas immunity', 'cas locus', 'cas mediated', 'cas prokaryotic', 'cas provide', 'cas provides', 'cas subtype', 'cas systems', 'cas technology', 'cas tool', 'cas used', 'cas widely', 'cascade', 'case', 'cassette', 'cell', 'cell crispr', 'cells', 'cellular', 'challenge', 'challenging', 'change', 'chapter', 'characteristic', 'characterization', 'characterized', 'chemical', 'chromatin', 'chromosomal', 'chromosome', 'class', 'classification', 'cleavage', 'cleavage activity', 'cleave', 'cleaves', 'cleaving', 'clinical', 'clinical application', 'clinical trial', 'clone', 'closely', 'clustered', 'clustered regularly', 'clustered regularly interspaced', 'cmr', 'coding', 'coli', 'combination', 'combined', 'combining', 'common', 'comparative', 'comparative analysis', 'compared', 'complementary', 'complete', 'complex', 'complex crispr', 'complexes', 'component', 'composition', 'comprehensive', 'computational', 'concept', 'concern', 'condition', 'conjugative', 'conservation', 'conserved', 'consideration', 'considering', 'consist', 'constant', 'constantly', 'construct', 'construction', 'containing', 'content', 'context', 'contrast', 'contribute', 'control', 'control gene', 'convenient', 'conventional', 'copy', 'copy number', 'cost', 'cpf', 'create', 'creating', 'crispr adaptation', 'crispr application', 'crispr array', 'crispr associated', 'crispr associated gene', 'crispr associated nuclease', 'crispr associated protein', 'crispr based', 'crispr cas', 'crispr cas activity', 'crispr cas adaptive', 'crispr cas based', 'crispr cas clustered', 'crispr cas complex', 'crispr cas crispr', 'crispr  ...
# Wrote visualization to: Abstract_tfidf_mmr.html

# %%
projected_X=keyphrase_mapper(cv_phrases_doc)
projected_tfidf_X=keyphrase_mapper(tfidf_phrases_doc)

cluster_visualization(docs1,projected_X,'Abstract_CV_doc.html')
cluster_visualization(docs1,projected_tfidf_X,'Abstract_tfidf_doc.html')
# Out:
# KeplerMapper(verbose=2)
# ..Composing projection pipeline of length 3:
# 	Projections: TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.85, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
# 		TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
# 		Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
# 	Distance matrices: False
# False
# False
# 	Scalers: None
# None
# MinMaxScaler(copy=True, feature_range=(0, 1))
# ..Projecting on data shaped ()
#
# ..Projecting data using:
# 	TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.85, max_features=None,
#                 min_df=0.05, ngram_range=(1, 6), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)
#
# ..Projecting on data shaped ()
#
# ..Projecting data using:
# 	TruncatedSVD(algorithm='randomized', n_components=100, n_iter=5,
#              random_state=1729, tol=0.0)
#
# ..Projecting on data shaped ()
#
# ..Projecting data using:
# 	Isomap(eigen_solver='auto', max_iter=None, metric='minkowski',
#        metric_params=None, n_components=2, n_jobs=-1, n_neighbors=5,
#        neighbors_algorithm='auto', p=2, path_method='auto', tol=0)
#
#
# ..Scaling with: MinMaxScaler(copy=True, feature_range=(0, 1))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-1172cfac184d> in <module>
# ----> 1 projected_X=keyphrase_mapper(cv_phrases_doc)
#       2 projected_tfidf_X=keyphrase_mapper(tfidf_phrases_doc)
#       3
#       4 cluster_visualization(docs1,projected_X,'Abstract_CV_doc.html')
#       5 cluster_visualization(docs1,projected_tfidf_X,'Abstract_tfidf_doc.html')
#
# <ipython-input-149-5b9dc78e4288> in keyphrase_mapper(phrases)
#       2     mapper = km.KeplerMapper(verbose=2)
#       3
# ----> 4     projected_X = mapper.fit_transform(np.array(phrases),
#       5     projection=[TfidfVectorizer(analyzer="char",
#       6                             ngram_range=(1,6),
#
# V:\ML_projects\Merckgroup\Notebooks\kmapper\kmapper.py in fit_transform(self, X, projection, scaler, distance_matrix)
#     356             projections, scalers, distance_matrices
#     357         ):
# --> 358             lens = self.project(
#     359                 lens,
#     360                 projection=projection,
#
# V:\ML_projects\Merckgroup\Notebooks\kmapper\kmapper.py in project(self, X, projection, scaler, distance_matrix)
#     281             if self.verbose > 0:
#     282                 print("\n..Scaling with: %s\n" % str(scaler))
# --> 283             X = scaler.fit_transform(X)
#     284
#     285         return X
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     369                             "Consider using MaxAbsScaler instead.")
#     370
# --> 371         X = check_array(X,
#     372                         estimator=self, dtype=FLOAT_DTYPES,
#     373                         force_all_finite="allow-nan")
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'sgrnas,crispr,genome,efficient,cas9,design,regulation,editing,targeted,bioinformatics'

# %%
from kmapper import jupyter
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 64em; }</style>"))

jupyter.display(path_html="Abstract_CV_mmr.html")
# Out:
# <style>div.output_scroll { height: 64em; }</style>
# <style>
#         .container { width:100% !important; }
#         .output_scroll {height: 800px !important;}
#         </style>
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=Abstract_CV_mmr.html width=100%% height=800 frameBorder="0"></iframe>

# %%
from kmapper import jupyter
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))

jupyter.display(path_html="Abstract_tfidf_mmr.html")
# Out:
# <style>div.output_scroll { height: 44em; }</style>
# <style>
#         .container { width:100% !important; }
#         .output_scroll {height: 800px !important;}
#         </style>
# <iframe src=Abstract_tfidf_mmr.html width=100%% height=800 frameBorder="0"></iframe>
